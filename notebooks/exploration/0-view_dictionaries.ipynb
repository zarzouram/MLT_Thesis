# %% [markdown]
# ## 1.0 Imports

# %%
import gzip
import json
from pathlib import Path
from pprint import pprint
from random import choice

# %% [markdown]
# ## 2.0 Define Paths

# %%
# Path for preproceed Wikitionary
wiktionary_dir = Path("../../data/processed/wikidata")
wiki_jsonl_path = wiktionary_dir / "ar-wiktextract-data.json.gz"
wiki_indices_path = wiktionary_dir / "ar_reindex.json.gz"

# %%
# Path to save words status
output_dir = Path("../../data/interim/")

# %% [markdown]
# # 3.0 Load Wikitionary Files

# %%
# 2. load the wikitionary
with gzip.open(wiki_jsonl_path, "rt", encoding="utf-8") as gzip_obj:
    wikitionary = []
    for i, json_line in enumerate(gzip_obj):
        wikitionary.append(dict(json.loads(json_line)))
        print(f"Reading line-{i}", end="\r")
# Out:
# Reading line-128636

# %%
# 3. load Indices
with gzip.open(wiki_indices_path, "rt", encoding="utf-8") as gzip_obj:
    wiki_idxs = json.load(gzip_obj)

# %% [markdown]
# # 4.0 View Dictionaries

# %% [markdown]
# ## 4.1 Search for Arabic Word in Wiktionary

# %%
ar_word = "متوسط"

# %%
if idxs := wiki_idxs.get(ar_word):
    for idx in idxs:
        print(idx)
        pprint(wikitionary[idx])
        print()
# Out:
# 7862
# {'متوسط': {'categories': ['Arabic 4-syllable words',
#                           'Arabic adjectives',
#                           'Arabic lemmas',
#                           'Arabic terms with IPA pronunciation',
#                           'Arabic terms with audio links'],
#            'derived': [{'roman': 'al-baḥr al-ʔabyaḍ al-mutawassiṭ',
#                         'word': 'اَلْبَحْر الْأَبْيَض الْمُتَوَسِّط'},
#                        {'roman': 'al-baḥr al-mutawassiṭ',
#                         'word': 'اَلْبَحْر الْمُتَوَسِّط'}],
#            'etymology_templates': [{'args': {'1': 'ar',
#                                              '2': 'participles',
#                                              '3': 'active participles',
#                                              '4': 'terms derived from active '
#                                                   'participles'},
#                                     'expansion': '',
#                                     'name': 'catlangname'},
#                                    {'args': {},
#                                     'expansion': 'Derived from the active '
#                                                  'participle',
#                                     'name': 'ar-active participle'},
#                                    {'args': {'1': 'ar',
#                                              '2': 'تَوَسَّطَ',
#                                              '3': '',
#                                              '4': 'to be in the middle'},
#                                     'expansion': 'تَوَسَّطَ (tawassaṭa, “to be '
#                                                  'in the middle”)',
#                                     'name': 'm'},
#                                    {'args': {'1': 'و', '2': 'س', '3': 'ط'},
#                                     'expansion': 'و س ط (w-s-ṭ)',
#                                     'name': 'ar-root'},
#                                    {'args': {'1': 'ar',
#                                              '2': 'وَسْط',
#                                              '3': '',
#                                              '4': 'middle'},
#                                     'expansion': 'وَسْط (wasṭ, “middle”)',
#                                     'name': 'm'}],
#            'etymology_text': 'Derived from the active participle of the verb '
#                              'تَوَسَّطَ (tawassaṭa, “to be in the middle”), '
#                              'constructed from the root و س ط (w-s-ṭ) of وَسْط '
#                              '(wasṭ, “middle”).',
#            'forms': [{'form': 'مُتَوَسِّط', 'tags': ['canonical']},
#                      {'form': 'mutawassiṭ', 'tags': ['romanization']},
#                      {'form': 'مُتَوَسِّطَة',
#                       'roman': 'mutawassiṭa',
#                       'tags': ['feminine']},
#                      {'form': 'مُتَوَسِّطُونَ',
#                       'roman': 'mutawassiṭūna',
#                       'tags': ['masculine', 'plural']},
#                      {'form': 'مُتَوَسِّطَات',
#                       'roman': 'mutawassiṭāt',
#                       'tags': ['feminine', 'plural']},
#                      {'form': '',
#                       'source': 'declension',
#                       'tags': ['table-tags']},
#                      {'form': 'ar-decl-adj',
#                       'source': 'declension',
#                       'tags': ['inflection-template']},
#                      {'form': 'مُتَوَسِّط',
#                       'roman': 'mutawassiṭ',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّط',
#                       'roman': 'al-mutawassiṭ',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَة',
#                       'roman': 'mutawassiṭa',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَة',
#                       'roman': 'al-mutawassiṭa',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطٌ',
#                       'roman': 'mutawassiṭun',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطُ',
#                       'roman': 'al-mutawassiṭu',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَةٌ',
#                       'roman': 'mutawassiṭatun',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَةُ',
#                       'roman': 'al-mutawassiṭatu',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطًا',
#                       'roman': 'mutawassiṭan',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَ',
#                       'roman': 'al-mutawassiṭa',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَةً',
#                       'roman': 'mutawassiṭatan',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَةَ',
#                       'roman': 'al-mutawassiṭata',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطٍ',
#                       'roman': 'mutawassiṭin',
#                       'source': 'declension',
#                       'tags': ['genitive',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطِ',
#                       'roman': 'al-mutawassiṭi',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'genitive',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَةٍ',
#                       'roman': 'mutawassiṭatin',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'genitive',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَةِ',
#                       'roman': 'al-mutawassiṭati',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'genitive',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَيْن',
#                       'roman': 'mutawassiṭayn',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'indefinite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَيْن',
#                       'roman': 'al-mutawassiṭayn',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَتَيْن',
#                       'roman': 'mutawassiṭatayn',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَتَيْن',
#                       'roman': 'al-mutawassiṭatayn',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَانِ',
#                       'roman': 'mutawassiṭāni',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'indefinite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَانِ',
#                       'roman': 'al-mutawassiṭāni',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَتَانِ',
#                       'roman': 'mutawassiṭatāni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَتَانِ',
#                       'roman': 'al-mutawassiṭatāni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَيْنِ',
#                       'roman': 'mutawassiṭayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'dual',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَيْنِ',
#                       'roman': 'al-mutawassiṭayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'dual',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَتَيْنِ',
#                       'roman': 'mutawassiṭatayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَتَيْنِ',
#                       'roman': 'al-mutawassiṭatayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَيْنِ',
#                       'roman': 'mutawassiṭayni',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'genitive',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَيْنِ',
#                       'roman': 'al-mutawassiṭayni',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'genitive',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطَتَيْنِ',
#                       'roman': 'mutawassiṭatayni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'genitive',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'الْمُتَوَسِّطَتَيْنِ',
#                       'roman': 'al-mutawassiṭatayni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'genitive',
#                                'singular',
#                                'triptote']},
#                      {'form': 'مُتَوَسِّطِين',
#                       'roman': 'mutawassiṭīn',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'informal',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'الْمُتَوَسِّطِين',
#                       'roman': 'al-mutawassiṭīn',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'informal',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'مُتَوَسِّطَات',
#                       'roman': 'mutawassiṭāt',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'indefinite',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'الْمُتَوَسِّطَات',
#                       'roman': 'al-mutawassiṭāt',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'مُتَوَسِّطُونَ',
#                       'roman': 'mutawassiṭūna',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'الْمُتَوَسِّطُونَ',
#                       'roman': 'al-mutawassiṭūna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'مُتَوَسِّطَاتٌ',
#                       'roman': 'mutawassiṭātun',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'indefinite',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'الْمُتَوَسِّطَاتُ',
#                       'roman': 'al-mutawassiṭātu',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'مُتَوَسِّطِينَ',
#                       'roman': 'mutawassiṭīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'الْمُتَوَسِّطِينَ',
#                       'roman': 'al-mutawassiṭīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'مُتَوَسِّطَاتٍ',
#                       'roman': 'mutawassiṭātin',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'feminine',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'الْمُتَوَسِّطَاتِ',
#                       'roman': 'al-mutawassiṭāti',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'feminine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'مُتَوَسِّطِينَ',
#                       'roman': 'mutawassiṭīna',
#                       'source': 'declension',
#                       'tags': ['genitive',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'الْمُتَوَسِّطِينَ',
#                       'roman': 'al-mutawassiṭīna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'genitive',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'مُتَوَسِّطَاتٍ',
#                       'roman': 'mutawassiṭātin',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'genitive',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'الْمُتَوَسِّطَاتِ',
#                       'roman': 'al-mutawassiṭāti',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'genitive',
#                                'plural',
#                                'sound-form']}],
#            'head_templates': [{'args': {'1': 'مُتَوَسِّط',
#                                         'el': '',
#                                         'f': 'مُتَوَسِّطَة',
#                                         'fpl': 'مُتَوَسِّطَات',
#                                         'pl': 'مُتَوَسِّطُونَ'},
#                                'expansion': 'مُتَوَسِّط • (mutawassiṭ) '
#                                             '(feminine مُتَوَسِّطَة '
#                                             '(mutawassiṭa), masculine plural '
#                                             'مُتَوَسِّطُونَ (mutawassiṭūna), '
#                                             'feminine plural مُتَوَسِّطَات '
#                                             '(mutawassiṭāt))',
#                                'name': 'ar-adj'},
#                               {'args': {'1': 'مُتَوَسِّط'},
#                                'expansion': 'مُتَوَسِّط • (mutawassiṭ) '
#                                             '(feminine مُتَوَسِّطَة '
#                                             '(mutawassiṭa), masculine plural '
#                                             'مُتَوَسِّطُونَ (mutawassiṭūna), '
#                                             'feminine plural مُتَوَسِّطَات '
#                                             '(mutawassiṭāt))',
#                                'name': 'ar-adj-sound'}],
#            'inflection_templates': [{'args': {'1': 'مُتَوَسِّط', 'pl': 'sp'},
#                                      'name': 'ar-decl-adj'}],
#            'lang': 'Arabic',
#            'lang_code': 'ar',
#            'pos': 'adj',
#            'senses': [{'glosses': ['being in the middle, mediating'],
#                        'links': [['middle', 'middle#English'],
#                                  ['mediating', 'mediating#English']]},
#                       {'glosses': ['middle, central'],
#                        'links': [['middle', 'middle#English'],
#                                  ['central', 'central#English']]},
#                       {'categories': ['Arabic terms with usage examples'],
#                        'examples': [{'english': 'their house is middle-sized',
#                                      'roman': 'baytuhum mutawassiṭu l-ḥajmi',
#                                      'text': 'بَيْتُهُمْ مُتَوَسِّطُ الْحَجْمِ',
#                                      'type': 'example'}],
#                        'glosses': ['medium'],
#                        'links': [['medium', 'medium#English']]},
#                       {'glosses': ['average, middling, indifferent'],
#                        'links': [['average', 'average#English'],
#                                  ['middling', 'middling#English'],
#                                  ['indifferent', 'indifferent#English']]}],
#            'sounds': [{'ipa': '/mu.ta.was.sitˤ/'},
#                       {'audio': 'Ar-متوسط.ogg',
#                        'mp3_url': 'https://upload.wikimedia.org/wikipedia/commons/transcoded/5/5e/Ar-%D9%85%D8%AA%D9%88%D8%B3%D8%B7.ogg/Ar-%D9%85%D8%AA%D9%88%D8%B3%D8%B7.ogg.mp3',
#                        'ogg_url': 'https://upload.wikimedia.org/wikipedia/commons/5/5e/Ar-%D9%85%D8%AA%D9%88%D8%B3%D8%B7.ogg',
#                        'text': 'Audio'}]}}

# %% [markdown]
# ## 4.2 View Random Dictionary

# %% [markdown]
# View dictionaries to check where to find the information

# %%
# show sample example
random_word = choice(list(wiki_idxs.keys()))
random_word_idxs = wiki_idxs[random_word]
print("word, idx:", random_word, random_word_idxs)
# Out:
# word, idx: املأ [56137]

# %%
pprint(wikitionary[choice(random_word_idxs)])
# Out:
# {'املأ': {'forms': [{'form': 'اِمْلَأْ', 'tags': ['canonical']},
#                     {'form': 'imlaʔ', 'tags': ['romanization']}],
#           'head_templates': [{'args': {'1': 'اِمْلَأْ', '2': 'I'},
#                               'expansion': 'اِمْلَأْ • (imlaʔ) (form I)',
#                               'name': 'ar-verb-form'}],
#           'lang': 'Arabic',
#           'lang_code': 'ar',
#           'pos': 'verb',
#           'senses': [{'categories': ['Arabic non-lemma forms',
#                                      'Arabic verb forms'],
#                       'form_of': [{'extra': 'malaʔa', 'word': 'مَلَأَ'}],
#                       'glosses': ['second-person masculine singular active '
#                                   'imperative of مَلَأَ (malaʔa)'],
#                       'links': [['مَلَأَ', 'ملأ#Arabic']],
#                       'tags': ['active',
#                                'form-i',
#                                'form-of',
#                                'imperative',
#                                'masculine',
#                                'second-person',
#                                'singular']}]}}

# %% [markdown]
# # 4.3 View Wikitionary By Index

# %%
wiki_idx = 10506
pprint(wikitionary[wiki_idx])
# Out:
# {'اسلنطح': {'categories': ['Arabic form-IIIq verbs',
#                            'Arabic lemmas',
#                            'Arabic sound form-IIIq verbs',
#                            'Arabic sound verbs',
#                            'Arabic sound verbs by conjugation',
#                            'Arabic verbs',
#                            'Arabic verbs with quadriliteral roots',
#                            'Terms with redundant transliterations',
#                            'Terms with redundant transliterations/ar'],
#             'etymology_templates': [{'args': {'1': 'س ل ط ح'},
#                                      'expansion': 'س ل ط ح (s-l-ṭ-ḥ)',
#                                      'name': 'ar-root'},
#                                     {'args': {'1': 'ar',
#                                               '2': 'سُلْطُح',
#                                               '3': '',
#                                               '4': 'slanting, rising '
#                                                    'gradually'},
#                                      'expansion': 'سُلْطُح (sulṭuḥ, “slanting, '
#                                                   'rising gradually”)',
#                                      'name': 'm'}],
#             'etymology_text': 'From the root س ل ط ح (s-l-ṭ-ḥ); possibly '
#                               'related to سُلْطُح (sulṭuḥ, “slanting, rising '
#                               'gradually”).',
#             'forms': [{'form': 'يَسْلَنْطِحُ',
#                        'roman': 'yaslanṭiḥu',
#                        'tags': ['non-past']},
#                       {'form': 'اِسْلَنْطَحَ', 'tags': ['canonical']},
#                       {'form': 'islanṭaḥa', 'tags': ['romanization']},
#                       {'form': '',
#                        'source': 'conjugation',
#                        'tags': ['table-tags']},
#                       {'form': 'ar-conj',
#                        'source': 'conjugation',
#                        'tags': ['inflection-template']},
#                       {'form': 'اِسْلِنْطَاح',
#                        'roman': 'islinṭāḥ',
#                        'source': 'conjugation',
#                        'tags': ['noun-from-verb']},
#                       {'form': 'مُسْلَنْطِح',
#                        'roman': 'muslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active', 'participle']},
#                       {'form': 'مُسْلَنْطَح',
#                        'roman': 'muslanṭaḥ',
#                        'source': 'conjugation',
#                        'tags': ['participle', 'passive']},
#                       {'form': 'اِسْلَنْطَحْتُ',
#                        'roman': 'islanṭaḥtu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطَحْتَ',
#                        'roman': 'islanṭaḥta',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطَحَ',
#                        'roman': 'islanṭaḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْتُمَا',
#                        'roman': 'islanṭaḥtumā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطَحَا',
#                        'roman': 'islanṭaḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْنَا',
#                        'roman': 'islanṭaḥnā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'plural']},
#                       {'form': 'اِسْلَنْطَحْتُمْ',
#                        'roman': 'islanṭaḥtum',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطَحُوا',
#                        'roman': 'islanṭaḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْتُ',
#                        'roman': 'islanṭaḥtu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطَحْتِ',
#                        'roman': 'islanṭaḥti',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطَحَتْ',
#                        'roman': 'islanṭaḥat',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْتُمَا',
#                        'roman': 'islanṭaḥtumā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطَحَتَا',
#                        'roman': 'islanṭaḥatā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْنَا',
#                        'roman': 'islanṭaḥnā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'plural']},
#                       {'form': 'اِسْلَنْطَحْتُنَّ',
#                        'roman': 'islanṭaḥtunna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطَحْنَ',
#                        'roman': 'islanṭaḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحُ',
#                        'roman': 'ʔaslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحُ',
#                        'roman': 'taslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'يَسْلَنْطِحُ',
#                        'roman': 'yaslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَانِ',
#                        'roman': 'taslanṭiḥāni',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحَانِ',
#                        'roman': 'yaslanṭiḥāni',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحُ',
#                        'roman': 'naslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'plural']},
#                       {'form': 'تَسْلَنْطِحُونَ',
#                        'roman': 'taslanṭiḥūna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحُونَ',
#                        'roman': 'yaslanṭiḥūna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحُ',
#                        'roman': 'ʔaslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحِينَ',
#                        'roman': 'taslanṭiḥīna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحُ',
#                        'roman': 'taslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَانِ',
#                        'roman': 'taslanṭiḥāni',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'second-person']},
#                       {'form': 'تَسْلَنْطِحَانِ',
#                        'roman': 'taslanṭiḥāni',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحُ',
#                        'roman': 'naslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'plural']},
#                       {'form': 'تَسْلَنْطِحْنَ',
#                        'roman': 'taslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحْنَ',
#                        'roman': 'yaslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحَ',
#                        'roman': 'ʔaslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'masculine',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحَ',
#                        'roman': 'taslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'masculine',
#                                 'second-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'يَسْلَنْطِحَ',
#                        'roman': 'yaslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'masculine',
#                                 'singular',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'masculine',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': 'يَسْلَنْطِحَا',
#                        'roman': 'yaslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'masculine',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحَ',
#                        'roman': 'naslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'masculine',
#                                 'plural',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحُوا',
#                        'roman': 'taslanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'masculine',
#                                 'plural',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': 'يَسْلَنْطِحُوا',
#                        'roman': 'yaslanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'masculine',
#                                 'plural',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحَ',
#                        'roman': 'ʔaslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحِي',
#                        'roman': 'taslanṭiḥī',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'second-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحَ',
#                        'roman': 'taslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'singular',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحَ',
#                        'roman': 'naslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'plural',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحْنَ',
#                        'roman': 'taslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'plural',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': 'يَسْلَنْطِحْنَ',
#                        'roman': 'yaslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'plural',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحْ',
#                        'roman': 'ʔaslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'jussive',
#                                 'masculine',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحْ',
#                        'roman': 'taslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'jussive',
#                                 'masculine',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'يَسْلَنْطِحْ',
#                        'roman': 'yaslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'jussive',
#                                 'masculine',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'jussive',
#                                 'masculine',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحَا',
#                        'roman': 'yaslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'jussive',
#                                 'masculine',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحْ',
#                        'roman': 'naslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'jussive',
#                                 'masculine',
#                                 'plural']},
#                       {'form': 'تَسْلَنْطِحُوا',
#                        'roman': 'taslanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'jussive',
#                                 'masculine',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحُوا',
#                        'roman': 'yaslanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'jussive',
#                                 'masculine',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحْ',
#                        'roman': 'ʔaslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'jussive',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحِي',
#                        'roman': 'taslanṭiḥī',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'jussive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحْ',
#                        'roman': 'taslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'jussive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'jussive',
#                                 'second-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'jussive',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحْ',
#                        'roman': 'naslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'jussive',
#                                 'plural']},
#                       {'form': 'تَسْلَنْطِحْنَ',
#                        'roman': 'taslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'jussive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحْنَ',
#                        'roman': 'yaslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'jussive',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطِحْ',
#                        'roman': 'islanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperative',
#                                 'masculine',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطِحَا',
#                        'roman': 'islanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'imperative',
#                                 'masculine',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطِحُوا',
#                        'roman': 'islanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperative',
#                                 'masculine',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطِحِي',
#                        'roman': 'islanṭiḥī',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperative',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطِحَا',
#                        'roman': 'islanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'imperative',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطِحْنَ',
#                        'roman': 'islanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperative',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اُسْلُنْطِحَ',
#                        'roman': 'uslunṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'second-person',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'يُسْلَنْطَحُ',
#                        'roman': 'yuslanṭaḥu',
#                        'source': 'conjugation',
#                        'tags': ['imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'masculine',
#                                 'passive',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['masculine',
#                                 'passive',
#                                 'second-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'يُسْلَنْطَحَ',
#                        'roman': 'yuslanṭaḥa',
#                        'source': 'conjugation',
#                        'tags': ['masculine',
#                                 'passive',
#                                 'singular',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'masculine',
#                                 'passive',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'masculine',
#                                 'passive',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'masculine',
#                                 'passive',
#                                 'plural',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['masculine',
#                                 'passive',
#                                 'plural',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['masculine',
#                                 'passive',
#                                 'plural',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'passive',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'passive',
#                                 'second-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'passive',
#                                 'singular',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'passive',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'passive',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'passive',
#                                 'plural',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'passive',
#                                 'plural',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'passive',
#                                 'plural',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'jussive',
#                                 'masculine',
#                                 'passive',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['jussive',
#                                 'masculine',
#                                 'passive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'يُسْلَنْطَحْ',
#                        'roman': 'yuslanṭaḥ',
#                        'source': 'conjugation',
#                        'tags': ['jussive',
#                                 'masculine',
#                                 'passive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'jussive',
#                                 'masculine',
#                                 'passive',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'jussive',
#                                 'masculine',
#                                 'passive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'jussive',
#                                 'masculine',
#                                 'passive',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['jussive',
#                                 'masculine',
#                                 'passive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['jussive',
#                                 'masculine',
#                                 'passive',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'jussive',
#                                 'passive',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'jussive',
#                                 'passive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'jussive',
#                                 'passive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'jussive',
#                                 'passive',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'jussive',
#                                 'passive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'jussive',
#                                 'passive',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'jussive',
#                                 'passive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'jussive',
#                                 'passive',
#                                 'plural',
#                                 'third-person']}],
#             'head_templates': [{'args': {'1': 'IIIq'},
#                                 'expansion': 'اِسْلَنْطَحَ • (islanṭaḥa) IIIq, '
#                                              'non-past يَسْلَنْطِحُ '
#                                              '(yaslanṭiḥu)',
#                                 'name': 'ar-verb'}],
#             'inflection_templates': [{'args': {'1': 'IIIq',
#                                                'passive': 'impers?'},
#                                       'name': 'ar-conj'}],
#             'lang': 'Arabic',
#             'lang_code': 'ar',
#             'pos': 'verb',
#             'senses': [{'glosses': ['to fall on the face'],
#                         'links': [['fall', 'fall'], ['face', 'face']]},
#                        {'glosses': ['to be long and wide'],
#                         'links': [['long', 'long'], ['wide', 'wide']]}]}}

# %% [markdown]
# # 5.0 Check Values in Wikitionaries

# %% [markdown]
# ## 5.1 Check Values in Categories

# %% [markdown]
# - List `categories` values in:
#   - `WIKITIONARY_DICT["categories"]: List[str]`
#   - `Senses[i]["categories"]` where `senses` is `WIKITIONARY_DICT["senses"]: List[Dict[str: List[str]]]`

# %%
import re

pattern = r'^(I|II|III|IV|V|VI|VII|VIII|IX|X|XI)$'


categories_values = set()
verb_forms = set()
for i, entry in enumerate(wikitionary):
    verb_form = []
    for _, word_data in entry.items():
        values = word_data.get("categories", [])
        if word_data["pos"] != "verb":
            continue
        for value in values:
            if match := re.search(r"(?<=form-)\w+(?= verbs)", value):
                if match.group() == "IIIq":
                    print(i)
                verb_form.append(match.group())
            categories_values.update(values)
    verb_forms.update([" ".join(verb_form)])
        # for sense in word_data.get("senses", []):
        #     if categories_senses := sense.get("categories", []):
        #         categories_values.update(categories_senses)

# pprint(sorted(list(categories_values)))
pprint(verb_forms)
# Out:
# 10506
# 10506
# 22473
# 22473
# 23260
# 23260
# 24582
# 24582
# 24596
# 24596
# {'',
#  'I I',
#  'I I I',
#  'I I I I',
#  'I I I I I',
#  'I I I I I I',
#  'I I I I I I I',
#  'I I II II I II',
#  'I I III III I',
#  'I I IV IV I',
#  'I II I I I II II II I II',
#  'I II I I II',
#  'I II I I II II',
#  'I II I II',
#  'I II I II I I I II II',
#  'I II I II I I I II II II',
#  'I II I II II',
#  'II II',
#  'II II II',
#  'II II II II',
#  'II II II II II',
#  'II II II II II II',
#  'II II IV IV II',
#  'III III',
#  'III III III',
#  'III III III III',
#  'III III III III III',
#  'III III IV IV III IV',
#  'III IV III III III IV IV IV III IV',
#  'IIIq IIIq',
#  'IIq IIq',
#  'IIq IIq IIq',
#  'IV IV',
#  'IV IV IV',
#  'IV IV IV IV',
#  'IV IV IV IV IV',
#  'IV Iq Iq Iq IV',
#  'IVq IVq',
#  'IVq IVq IVq',
#  'IX IX',
#  'Iq Iq',
#  'Iq Iq Iq',
#  'Iq Iq Iq Iq',
#  'Iq V Iq V',
#  'V V',
#  'V V V',
#  'V V V V',
#  'V V V V V',
#  'VI VI',
#  'VI VI VI',
#  'VI VI VI VI VI',
#  'VII VII',
#  'VII VII VII',
#  'VII VII VII VII VII',
#  'VIII VIII',
#  'VIII VIII VIII',
#  'VIII VIII VIII VIII',
#  'VIII VIII VIII VIII VIII',
#  'VIII X X VIII',
#  'X X',
#  'X X X',
#  'X X X X X',
#  'XI XI',
#  'XII XII',
#  'XII XII XII',
#  'XIII XIII'}
