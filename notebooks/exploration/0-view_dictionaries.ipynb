# %% [markdown]
# ## 1.0 Imports

# %%
import gzip
import json
from pathlib import Path
from pprint import pprint
from random import choice

# %% [markdown]
# ## 2.0 Define Paths

# %%
# Path for preproceed Wikitionary
wiktionary_dir = Path("../../data/processed/wikidata")
wiki_jsonl_path = wiktionary_dir / "ar-wiktextract-data.json.gz"
wiki_indices_path = wiktionary_dir / "ar_reindex.json.gz"

# %%
# Path to save words status
output_dir = Path("../../data/interim/")

# %% [markdown]
# # 3.0 Load Wikitionary Files

# %%
# 2. load the wikitionary
with gzip.open(wiki_jsonl_path, "rt", encoding="utf-8") as gzip_obj:
    wikitionary = []
    for i, json_line in enumerate(gzip_obj):
        wikitionary.append(dict(json.loads(json_line)))
        print(f"Reading line-{i}", end="\r")
# Out:
# Reading line-128636

# %%
# 3. load Indices
with gzip.open(wiki_indices_path, "rt", encoding="utf-8") as gzip_obj:
    wiki_idxs = json.load(gzip_obj)

# %% [markdown]
# # 4.0 View Dictionaries

# %% [markdown]
# ## 4.1 Search for Arabic Word in Wiktionary

# %%
ar_word = "لاتفي"

# %%
if idxs := wiki_idxs.get(ar_word):
    for idx in idxs:
        print(idx)
        pprint(wikitionary[idx])
        print()
# Out:
# 124663
# {'لاتفي': {'categories': ['Arabic 2-syllable words',
#                           'Arabic adjectives',
#                           'Arabic lemmas',
#                           'Arabic masculine nouns',
#                           'Arabic nouns',
#                           'Arabic relative nouns (nisba)',
#                           'Arabic terms with IPA pronunciation',
#                           'Terms with redundant transliterations',
#                           'Terms with redundant transliterations/ar'],
#            'etymology_templates': [{'args': {'1': 'ar',
#                                              '2': 'relative adjectives '
#                                                   '(nisba)'},
#                                     'expansion': '',
#                                     'name': 'catlangname'},
#                                    {'args': {'1': 'ar',
#                                              '2': 'لَاتْفِيَا',
#                                              '3': 'ِيّ',
#                                              'id2': 'nisba',
#                                              't1': 'Latvia',
#                                              'tr1': ''},
#                                     'expansion': 'لَاتْفِيَا (lātfiyā, '
#                                                  '“Latvia”) + ـِيّ (-iyy)',
#                                     'name': 'suffix'},
#                                    {'args': {'1': 'لَاتْفِيَا', '2': 'Latvia'},
#                                     'expansion': 'Relative adjective (nisba) '
#                                                  'composed of لَاتْفِيَا '
#                                                  '(lātfiyā, “Latvia”) + ـِيّ '
#                                                  '(-iyy)',
#                                     'name': 'ar-etym-nisba'}],
#            'etymology_text': 'Relative adjective (nisba) composed of '
#                              'لَاتْفِيَا (lātfiyā, “Latvia”) + ـِيّ (-iyy).',
#            'forms': [{'form': 'لَاتْفِيّ', 'head_nr': 1, 'tags': ['canonical']},
#                      {'form': 'lātfiyy',
#                       'head_nr': 1,
#                       'tags': ['romanization']},
#                      {'form': 'لَاتْفِيَّة',
#                       'head_nr': 1,
#                       'roman': 'lātfiyya',
#                       'tags': ['feminine']},
#                      {'form': 'لَاتْفِيُّونَ',
#                       'head_nr': 1,
#                       'roman': 'lātfiyyūna',
#                       'tags': ['masculine', 'plural']},
#                      {'form': 'لَاتْفِيَّات',
#                       'head_nr': 1,
#                       'roman': 'lātfiyyāt',
#                       'tags': ['feminine', 'plural']},
#                      {'form': 'لَاتْڤِيّ', 'head_nr': 2, 'tags': ['canonical']},
#                      {'form': 'lātviyy',
#                       'head_nr': 2,
#                       'tags': ['romanization']},
#                      {'form': 'لَاتْڤِيَّة',
#                       'head_nr': 2,
#                       'roman': 'lātviyya',
#                       'tags': ['feminine']},
#                      {'form': 'لَاتْڤِيُّونَ',
#                       'head_nr': 2,
#                       'roman': 'lātviyyūna',
#                       'tags': ['masculine', 'plural']},
#                      {'form': 'لَاتْڤِيَّات',
#                       'head_nr': 2,
#                       'roman': 'lātviyyāt',
#                       'tags': ['feminine', 'plural']},
#                      {'form': '',
#                       'source': 'declension',
#                       'tags': ['table-tags']},
#                      {'form': 'ar-decl-adj',
#                       'source': 'declension',
#                       'tags': ['inflection-template']},
#                      {'form': 'لَاتْفِي',
#                       'roman': 'lātfī',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِي',
#                       'roman': 'lātvī',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِي',
#                       'roman': 'al-lātfī',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِي',
#                       'roman': 'al-lātvī',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّة',
#                       'roman': 'lātfiyya',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّة',
#                       'roman': 'lātviyya',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّة',
#                       'roman': 'al-lātfiyya',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّة',
#                       'roman': 'al-lātviyya',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيٌّ',
#                       'roman': 'lātfiyyun',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيٌّ',
#                       'roman': 'lātviyyun',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيُّ',
#                       'roman': 'al-lātfiyyu',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيُّ',
#                       'roman': 'al-lātviyyu',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّةٌ',
#                       'roman': 'lātfiyyatun',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّةٌ',
#                       'roman': 'lātviyyatun',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّةُ',
#                       'roman': 'al-lātfiyyatu',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّةُ',
#                       'roman': 'al-lātviyyatu',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيًّا',
#                       'roman': 'lātfiyyan',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيًّا',
#                       'roman': 'lātviyyan',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّ',
#                       'roman': 'al-lātfiyya',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّ',
#                       'roman': 'al-lātviyya',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّةً',
#                       'roman': 'lātfiyyatan',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّةً',
#                       'roman': 'lātviyyatan',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'feminine',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّةَ',
#                       'roman': 'al-lātfiyyata',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّةَ',
#                       'roman': 'al-lātviyyata',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيٍّ',
#                       'roman': 'lātfiyyin',
#                       'source': 'declension',
#                       'tags': ['genitive',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيٍّ',
#                       'roman': 'lātviyyin',
#                       'source': 'declension',
#                       'tags': ['genitive',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيِّ',
#                       'roman': 'al-lātfiyyi',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'genitive',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيِّ',
#                       'roman': 'al-lātviyyi',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'genitive',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّةٍ',
#                       'roman': 'lātfiyyatin',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'genitive',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّةٍ',
#                       'roman': 'lātviyyatin',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'feminine',
#                                'genitive',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّةِ',
#                       'roman': 'al-lātfiyyati',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'genitive',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّةِ',
#                       'roman': 'al-lātviyyati',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'feminine',
#                                'genitive',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّيْن',
#                       'roman': 'lātfiyyayn',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'indefinite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّيْن',
#                       'roman': 'lātviyyayn',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'indefinite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّيْن',
#                       'roman': 'al-lātfiyyayn',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّيْن',
#                       'roman': 'al-lātviyyayn',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّتَيْن',
#                       'roman': 'lātfiyyatayn',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّتَيْن',
#                       'roman': 'lātviyyatayn',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّتَيْن',
#                       'roman': 'al-lātfiyyatayn',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّتَيْن',
#                       'roman': 'al-lātviyyatayn',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'informal',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّانِ',
#                       'roman': 'lātfiyyāni',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'indefinite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّانِ',
#                       'roman': 'lātviyyāni',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'indefinite',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّانِ',
#                       'roman': 'al-lātfiyyāni',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّانِ',
#                       'roman': 'al-lātviyyāni',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'masculine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّتَانِ',
#                       'roman': 'lātfiyyatāni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّتَانِ',
#                       'roman': 'lātviyyatāni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّتَانِ',
#                       'roman': 'al-lātfiyyatāni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّتَانِ',
#                       'roman': 'al-lātviyyatāni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'nominative',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّيْنِ',
#                       'roman': 'lātfiyyayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'dual',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّيْنِ',
#                       'roman': 'lātviyyayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'dual',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّيْنِ',
#                       'roman': 'al-lātfiyyayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'dual',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّيْنِ',
#                       'roman': 'al-lātviyyayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'dual',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّتَيْنِ',
#                       'roman': 'lātfiyyatayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّتَيْنِ',
#                       'roman': 'lātviyyatayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّتَيْنِ',
#                       'roman': 'al-lātfiyyatayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّتَيْنِ',
#                       'roman': 'al-lātviyyatayni',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّيْنِ',
#                       'roman': 'lātfiyyayni',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'genitive',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّيْنِ',
#                       'roman': 'lātviyyayni',
#                       'source': 'declension',
#                       'tags': ['dual',
#                                'genitive',
#                                'indefinite',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّيْنِ',
#                       'roman': 'al-lātfiyyayni',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'genitive',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّيْنِ',
#                       'roman': 'al-lātviyyayni',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'dual',
#                                'genitive',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّتَيْنِ',
#                       'roman': 'lātfiyyatayni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'genitive',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيَّتَيْنِ',
#                       'roman': 'lātviyyatayni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'dual',
#                                'feminine',
#                                'genitive',
#                                'indefinite',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّتَيْنِ',
#                       'roman': 'al-lātfiyyatayni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'genitive',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِيَّتَيْنِ',
#                       'roman': 'al-lātviyyatayni',
#                       'source': 'declension',
#                       'tags': ['ar-infl-a',
#                                'definite',
#                                'dual',
#                                'feminine',
#                                'genitive',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِيِّين',
#                       'roman': 'lātfiyyīn',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'informal',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّين',
#                       'roman': 'lātviyyīn',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'informal',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّين',
#                       'roman': 'al-lātfiyyīn',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'informal',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّين',
#                       'roman': 'al-lātviyyīn',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'informal',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّات',
#                       'roman': 'lātfiyyāt',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'indefinite',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّات',
#                       'roman': 'lātviyyāt',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'indefinite',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّات',
#                       'roman': 'al-lātfiyyāt',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّات',
#                       'roman': 'al-lātviyyāt',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيُّونَ',
#                       'roman': 'lātfiyyūna',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيُّونَ',
#                       'roman': 'lātviyyūna',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيُّونَ',
#                       'roman': 'al-lātfiyyūna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيُّونَ',
#                       'roman': 'al-lātviyyūna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٌ',
#                       'roman': 'lātfiyyātun',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'indefinite',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٌ',
#                       'roman': 'lātviyyātun',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'indefinite',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتُ',
#                       'roman': 'al-lātfiyyātu',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتُ',
#                       'roman': 'al-lātviyyātu',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّينَ',
#                       'roman': 'lātfiyyīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّينَ',
#                       'roman': 'lātviyyīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّينَ',
#                       'roman': 'al-lātfiyyīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّينَ',
#                       'roman': 'al-lātviyyīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٍ',
#                       'roman': 'lātfiyyātin',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'feminine',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٍ',
#                       'roman': 'lātviyyātin',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'feminine',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتِ',
#                       'roman': 'al-lātfiyyāti',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'feminine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتِ',
#                       'roman': 'al-lātviyyāti',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'feminine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّينَ',
#                       'roman': 'lātfiyyīna',
#                       'source': 'declension',
#                       'tags': ['genitive',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّينَ',
#                       'roman': 'lātviyyīna',
#                       'source': 'declension',
#                       'tags': ['genitive',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّينَ',
#                       'roman': 'al-lātfiyyīna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'genitive',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّينَ',
#                       'roman': 'al-lātviyyīna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'genitive',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٍ',
#                       'roman': 'lātfiyyātin',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'genitive',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٍ',
#                       'roman': 'lātviyyātin',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'genitive',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتِ',
#                       'roman': 'al-lātfiyyāti',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'genitive',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتِ',
#                       'roman': 'al-lātviyyāti',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'genitive',
#                                'plural',
#                                'sound-form']}],
#            'head_templates': [{'args': {'1': 'لَاتْفِيّ',
#                                         'el': '',
#                                         'f': 'لَاتْفِيَّة',
#                                         'fpl': 'لَاتْفِيَّات',
#                                         'pl': 'لَاتْفِيُّونَ'},
#                                'expansion': 'لَاتْفِيّ • (lātfiyy) (feminine '
#                                             'لَاتْفِيَّة (lātfiyya), masculine '
#                                             'plural لَاتْفِيُّونَ '
#                                             '(lātfiyyūna), feminine plural '
#                                             'لَاتْفِيَّات (lātfiyyāt))',
#                                'name': 'ar-adj'},
#                               {'args': {'1': 'لَاتْفِيّ'},
#                                'expansion': 'لَاتْفِيّ • (lātfiyy) (feminine '
#                                             'لَاتْفِيَّة (lātfiyya), masculine '
#                                             'plural لَاتْفِيُّونَ '
#                                             '(lātfiyyūna), feminine plural '
#                                             'لَاتْفِيَّات (lātfiyyāt))',
#                                'name': 'ar-adj-sound'},
#                               {'args': {'1': 'لَاتْڤِيّ',
#                                         'el': '',
#                                         'f': 'لَاتْڤِيَّة',
#                                         'fpl': 'لَاتْڤِيَّات',
#                                         'pl': 'لَاتْڤِيُّونَ'},
#                                'expansion': 'لَاتْڤِيّ • (lātviyy) (feminine '
#                                             'لَاتْڤِيَّة (lātviyya), masculine '
#                                             'plural لَاتْڤِيُّونَ '
#                                             '(lātviyyūna), feminine plural '
#                                             'لَاتْڤِيَّات (lātviyyāt))',
#                                'name': 'ar-adj'},
#                               {'args': {'1': 'لَاتْڤِيّ'},
#                                'expansion': 'لَاتْڤِيّ • (lātviyy) (feminine '
#                                             'لَاتْڤِيَّة (lātviyya), masculine '
#                                             'plural لَاتْڤِيُّونَ '
#                                             '(lātviyyūna), feminine plural '
#                                             'لَاتْڤِيَّات (lātviyyāt))',
#                                'name': 'ar-adj-sound'}],
#            'inflection_templates': [{'args': {'1': 'لَاتْفِيّ',
#                                               'head2': 'لَاتْفِيّ',
#                                               'pl': 'sp',
#                                               'tr2': 'lātviyy'},
#                                      'name': 'ar-decl-adj'}],
#            'lang': 'Arabic',
#            'lang_code': 'ar',
#            'pos': 'adj',
#            'senses': [{'glosses': ['Latvian'],
#                        'head_nr': 2,
#                        'links': [['Latvian', 'Latvian']]}],
#            'sounds': [{'ipa': '/laːt.fijj/'}, {'ipa': '/laːt.vijj/'}]}}
#
# 124664
# {'لاتفي': {'categories': ['Arabic 2-syllable words',
#                           'Arabic lemmas',
#                           'Arabic masculine nouns',
#                           'Arabic nouns',
#                           'Arabic relative nouns (nisba)',
#                           'Arabic terms with IPA pronunciation',
#                           'Terms with redundant transliterations',
#                           'Terms with redundant transliterations/ar'],
#            'etymology_templates': [{'args': {'1': 'ar',
#                                              '2': 'relative adjectives '
#                                                   '(nisba)'},
#                                     'expansion': '',
#                                     'name': 'catlangname'},
#                                    {'args': {'1': 'ar',
#                                              '2': 'لَاتْفِيَا',
#                                              '3': 'ِيّ',
#                                              'id2': 'nisba',
#                                              't1': 'Latvia',
#                                              'tr1': ''},
#                                     'expansion': 'لَاتْفِيَا (lātfiyā, '
#                                                  '“Latvia”) + ـِيّ (-iyy)',
#                                     'name': 'suffix'},
#                                    {'args': {'1': 'لَاتْفِيَا', '2': 'Latvia'},
#                                     'expansion': 'Relative adjective (nisba) '
#                                                  'composed of لَاتْفِيَا '
#                                                  '(lātfiyā, “Latvia”) + ـِيّ '
#                                                  '(-iyy)',
#                                     'name': 'ar-etym-nisba'}],
#            'etymology_text': 'Relative adjective (nisba) composed of '
#                              'لَاتْفِيَا (lātfiyā, “Latvia”) + ـِيّ (-iyy).',
#            'forms': [{'form': 'لَاتْفِيّ', 'head_nr': 1, 'tags': ['canonical']},
#                      {'form': 'lātfiyy',
#                       'head_nr': 1,
#                       'tags': ['romanization']},
#                      {'form': 'lātfiyyūn',
#                       'head_nr': 1,
#                       'tags': ['romanization']},
#                      {'form': 'lātfiyya',
#                       'head_nr': 1,
#                       'tags': ['romanization']},
#                      {'form': 'لَاتْڤِيّ', 'head_nr': 2, 'tags': ['canonical']},
#                      {'form': 'lātviyy',
#                       'head_nr': 2,
#                       'tags': ['romanization']},
#                      {'form': 'lātviyyūn',
#                       'head_nr': 2,
#                       'tags': ['romanization']},
#                      {'form': 'lātviyya',
#                       'head_nr': 2,
#                       'tags': ['romanization']},
#                      {'form': '',
#                       'source': 'declension',
#                       'tags': ['table-tags']},
#                      {'form': 'ar-decl-gendered-noun',
#                       'source': 'declension',
#                       'tags': ['inflection-template']},
#                      {'form': 'لَاتْفِي',
#                       'roman': 'lātfī',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'لَاتْفِي',
#                       'roman': 'lātvī',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'informal',
#                                'masculine',
#                                'singular',
#                                'triptote']},
#                      {'form': 'اللَّاتْفِي',
#                       'roman': 'al-lātfī',
#                       'source': 'declension',
#                       'tags': ['definite',
# ...
#                       'tags': ['definite',
#                                'feminine',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّات',
#                       'roman': 'lātfiyyāt',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'feminine',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّات',
#                       'roman': 'lātviyyāt',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'feminine',
#                                'informal',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيُّونَ',
#                       'roman': 'lātfiyyūna',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيُّونَ',
#                       'roman': 'lātviyyūna',
#                       'source': 'declension',
#                       'tags': ['indefinite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيُّونَ',
#                       'roman': 'al-lātfiyyūna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيُّونَ',
#                       'roman': 'al-lātviyyūna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيُّو',
#                       'roman': 'lātfiyyū',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيُّو',
#                       'roman': 'lātviyyū',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'masculine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٌ',
#                       'roman': 'lātfiyyātun',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'indefinite',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٌ',
#                       'roman': 'lātviyyātun',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'indefinite',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتُ',
#                       'roman': 'al-lātfiyyātu',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتُ',
#                       'roman': 'al-lātviyyātu',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتُ',
#                       'roman': 'lātfiyyātu',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'feminine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتُ',
#                       'roman': 'lātviyyātu',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'feminine',
#                                'nominative',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّينَ',
#                       'roman': 'lātfiyyīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّينَ',
#                       'roman': 'lātviyyīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّينَ',
#                       'roman': 'al-lātfiyyīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّينَ',
#                       'roman': 'al-lātviyyīna',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّي',
#                       'roman': 'lātfiyyī',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'construct',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّي',
#                       'roman': 'lātviyyī',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'construct',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٍ',
#                       'roman': 'lātfiyyātin',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'feminine',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٍ',
#                       'roman': 'lātviyyātin',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'feminine',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتِ',
#                       'roman': 'al-lātfiyyāti',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'feminine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتِ',
#                       'roman': 'al-lātviyyāti',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'definite',
#                                'feminine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتِ',
#                       'roman': 'lātfiyyāti',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'construct',
#                                'feminine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتِ',
#                       'roman': 'lātviyyāti',
#                       'source': 'declension',
#                       'tags': ['accusative',
#                                'construct',
#                                'feminine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّينَ',
#                       'roman': 'lātfiyyīna',
#                       'source': 'declension',
#                       'tags': ['genitive',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّينَ',
#                       'roman': 'lātviyyīna',
#                       'source': 'declension',
#                       'tags': ['genitive',
#                                'indefinite',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّينَ',
#                       'roman': 'al-lātfiyyīna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'genitive',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيِّينَ',
#                       'roman': 'al-lātviyyīna',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'genitive',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّي',
#                       'roman': 'lātfiyyī',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'genitive',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيِّي',
#                       'roman': 'lātviyyī',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'genitive',
#                                'masculine',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٍ',
#                       'roman': 'lātfiyyātin',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'genitive',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتٍ',
#                       'roman': 'lātviyyātin',
#                       'source': 'declension',
#                       'tags': ['feminine',
#                                'genitive',
#                                'indefinite',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتِ',
#                       'roman': 'al-lātfiyyāti',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'genitive',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'اللَّاتْفِيَّاتِ',
#                       'roman': 'al-lātviyyāti',
#                       'source': 'declension',
#                       'tags': ['definite',
#                                'feminine',
#                                'genitive',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتِ',
#                       'roman': 'lātfiyyāti',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'feminine',
#                                'genitive',
#                                'plural',
#                                'sound-form']},
#                      {'form': 'لَاتْفِيَّاتِ',
#                       'roman': 'lātviyyāti',
#                       'source': 'declension',
#                       'tags': ['construct',
#                                'feminine',
#                                'genitive',
#                                'plural',
#                                'sound-form']}],
#            'head_templates': [{'args': {'1': 'ar',
#                                         '2': 'noun',
#                                         'g': 'm',
#                                         'head': 'لَاتْفِيّ',
#                                         'tr': 'lātfiyy'},
#                                'expansion': 'لَاتْفِيّ • (lātfiyy) m',
#                                'name': 'head'},
#                               {'args': {'1': 'لَاتْفِيّ'},
#                                'expansion': 'لَاتْفِيّ • (lātfiyy) m, plural '
#                                             'لَاتْفِيُّون (lātfiyyūn), '
#                                             'feminine لَاتْفِيَّة (lātfiyya)',
#                                'name': 'ar-noun-nisba'},
#                               {'args': {'1': 'ar',
#                                         '2': 'noun',
#                                         'g': 'm',
#                                         'head': 'لَاتْڤِيّ',
#                                         'tr': 'lātviyy'},
#                                'expansion': 'لَاتْڤِيّ • (lātviyy) m',
#                                'name': 'head'},
#                               {'args': {'1': 'لَاتْڤِيّ'},
#                                'expansion': 'لَاتْڤِيّ • (lātviyy) m, plural '
#                                             'لَاتْڤِيُّون (lātviyyūn), '
#                                             'feminine لَاتْڤِيَّة (lātviyya)',
#                                'name': 'ar-noun-nisba'}],
#            'inflection_templates': [{'args': {'1': 'لَاتْفِيّ',
#                                               'head2': 'لَاتْفِيّ',
#                                               'pl': 'sp',
#                                               'tr2': 'lātviyy'},
#                                      'name': 'ar-decl-gendered-noun'}],
#            'lang': 'Arabic',
#            'lang_code': 'ar',
#            'pos': 'noun',
#            'senses': [{'glosses': ['Latvian man'],
#                        'head_nr': 2,
#                        'links': [['Latvian', 'Latvian'], ['man', 'man']]}],
#            'sounds': [{'ipa': '/laːt.fijj/'}, {'ipa': '/laːt.vijj/'}]}}

# %% [markdown]
# ## 4.2 View Random Dictionary

# %% [markdown]
# View dictionaries to check where to find the information

# %%
# show sample example
random_word = choice(list(wiki_idxs.keys()))
random_word_idxs = wiki_idxs[random_word]
print("word, idx:", random_word, random_word_idxs)
# Out:
# word, idx: تك [119615, 119616, 119617]

# %%
pprint(wikitionary[choice(random_word_idxs)])
# Out:
# {'تك': {'categories': ['Arabic form-I verbs',
#                        'Arabic geminate form-I verbs',
#                        'Arabic geminate verbs',
#                        'Arabic geminate verbs by conjugation',
#                        'Arabic lemmas',
#                        'Arabic non-lemma forms',
#                        'Arabic verb forms',
#                        'Arabic verbs',
#                        'Terms with redundant transliterations',
#                        'Terms with redundant transliterations/ar'],
#         'etymology_number': 1,
#         'etymology_templates': [{'args': {'1': 'ar'},
#                                  'expansion': 'Onomatopoeic',
#                                  'name': 'onomatopoeic'}],
#         'etymology_text': 'Onomatopoeic.',
#         'forms': [{'form': 'يَتُكُّ', 'roman': 'yatukku', 'tags': ['non-past']},
#                   {'form': 'تَكَّ', 'tags': ['canonical']},
#                   {'form': 'takka', 'tags': ['romanization']},
#                   {'form': '', 'source': 'conjugation', 'tags': ['table-tags']},
#                   {'form': 'ar-conj',
#                    'source': 'conjugation',
#                    'tags': ['inflection-template']},
#                   {'form': 'تَكّ',
#                    'roman': 'takk',
#                    'source': 'conjugation',
#                    'tags': ['noun-from-verb']},
#                   {'form': 'تَاكّ',
#                    'roman': 'tākk',
#                    'source': 'conjugation',
#                    'tags': ['active', 'participle']},
#                   {'form': 'تَكَكْتُ',
#                    'roman': 'takaktu',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'indicative',
#                             'masculine',
#                             'past',
#                             'perfective',
#                             'singular']},
#                   {'form': 'تَكَكْتَ',
#                    'roman': 'takakta',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'indicative',
#                             'masculine',
#                             'past',
#                             'perfective',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تَكَّ',
#                    'roman': 'takka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'indicative',
#                             'masculine',
#                             'past',
#                             'perfective',
#                             'singular',
#                             'third-person']},
#                   {'form': 'تَكَكْتُمَا',
#                    'roman': 'takaktumā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'indicative',
#                             'masculine',
#                             'past',
#                             'perfective',
#                             'second-person']},
#                   {'form': 'تَكَّا',
#                    'roman': 'takkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'indicative',
#                             'masculine',
#                             'past',
#                             'perfective',
#                             'third-person']},
#                   {'form': 'تَكَكْنَا',
#                    'roman': 'takaknā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'indicative',
#                             'masculine',
#                             'past',
#                             'perfective',
#                             'plural']},
#                   {'form': 'تَكَكْتُمْ',
#                    'roman': 'takaktum',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'indicative',
#                             'masculine',
#                             'past',
#                             'perfective',
#                             'plural',
#                             'second-person']},
#                   {'form': 'تَكُّوا',
#                    'roman': 'takkū',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'indicative',
#                             'masculine',
#                             'past',
#                             'perfective',
#                             'plural',
#                             'third-person']},
#                   {'form': 'تَكَكْتُ',
#                    'roman': 'takaktu',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'indicative',
#                             'past',
#                             'perfective',
#                             'singular']},
#                   {'form': 'تَكَكْتِ',
#                    'roman': 'takakti',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'indicative',
#                             'past',
#                             'perfective',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تَكَّتْ',
#                    'roman': 'takkat',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'indicative',
#                             'past',
#                             'perfective',
#                             'singular',
#                             'third-person']},
#                   {'form': 'تَكَكْتُمَا',
#                    'roman': 'takaktumā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'indicative',
#                             'past',
#                             'perfective',
#                             'second-person']},
#                   {'form': 'تَكَّتَا',
#                    'roman': 'takkatā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'indicative',
#                             'past',
#                             'perfective',
#                             'third-person']},
#                   {'form': 'تَكَكْنَا',
#                    'roman': 'takaknā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'indicative',
#                             'past',
#                             'perfective',
#                             'plural']},
#                   {'form': 'تَكَكْتُنَّ',
#                    'roman': 'takaktunna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'indicative',
#                             'past',
#                             'perfective',
#                             'plural',
#                             'second-person']},
#                   {'form': 'تَكَكْنَ',
#                    'roman': 'takakna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'indicative',
#                             'past',
#                             'perfective',
#                             'plural',
#                             'third-person']},
#                   {'form': 'أَتُكُّ',
#                    'roman': 'ʔatukku',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'imperfective',
#                             'indicative',
#                             'masculine',
#                             'non-past',
#                             'singular']},
#                   {'form': 'تَتُكُّ',
#                    'roman': 'tatukku',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'imperfective',
#                             'indicative',
#                             'masculine',
#                             'non-past',
#                             'second-person',
#                             'singular']},
#                   {'form': 'يَتُكُّ',
#                    'roman': 'yatukku',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'imperfective',
#                             'indicative',
#                             'masculine',
#                             'non-past',
#                             'singular',
#                             'third-person']},
#                   {'form': 'تَتُكَّانِ',
#                    'roman': 'tatukkāni',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'imperfective',
#                             'indicative',
#                             'masculine',
#                             'non-past',
#                             'second-person']},
#                   {'form': 'يَتُكَّانِ',
#                    'roman': 'yatukkāni',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'imperfective',
#                             'indicative',
#                             'masculine',
#                             'non-past',
#                             'third-person']},
#                   {'form': 'نَتُكُّ',
#                    'roman': 'natukku',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'imperfective',
#                             'indicative',
#                             'masculine',
#                             'non-past',
#                             'plural']},
#                   {'form': 'تَتُكُّونَ',
#                    'roman': 'tatukkūna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'imperfective',
#                             'indicative',
#                             'masculine',
#                             'non-past',
#                             'plural',
#                             'second-person']},
#                   {'form': 'يَتُكُّونَ',
#                    'roman': 'yatukkūna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'imperfective',
#                             'indicative',
#                             'masculine',
#                             'non-past',
#                             'plural',
#                             'third-person']},
#                   {'form': 'أَتُكُّ',
#                    'roman': 'ʔatukku',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'imperfective',
#                             'indicative',
#                             'non-past',
#                             'singular']},
#                   {'form': 'تَتُكِّينَ',
#                    'roman': 'tatukkīna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'imperfective',
#                             'indicative',
#                             'non-past',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تَتُكُّ',
#                    'roman': 'tatukku',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'imperfective',
#                             'indicative',
#                             'non-past',
#                             'singular',
#                             'third-person']},
#                   {'form': 'تَتُكَّانِ',
#                    'roman': 'tatukkāni',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'imperfective',
#                             'indicative',
#                             'non-past',
#                             'second-person']},
#                   {'form': 'تَتُكَّانِ',
#                    'roman': 'tatukkāni',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'imperfective',
#                             'indicative',
#                             'non-past',
#                             'third-person']},
#                   {'form': 'نَتُكُّ',
#                    'roman': 'natukku',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'imperfective',
#                             'indicative',
#                             'non-past',
#                             'plural']},
#                   {'form': 'تَتْكُكْنَ',
#                    'roman': 'tatkukna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'imperfective',
#                             'indicative',
#                             'non-past',
#                             'plural',
#                             'second-person']},
#                   {'form': 'يَتْكُكْنَ',
#                    'roman': 'yatkukna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'imperfective',
#                             'indicative',
#                             'non-past',
#                             'plural',
#                             'third-person']},
#                   {'form': 'أَتُكَّ',
#                    'roman': 'ʔatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'masculine',
#                             'singular',
#                             'subjunctive']},
#                   {'form': 'تَتُكَّ',
#                    'roman': 'tatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'masculine',
#                             'second-person',
#                             'singular',
#                             'subjunctive']},
#                   {'form': 'يَتُكَّ',
#                    'roman': 'yatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'masculine',
#                             'singular',
#                             'subjunctive',
#                             'third-person']},
#                   {'form': 'تَتُكَّا',
#                    'roman': 'tatukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'masculine',
#                             'second-person',
#                             'subjunctive']},
#                   {'form': 'يَتُكَّا',
#                    'roman': 'yatukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'masculine',
#                             'subjunctive',
#                             'third-person']},
#                   {'form': 'نَتُكَّ',
#                    'roman': 'natukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'masculine',
#                             'plural',
#                             'subjunctive']},
#                   {'form': 'تَتُكُّوا',
#                    'roman': 'tatukkū',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'masculine',
#                             'plural',
#                             'second-person',
#                             'subjunctive']},
#                   {'form': 'يَتُكُّوا',
#                    'roman': 'yatukkū',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'masculine',
#                             'plural',
#                             'subjunctive',
#                             'third-person']},
#                   {'form': 'أَتُكَّ',
#                    'roman': 'ʔatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'singular',
#                             'subjunctive']},
#                   {'form': 'تَتُكِّي',
#                    'roman': 'tatukkī',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'second-person',
#                             'singular',
#                             'subjunctive']},
#                   {'form': 'تَتُكَّ',
#                    'roman': 'tatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'singular',
#                             'subjunctive',
#                             'third-person']},
#                   {'form': 'تَتُكَّا',
#                    'roman': 'tatukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'second-person',
#                             'subjunctive']},
#                   {'form': 'تَتُكَّا',
#                    'roman': 'tatukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'subjunctive',
#                             'third-person']},
#                   {'form': 'نَتُكَّ',
#                    'roman': 'natukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'plural',
#                             'subjunctive']},
#                   {'form': 'تَتْكُكْنَ',
#                    'roman': 'tatkukna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'plural',
#                             'second-person',
#                             'subjunctive']},
#                   {'form': 'يَتْكُكْنَ',
#                    'roman': 'yatkukna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'plural',
#                             'subjunctive',
#                             'third-person']},
#                   {'form': 'أَتُكَّ',
#                    'roman': 'ʔatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'jussive',
#                             'masculine',
#                             'singular']},
#                   {'form': 'أَتُكِّ',
#                    'roman': 'ʔatukki',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'jussive',
#                             'masculine',
#                             'singular']},
#                   {'form': 'أَتْكُكْ',
#                    'roman': 'ʔatkuk',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'jussive',
#                             'masculine',
#                             'singular']},
#                   {'form': 'تَتُكَّ',
#                    'roman': 'tatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'jussive',
#                             'masculine',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تَتُكِّ',
#                    'roman': 'tatukki',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'jussive',
#                             'masculine',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تَتْكُكْ',
#                    'roman': 'tatkuk',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'jussive',
#                             'masculine',
#                             'second-person',
#                             'singular']},
#                   {'form': 'يَتُكَّ',
#                    'roman': 'yatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'jussive',
#                             'masculine',
#                             'singular',
#                             'third-person']},
#                   {'form': 'يَتُكِّ',
#                    'roman': 'yatukki',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'jussive',
#                             'masculine',
#                             'singular',
#                             'third-person']},
#                   {'form': 'يَتْكُكْ',
#                    'roman': 'yatkuk',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'jussive',
#                             'masculine',
#                             'singular',
#                             'third-person']},
#                   {'form': 'تَتُكَّا',
#                    'roman': 'tatukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'jussive',
#                             'masculine',
#                             'second-person']},
#                   {'form': 'يَتُكَّا',
#                    'roman': 'yatukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'jussive',
#                             'masculine',
#                             'third-person']},
#                   {'form': 'نَتُكَّ',
#                    'roman': 'natukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'jussive',
#                             'masculine',
#                             'plural']},
#                   {'form': 'نَتُكِّ',
#                    'roman': 'natukki',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'jussive',
#                             'masculine',
#                             'plural']},
#                   {'form': 'نَتْكُكْ',
#                    'roman': 'natkuk',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'first-person',
#                             'jussive',
#                             'masculine',
#                             'plural']},
#                   {'form': 'تَتُكُّوا',
#                    'roman': 'tatukkū',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'jussive',
#                             'masculine',
#                             'plural',
#                             'second-person']},
#                   {'form': 'يَتُكُّوا',
#                    'roman': 'yatukkū',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'jussive',
#                             'masculine',
#                             'plural',
#                             'third-person']},
#                   {'form': 'أَتُكَّ',
#                    'roman': 'ʔatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'jussive',
#                             'singular']},
#                   {'form': 'أَتُكِّ',
#                    'roman': 'ʔatukki',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'jussive',
#                             'singular']},
#                   {'form': 'أَتْكُكْ',
#                    'roman': 'ʔatkuk',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'jussive',
#                             'singular']},
#                   {'form': 'تَتُكِّي',
#                    'roman': 'tatukkī',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'jussive',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تَتُكَّ',
#                    'roman': 'tatukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'jussive',
#                             'singular',
#                             'third-person']},
#                   {'form': 'تَتُكِّ',
#                    'roman': 'tatukki',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'jussive',
#                             'singular',
#                             'third-person']},
#                   {'form': 'تَتْكُكْ',
#                    'roman': 'tatkuk',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'jussive',
#                             'singular',
#                             'third-person']},
#                   {'form': 'تَتُكَّا',
#                    'roman': 'tatukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'jussive',
#                             'second-person']},
#                   {'form': 'تَتُكَّا',
#                    'roman': 'tatukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'jussive',
#                             'third-person']},
#                   {'form': 'نَتُكَّ',
#                    'roman': 'natukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'jussive',
#                             'plural']},
#                   {'form': 'نَتُكِّ',
#                    'roman': 'natukki',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'jussive',
#                             'plural']},
#                   {'form': 'نَتْكُكْ',
#                    'roman': 'natkuk',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'first-person',
#                             'jussive',
#                             'plural']},
#                   {'form': 'تَتْكُكْنَ',
#                    'roman': 'tatkukna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'jussive',
#                             'plural',
#                             'second-person']},
#                   {'form': 'يَتْكُكْنَ',
#                    'roman': 'yatkukna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'jussive',
#                             'plural',
#                             'third-person']},
#                   {'form': 'تُكَّ',
#                    'roman': 'tukka',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'imperative',
#                             'masculine',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تُكِّ',
#                    'roman': 'tukki',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'imperative',
#                             'masculine',
#                             'second-person',
#                             'singular']},
#                   {'form': 'اُتْكُكْ',
#                    'roman': 'utkuk',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'imperative',
#                             'masculine',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تُكَّا',
#                    'roman': 'tukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'imperative',
#                             'masculine',
#                             'second-person']},
#                   {'form': 'تُكُّوا',
#                    'roman': 'tukkū',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'imperative',
#                             'masculine',
#                             'plural',
#                             'second-person']},
#                   {'form': 'تُكِّي',
#                    'roman': 'tukkī',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'imperative',
#                             'second-person',
#                             'singular']},
#                   {'form': 'تُكَّا',
#                    'roman': 'tukkā',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'dual',
#                             'feminine',
#                             'imperative',
#                             'second-person']},
#                   {'form': 'اُتْكُكْنَ',
#                    'roman': 'utkukna',
#                    'source': 'conjugation',
#                    'tags': ['active',
#                             'feminine',
#                             'imperative',
#                             'plural',
#                             'second-person']}],
#         'head_templates': [{'args': {'1': 'I', '2': 'a', '3': 'u'},
#                             'expansion': 'تَكَّ • (takka) I, non-past يَتُكُّ '
#                                          '(yatukku)',
#                             'name': 'ar-verb'}],
#         'inflection_templates': [{'args': {'1': 'I',
#                                            '2': 'a',
#                                            '3': 'u',
#                                            'passive': 'no',
#                                            'vn': 'تَكّ'},
#                                   'name': 'ar-conj'}],
#         'lang': 'Arabic',
#         'lang_code': 'ar',
#         'pos': 'verb',
#         'senses': [{'glosses': ['to tick'], 'links': [['tick', 'tick']]}]}}

# %% [markdown]
# # 5.0 Check Values in Wikitionaries

# %% [markdown]
# ## 5.1 Check Values in Categories

# %% [markdown]
# - List `categories` values in:
#   - `WIKITIONARY_DICT["categories"]: List[str]`
#   - `Senses[i]["categories"]` where `senses` is `WIKITIONARY_DICT["senses"]: List[Dict[str: List[str]]]`

# %%
categories_values = set()
for entry in wikitionary:
    for _, word_data in entry.items():
        values = word_data.get("categories", [])
        for value in values:
            categories_values.update(values)
        for sense in word_data.get("senses", []):
            if categories_senses := sense.get("categories", []):
                categories_values.update(categories_senses)

pprint(sorted(list(categories_values)))
# Out:
# ['Algerian Arabic',
#  'Algerian Arabic terms with IPA pronunciation',
#  'Andalusian Arabic',
#  'Andalusian Arabic terms with IPA pronunciation',
#  'Arabic 1-syllable words',
#  'Arabic 2-syllable words',
#  'Arabic 3-syllable words',
#  'Arabic 4-syllable words',
#  'Arabic 5-syllable words',
#  'Arabic 6-syllable words',
#  'Arabic abbreviations',
#  'Arabic acronyms',
#  'Arabic act-related adverbs',
#  'Arabic active participles',
#  'Arabic adjective feminine forms',
#  'Arabic adjective forms',
#  'Arabic adjective plural forms',
#  'Arabic adjectives',
#  'Arabic adverbial accusatives',
#  'Arabic adverbs',
#  'Arabic archaic forms',
#  'Arabic archaic terms',
#  'Arabic articles',
#  'Arabic assimilated form-I verbs',
#  'Arabic assimilated form-II verbs',
#  'Arabic assimilated form-III verbs',
#  'Arabic assimilated form-IV verbs',
#  'Arabic assimilated form-Iq verbs',
#  'Arabic assimilated form-V verbs',
#  'Arabic assimilated form-VI verbs',
#  'Arabic assimilated form-VIII verbs',
#  'Arabic assimilated form-X verbs',
#  'Arabic assimilated verbs',
#  'Arabic assimilated verbs by conjugation',
#  'Arabic assimilated+final-weak verbs by conjugation',
#  'Arabic augmented verbs with parameter override',
#  'Arabic autological terms',
#  'Arabic auxiliary verbs',
#  'Arabic back-formations',
#  'Arabic cardinal numbers',
#  'Arabic causative verbs',
#  'Arabic characteristic adjectives',
#  'Arabic childish terms',
#  'Arabic clippings',
#  'Arabic collective nouns',
#  'Arabic colloquialisms',
#  'Arabic compound terms',
#  'Arabic conjunctions',
#  'Arabic contractions',
#  'Arabic contranyms',
#  'Arabic coordinated pairs',
#  'Arabic coordinated triples',
#  'Arabic copulative verbs',
#  'Arabic countable nouns',
#  'Arabic dated forms',
#  'Arabic dated terms',
#  'Arabic defective adjectives',
#  'Arabic defective verbs',
#  'Arabic definite nouns',
#  'Arabic demonstrative adverbs',
#  'Arabic derogatory terms',
#  'Arabic determiners',
#  'Arabic diacritical marks',
#  'Arabic dialectal terms',
#  'Arabic diminutive nouns',
#  'Arabic diminutives of female given names',
#  'Arabic ditransitive verbs',
#  'Arabic double plurals',
#  'Arabic dualia tantum',
#  'Arabic elative adjectives',
#  'Arabic ellipses',
#  'Arabic endearing terms',
#  'Arabic entries with language name categories using raw markup',
#  'Arabic entries with topic categories using raw markup',
#  'Arabic eponyms',
#  'Arabic ergative verbs',
#  'Arabic ethnic slurs',
#  'Arabic euphemisms',
#  'Arabic expressions',
#  'Arabic familiar terms',
#  'Arabic female equivalent nouns',
#  'Arabic female given names',
#  'Arabic female given names from Persian',
#  'Arabic feminine nouns',
#  'Arabic final-weak form-I verbs',
#  'Arabic final-weak form-II verbs',
#  'Arabic final-weak form-III verbs',
#  'Arabic final-weak form-IV verbs',
#  'Arabic final-weak form-V verbs',
#  'Arabic final-weak form-VI verbs',
#  'Arabic final-weak form-VII verbs',
#  'Arabic final-weak form-VIII verbs',
#  'Arabic final-weak form-X verbs',
#  'Arabic final-weak form-XII verbs',
#  'Arabic final-weak verbs',
#  'Arabic final-weak verbs by conjugation',
#  'Arabic focus adverbs',
#  'Arabic form-I verbs',
#  'Arabic form-I verbs with headword imperfect determined through param, not '
#  'non-past vowel',
#  'Arabic form-I verbs with headword perfect determined through param, not past '
#  'vowel',
#  'Arabic form-I verbs with missing non-past vowel in headword',
#  'Arabic form-I verbs with ء as first radical',
#  'Arabic form-I verbs with ء as second radical',
#  'Arabic form-I verbs with ء as third radical',
#  'Arabic form-I verbs with و as first radical',
#  'Arabic form-I verbs with و as second radical',
#  'Arabic form-I verbs with و as third radical',
#  'Arabic form-I verbs with ي as first radical',
#  'Arabic form-I verbs with ي as second radical',
#  'Arabic form-I verbs with ي as third radical',
#  'Arabic form-II verbs',
#  'Arabic form-II verbs with ء as first radical',
#  'Arabic form-II verbs with ء as second radical',
#  'Arabic form-II verbs with ء as third radical',
#  'Arabic form-II verbs with و as first radical',
#  'Arabic form-II verbs with و as second radical',
#  'Arabic form-II verbs with و as third radical',
#  'Arabic form-II verbs with ي as first radical',
#  'Arabic form-II verbs with ي as second radical',
#  'Arabic form-II verbs with ي as third radical',
#  'Arabic form-III verbs',
#  'Arabic form-III verbs with ء as first radical',
#  'Arabic form-III verbs with ء as second radical',
#  'Arabic form-III verbs with ء as third radical',
#  'Arabic form-III verbs with و as first radical',
#  'Arabic form-III verbs with و as second radical',
#  'Arabic form-III verbs with و as third radical',
#  'Arabic form-III verbs with ي as second radical',
#  'Arabic form-III verbs with ي as third radical',
#  'Arabic form-IIIq verbs',
#  'Arabic form-IIq verbs',
#  'Arabic form-IIq verbs with ء as first radical',
#  'Arabic form-IIq verbs with و as second radical',
#  'Arabic form-IIq verbs with و as third radical',
#  'Arabic form-IIq verbs with ي as second radical',
#  'Arabic form-IIq verbs with ي as third radical',
#  'Arabic form-IV verbs',
#  'Arabic form-IV verbs with ء as first radical',
#  'Arabic form-IV verbs with ء as second radical',
#  'Arabic form-IV verbs with ء as third radical',
#  'Arabic form-IV verbs with و as first radical',
#  'Arabic form-IV verbs with و as second radical',
#  'Arabic form-IV verbs with و as third radical',
#  'Arabic form-IV verbs with ي as first radical',
#  'Arabic form-IV verbs with ي as second radical',
#  'Arabic form-IV verbs with ي as third radical',
#  'Arabic form-IVq verbs',
#  'Arabic form-IVq verbs with ء as third radical',
#  'Arabic form-IX verbs',
#  'Arabic form-IX verbs with و as second radical',
#  'Arabic form-IX verbs with ي as second radical',
#  'Arabic form-Iq verbs',
#  'Arabic form-Iq verbs with ء as first radical',
#  'Arabic form-Iq verbs with ء as fourth radical',
#  'Arabic form-Iq verbs with ء as second radical',
#  'Arabic form-Iq verbs with ء as third radical',
#  'Arabic form-Iq verbs with و as first radical',
#  'Arabic form-Iq verbs with و as second radical',
#  'Arabic form-Iq verbs with و as third radical',
#  'Arabic form-Iq verbs with ي as second radical',
#  'Arabic form-Iq verbs with ي as third radical',
#  'Arabic form-V verbs',
#  'Arabic form-V verbs with ء as first radical',
#  'Arabic form-V verbs with ء as second radical',
#  'Arabic form-V verbs with ء as third radical',
#  'Arabic form-V verbs with و as first radical',
#  'Arabic form-V verbs with و as second radical',
#  'Arabic form-V verbs with و as third radical',
#  'Arabic form-V verbs with ي as first radical',
#  'Arabic form-V verbs with ي as second radical',
#  'Arabic form-V verbs with ي as third radical',
#  'Arabic form-VI verbs',
#  'Arabic form-VI verbs with ء as first radical',
#  'Arabic form-VI verbs with ء as second radical',
#  'Arabic form-VI verbs with ء as third radical',
#  'Arabic form-VI verbs with و as first radical',
#  'Arabic form-VI verbs with و as second radical',
#  'Arabic form-VI verbs with و as third radical',
#  'Arabic form-VI verbs with ي as second radical',
#  'Arabic form-VI verbs with ي as third radical',
#  'Arabic form-VII verbs',
#  'Arabic form-VII verbs with ء as third radical',
#  'Arabic form-VII verbs with و as second radical',
#  'Arabic form-VII verbs with و as third radical',
#  'Arabic form-VII verbs with ي as second radical',
#  'Arabic form-VII verbs with ي as third radical',
#  'Arabic form-VIII verbs',
#  'Arabic form-VIII verbs with ء as first radical',
#  'Arabic form-VIII verbs with ء as second radical',
#  'Arabic form-VIII verbs with ء as third radical',
#  'Arabic form-VIII verbs with و as first radical',
#  'Arabic form-VIII verbs with و as second radical',
#  'Arabic form-VIII verbs with و as third radical',
#  'Arabic form-VIII verbs with ي as second radical',
#  'Arabic form-VIII verbs with ي as third radical',
#  'Arabic form-X verbs',
#  'Arabic form-X verbs with ء as first radical',
#  'Arabic form-X verbs with ء as third radical',
#  'Arabic form-X verbs with و as first radical',
#  'Arabic form-X verbs with و as second radical',
#  'Arabic form-X verbs with و as third radical',
#  'Arabic form-X verbs with ي as first radical',
#  'Arabic form-X verbs with ي as second radical',
#  'Arabic form-X verbs with ي as third radical',
#  'Arabic form-XI verbs',
#  'Arabic form-XII verbs',
#  'Arabic form-XII verbs with ي as third radical',
#  'Arabic form-XIII verbs',
#  'Arabic formal terms',
#  'Arabic frequency adverbs',
#  'Arabic frequentative verbs',
#  'Arabic geminate form-I verbs',
#  'Arabic geminate form-II verbs',
#  'Arabic geminate form-III verbs',
#  'Arabic geminate form-IV verbs',
#  'Arabic geminate form-V verbs',
#  'Arabic geminate form-VI verbs',
#  'Arabic geminate form-VII verbs',
#  'Arabic geminate form-VIII verbs',
#  'Arabic geminate form-X verbs',
#  'Arabic geminate verbs',
#  'Arabic geminate verbs by conjugation',
#  'Arabic ghost words',
#  'Arabic given names',
#  'Arabic hamzated form-I verbs',
#  'Arabic hamzated form-II verbs',
#  'Arabic hamzated form-III verbs',
#  'Arabic hamzated form-IIq verbs',
#  'Arabic hamzated form-IV verbs',
#  'Arabic hamzated form-IVq verbs',
#  'Arabic hamzated form-Iq verbs',
#  'Arabic hamzated form-V verbs',
#  'Arabic hamzated form-VI verbs',
#  'Arabic hamzated form-VII verbs',
#  'Arabic hamzated form-VIII verbs',
#  'Arabic hamzated form-X verbs',
#  'Arabic hamzated verbs',
#  'Arabic hapax legomena',
#  'Arabic higher register terms',
#  'Arabic historical terms',
#  'Arabic hollow form-I verbs',
#  'Arabic hollow form-II verbs',
#  'Arabic hollow form-III verbs',
#  'Arabic hollow form-IV verbs',
#  'Arabic hollow form-IX verbs',
#  'Arabic hollow form-V verbs',
#  'Arabic hollow form-VI verbs',
#  'Arabic hollow form-VII verbs',
#  'Arabic hollow form-VIII verbs',
#  'Arabic hollow form-X verbs',
#  'Arabic hollow verbs',
#  'Arabic hollow verbs by conjugation',
#  'Arabic humorous terms',
#  'Arabic hyperboles',
#  'Arabic idioms',
#  'Arabic impersonal verbs',
#  'Arabic indeclinable adjectives',
#  'Arabic informal forms',
#  'Arabic informal terms',
#  'Arabic initialisms',
#  'Arabic instance nouns',
#  'Arabic interfixes',
#  'Arabic interjections',
#  'Arabic internet slang',
#  'Arabic interrogative adverbs',
#  'Arabic interrogative particles',
#  'Arabic interrogative pronouns',
#  'Arabic intransitive verbs',
#  'Arabic irregular adjectives',
#  'Arabic irregular elative adjectives',
#  'Arabic irregular nouns',
#  'Arabic irregular verbs',
#  'Arabic jussive particles',
#  'Arabic lemmas',
#  'Arabic letters',
#  'Arabic literary terms',
#  'Arabic location adverbs',
#  'Arabic male given names',
#  'Arabic male given names from Ancient Greek',
#  'Arabic male given names from Aramaic',
#  'Arabic male given names from Coptic',
#  'Arabic male given names from English',
#  'Arabic male given names from Hebrew',
#  'Arabic male given names from Old English',
#  'Arabic male given names from Russian',
#  'Arabic masculine and feminine nouns by sense',
#  'Arabic masculine nouns',
#  'Arabic masculine suffixes',
#  'Arabic matched pairs',
#  'Arabic metonyms',
#  'Arabic misconstructions',
#  'Arabic misspellings',
#  'Arabic mnemonics',
#  'Arabic multiword terms',
#  'Arabic names',
#  'Arabic negative polarity items',
#  'Arabic negatives',
#  'Arabic neologisms',
#  'Arabic non-constituents',
#  'Arabic non-lemma forms',
#  'Arabic nonce terms',
#  'Arabic nonpersonal nouns',
#  'Arabic nonstandard forms',
#  'Arabic nonstandard terms',
#  'Arabic noun dual forms',
#  'Arabic noun forms',
#  'Arabic noun plural forms',
#  'Arabic nouns',
#  'Arabic nouns of place',
#  'Arabic nouns of time',
#  'Arabic nouns with irregular dual',
#  'Arabic nouns with long construct singular',
#  'Arabic nouns with multiple genders',
#  'Arabic numeral forms',
#  'Arabic numeral symbols',
#  'Arabic numerals',
#  'Arabic oaths',
#  'Arabic obsolete forms',
#  'Arabic obsolete terms',
#  'Arabic occupational nouns',
#  'Arabic offensive terms',
#  'Arabic onomatopoeias',
#  'Arabic ordinal numbers',
#  'Arabic oxymorons',
#  'Arabic palindromes',
#  'Arabic participles',
#  'Arabic particles',
#  'Arabic passive participles',
#  'Arabic personal nouns',
#  'Arabic phrasal verbs',
#  'Arabic phrasebook',
#  'Arabic phrases',
#  'Arabic placeholder terms',
#  'Arabic pluralia tantum',
#  'Arabic poetic terms',
#  'Arabic prefixes',
#  'Arabic preposition forms',
#  'Arabic prepositional phrases',
#  'Arabic prepositions',
#  'Arabic pronoun forms',
#  'Arabic pronouns',
#  'Arabic pronouns with prepositions',
#  'Arabic proper noun forms',
#  'Arabic proper nouns',
#  'Arabic proscribed terms',
#  'Arabic proverbs',
#  'Arabic punctuation marks',
#  'Arabic puristic terms',
#  'Arabic quotations with omitted translation',
#  'Arabic rare forms',
#  'Arabic rare terms',
#  'Arabic reciprocal verbs',
#  'Arabic reduplications',
#  'Arabic reflexive pronouns',
#  'Arabic reflexive verbs',
#  'Arabic relational adjectives',
#  'Arabic relative adverbs',
#  'Arabic relative nouns (nisba)',
#  'Arabic relative pronouns',
#  'Arabic religious slurs',
#  'Arabic reporting verbs',
#  'Arabic requests for English equivalent term',
#  'Arabic retronyms',
#  'Arabic rhyming phrases',
#  'Arabic roots',
#  'Arabic sarcastic terms',
#  'Arabic semantic loans from Spanish',
#  'Arabic short forms',
#  'Arabic similes',
#  'Arabic singularia tantum',
#  'Arabic singulative nouns',
#  'Arabic slang',
#  'Arabic sound form-I verbs',
#  'Arabic sound form-II verbs',
#  'Arabic sound form-III verbs',
#  'Arabic sound form-IIIq verbs',
#  'Arabic sound form-IIq verbs',
#  'Arabic sound form-IV verbs',
#  'Arabic sound form-IVq verbs',
#  'Arabic sound form-IX verbs',
#  'Arabic sound form-Iq verbs',
#  'Arabic sound form-V verbs',
#  'Arabic sound form-VI verbs',
#  'Arabic sound form-VII verbs',
#  'Arabic sound form-VIII verbs',
#  'Arabic sound form-X verbs',
#  'Arabic sound form-XI verbs',
#  'Arabic sound form-XII verbs',
#  'Arabic sound form-XIII verbs',
#  'Arabic sound verbs',
#  'Arabic sound verbs by conjugation',
#  'Arabic spellings with ا instead of أ',
#  'Arabic spellings with ا instead of إ',
#  'Arabic spellings with ا instead of ى',
#  'Arabic stative verbs',
#  'Arabic subjunctive particles',
#  'Arabic suffixes',
#  'Arabic suppletive nouns',
#  'Arabic surnames',
#  'Arabic surnames from Armenian',
#  'Arabic surnames from occupations',
#  'Arabic symbols',
#  'Arabic taxonomic eponyms',
#  'Arabic terms belonging to the root ء ث ث',
#  'Arabic terms belonging to the root ء ج ر',
#  'Arabic terms belonging to the root ء ح د',
#  'Arabic terms belonging to the root ء خ و',
#  'Arabic terms belonging to the root ء ذ ن',
#  'Arabic terms belonging to the root ء ز ل',
#  'Arabic terms belonging to the root ء ك ل',
#  'Arabic terms belonging to the root ء ل و',
#  'Arabic terms belonging to the root ء م م',
#  'Arabic terms belonging to the root ء ن ث',
#  'Arabic terms belonging to the root ء ن س',
#  'Arabic terms belonging to the root ب د ر',
#  'Arabic terms belonging to the root ب ر ح',
#  'Arabic terms belonging to the root ب ر ر',
#  'Arabic terms belonging to the root ب ر ي',
#  'Arabic terms belonging to the root ب س ط',
#  'Arabic terms belonging to the root ب ط ل',
#  'Arabic terms belonging to the root ب غ ض',
#  'Arabic terms belonging to the root ب ق ع',
#  'Arabic terms belonging to the root ب ك ي',
#  'Arabic terms belonging to the root ب ن ي',
#  'Arabic terms belonging to the root ب ي ض',
#  'Arabic terms belonging to the root ب ي ع',
#  'Arabic terms belonging to the root ب ي ن',
#  'Arabic terms belonging to the root ت س ع',
#  'Arabic terms belonging to the root ت ف ه',
#  'Arabic terms belonging to the root ت و ب',
#  'Arabic terms belonging to the root ث ر ب',
#  'Arabic terms belonging to the root ث ل ث',
#  'Arabic terms belonging to the root ث م ن',
#  'Arabic terms belonging to the root ث ن ي',
#  'Arabic terms belonging to the root ج ر ر',
#  'Arabic terms belonging to the root ج ر م',
#  'Arabic terms belonging to the root ج ز ر',
#  'Arabic terms belonging to the root ج ل د',
#  'Arabic terms belonging to the root ج ل س',
#  'Arabic terms belonging to the root ج م ع',
#  'Arabic terms belonging to the root ح ب و',
#  'Arabic terms belonging to the root ح ج ج',
#  'Arabic terms belonging to the root ح ر ب',
#  'Arabic terms belonging to the root ح ر ر',
#  'Arabic terms belonging to the root ح ر س',
#  'Arabic terms belonging to the root ح ر ف',
#  'Arabic terms belonging to the root ح ر ق',
#  'Arabic terms belonging to the root ح س ب',
#  'Arabic terms belonging to the root ح س ن',
#  'Arabic terms belonging to the root ح ص ن',
#  'Arabic terms belonging to the root ح ف ر',
#  'Arabic terms belonging to the root ح ف ظ',
#  'Arabic terms belonging to the root ح ق ق',
#  'Arabic terms belonging to the root ح ك ك',
#  'Arabic terms belonging to the root ح ل م',
#  'Arabic terms belonging to the root ح ل و',
#  'Arabic terms belonging to the root ح م د',
#  'Arabic terms belonging to the root ح م ر',
#  'Arabic terms belonging to the root ح و ل',
#  'Arabic terms belonging to the root ح ي د',
#  'Arabic terms belonging to the root ح ي ن',
#  'Arabic terms belonging to the root ح ي و',
#  'Arabic terms belonging to the root خ ب ز',
#  'Arabic terms belonging to the root خ ط ط',
#  'Arabic terms belonging to the root خ ل ل',
#  'Arabic terms belonging to the root خ م س',
#  'Arabic terms belonging to the root خ ي ر',
#  'Arabic terms belonging to the root خ ي ل',
#  'Arabic terms belonging to the root د ر ب',
#  'Arabic terms belonging to the root د و ل',
#  'Arabic terms belonging to the root د ي ن',
#  'Arabic terms belonging to the root ذ ك ر',
#  'Arabic terms belonging to the root ذ و ب',
#  'Arabic terms belonging to the root ر ء س',
#  'Arabic terms belonging to the root ر ء ي',
#  'Arabic terms belonging to the root ر ب ع',
#  'Arabic terms belonging to the root ر ح م',
#  'Arabic terms belonging to the root ر ض و',
#  'Arabic terms belonging to the root ر ع ب',
#  'Arabic terms belonging to the root ر ق د',
#  'Arabic terms belonging to the root ر ق ق',
#  'Arabic terms belonging to the root ر ك ب',
#  'Arabic terms belonging to the root ر ك ع',
#  'Arabic terms belonging to the root ر م ي',
#  'Arabic terms belonging to the root ر و د',
#  'Arabic terms belonging to the root ر ي ث',
#  'Arabic terms belonging to the root ز ر ق',
#  'Arabic terms belonging to the root ز ن ي',
#  'Arabic terms belonging to the root ز و ج',
#  'Arabic terms belonging to the root ز ي ن',
#  'Arabic terms belonging to the root س ء ل',
#  'Arabic terms belonging to the root س ب ب',
#  'Arabic terms belonging to the root س ب ع',
#  'Arabic terms belonging to the root س ب ق',
#  'Arabic terms belonging to the root س ج د',
#  'Arabic terms belonging to the root س د س',
#  'Arabic terms belonging to the root س ر ق',
#  'Arabic terms belonging to the root س ع د',
#  'Arabic terms belonging to the root س ف ك',
#  'Arabic terms belonging to the root س ل م',
#  'Arabic terms belonging to the root س م ع',
#  'Arabic terms belonging to the root س ن ه',
#  'Arabic terms belonging to the root س ه ر',
#  'Arabic terms belonging to the root س و ء',
#  'Arabic terms belonging to the root س و د',
#  'Arabic terms belonging to the root س و ي',
#  'Arabic terms belonging to the root س ي ب',
#  'Arabic terms belonging to the root ش ب ه',
#  'Arabic terms belonging to the root ش د د',
#  'Arabic terms belonging to the root ش ر ب',
#  'Arabic terms belonging to the root ش ر ر',
#  'Arabic terms belonging to the root ش ر ي',
#  'Arabic terms belonging to the root ش ع ر',
#  'Arabic terms belonging to the root ش م ت',
#  'Arabic terms belonging to the root ش م ل',
#  'Arabic terms belonging to the root ش ه د',
#  'Arabic terms belonging to the root ش ي خ',
#  'Arabic terms belonging to the root ص ء م',
#  'Arabic terms belonging to the root ص ح ب',
#  'Arabic terms belonging to the root ص ح ح',
#  'Arabic terms belonging to the root ص د ق',
#  'Arabic terms belonging to the root ص ل ب',
#  'Arabic terms belonging to the root ص و م',
#  'Arabic terms belonging to the root ص ي ر',
#  'Arabic terms belonging to the root ض ر ر',
#  'Arabic terms belonging to the root ض ع ف',
#  'Arabic terms belonging to the root ض ل ل',
#  'Arabic terms belonging to the root ض م د',
#  'Arabic terms belonging to the root ض ي ر',
#  'Arabic terms belonging to the root ض ي ق',
#  'Arabic terms belonging to the root ط ب خ',
#  'Arabic terms belonging to the root ط ب ق',
#  'Arabic terms belonging to the root ط ر د',
#  'Arabic terms belonging to the root ط ر ق',
#  'Arabic terms belonging to the root ط ع م',
#  'Arabic terms belonging to the root ط ه ر',
#  'Arabic terms belonging to the root ط و ع',
#  'Arabic terms belonging to the root ط و ل',
#  'Arabic terms belonging to the root ط ي ر',
#  'Arabic terms belonging to the root ظ م ء',
#  'Arabic terms belonging to the root ظ ه ر',
#  'Arabic terms belonging to the root ع ب ث',
#  'Arabic terms belonging to the root ع ب د',
#  'Arabic terms belonging to the root ع ب ر',
#  'Arabic terms belonging to the root ع ت ق',
#  'Arabic terms belonging to the root ع د د',
#  'Arabic terms belonging to the root ع د و',
#  'Arabic terms belonging to the root ع ر ق',
#  'Arabic terms belonging to the root ع ر ك',
#  'Arabic terms belonging to the root ع ش ر',
#  'Arabic terms belonging to the root ع ص ر',
#  'Arabic terms belonging to the root ع ص م',
#  'Arabic terms belonging to the root ع ص ي',
#  'Arabic terms belonging to the root ع ط ش',
#  'Arabic terms belonging to the root ع ط و',
#  'Arabic terms belonging to the root ع ف و',
#  'Arabic terms belonging to the root ع ق ب',
#  'Arabic terms belonging to the root ع ل ك',
#  'Arabic terms belonging to the root ع ل م',
#  'Arabic terms belonging to the root ع ل و',
#  'Arabic terms belonging to the root ع م ي',
#  'Arabic terms belonging to the root ع و د',
#  'Arabic terms belonging to the root ع و ذ',
#  'Arabic terms belonging to the root ع و ن',
#  'Arabic terms belonging to the root غ د ر',
#  'Arabic terms belonging to the root غ ر ق د',
#  'Arabic terms belonging to the root غ ص ب',
#  'Arabic terms belonging to the root غ ف ر',
#  'Arabic terms belonging to the root غ ل ظ',
#  'Arabic terms belonging to the root غ ل ق',
#  'Arabic terms belonging to the root غ م ض',
#  'Arabic terms belonging to the root غ ي ب',
#  'Arabic terms belonging to the root ف ء ل',
#  'Arabic terms belonging to the root ف ت ح',
#  'Arabic terms belonging to the root ف ج ر',
#  'Arabic terms belonging to the root ف ر ح',
#  'Arabic terms belonging to the root ف ر ق',
#  'Arabic terms belonging to the root ف س د',
#  'Arabic terms belonging to the root ق ب ل',
#  'Arabic terms belonging to the root ق ت ل',
#  'Arabic terms belonging to the root ق ذ ر',
#  'Arabic terms belonging to the root ق س ر',
#  'Arabic terms belonging to the root ق س م',
#  'Arabic terms belonging to the root ق ص ص',
#  'Arabic terms belonging to the root ق ص م',
#  'Arabic terms belonging to the root ق ط ع',
#  'Arabic terms belonging to the root ق ف ز',
#  'Arabic terms belonging to the root ق ف ل',
#  'Arabic terms belonging to the root ق ل ب',
#  'Arabic terms belonging to the root ق ل ل',
#  'Arabic terms belonging to the root ق م ر',
#  'Arabic terms belonging to the root ق و م',
#  'Arabic terms belonging to the root ق و و',
#  'Arabic terms belonging to the root ك ب ر',
#  'Arabic terms belonging to the root ك ت ل',
#  'Arabic terms belonging to the root ك ر ه',
#  'Arabic terms belonging to the root ك س ر',
#  'Arabic terms belonging to the root ك ش ف',
#  'Arabic terms belonging to the root ك ل م',
#  'Arabic terms belonging to the root ل ث م',
#  'Arabic terms belonging to the root ل ح ظ',
#  'Arabic terms belonging to the root ل ذ ذ',
#  'Arabic terms belonging to the root ل س ن',
#  'Arabic terms belonging to the root ل ط خ',
#  'Arabic terms belonging to the root ل ظ ي',
#  'Arabic terms belonging to the root ل و م',
#  'Arabic terms belonging to the root ل ي ل',
#  'Arabic terms belonging to the root ل ي ن',
#  'Arabic terms belonging to the root م ر ر',
#  'Arabic terms belonging to the root م ر ي',
#  'Arabic terms belonging to the root م ص ص',
#  'Arabic terms belonging to the root م ض ي',
#  'Arabic terms belonging to the root م ل ك',
#  'Arabic terms belonging to the root م و ت',
#  'Arabic terms belonging to the root م و ه',
#  'Arabic terms belonging to the root م ي ز',
#  'Arabic terms belonging to the root ن ث ر',
#  'Arabic terms belonging to the root ن ز ع',
#  'Arabic terms belonging to the root ن ز ل',
#  'Arabic terms belonging to the root ن ض د',
#  'Arabic terms belonging to the root ن ط ق',
#  'Arabic terms belonging to the root ن ظ ر',
#  'Arabic terms belonging to the root ن ف ق',
#  'Arabic terms belonging to the root ن ق ب',
#  'Arabic terms belonging to the root ن ق ل',
#  'Arabic terms belonging to the root ن ك ح',
#  'Arabic terms belonging to the root ن ك ه',
#  'Arabic terms belonging to the root ن ه ي',
#  'Arabic terms belonging to the root ن و ر',
#  'Arabic terms belonging to the root ن و م',
#  'Arabic terms belonging to the root ه د م',
#  'Arabic terms belonging to the root ه ل ل',
#  'Arabic terms belonging to the root و ج د',
#  'Arabic terms belonging to the root و ج ه',
#  'Arabic terms belonging to the root و ح د',
#  'Arabic terms belonging to the root و د د',
#  'Arabic terms belonging to the root و ز ر',
#  'Arabic terms belonging to the root و ش م',
#  'Arabic terms belonging to the root و ض ع',
#  'Arabic terms belonging to the root و ف ق',
#  'Arabic terms belonging to the root و ق ت',
#  'Arabic terms belonging to the root و ق ع',
#  'Arabic terms belonging to the root و ق ي',
#  'Arabic terms belonging to the root و ك ل',
#  'Arabic terms belonging to the root و ل ي',
#  'Arabic terms belonging to the root و ه ج',
#  'Arabic terms belonging to the root ي ء س',
#  'Arabic terms borrowed from Akkadian',
#  'Arabic terms borrowed from Coptic',
#  'Arabic terms borrowed from English',
#  'Arabic terms borrowed from Russian',
#  'Arabic terms derived from Coptic',
#  'Arabic terms derived from Egyptian',
#  'Arabic terms derived from English',
#  'Arabic terms derived from Persian',
#  'Arabic terms derived from Proto-Afroasiatic',
#  'Arabic terms derived from Proto-Celtic',
#  'Arabic terms derived from Proto-Semitic',
#  'Arabic terms derived from Russian',
#  'Arabic terms derived from Spanish',
#  'Arabic terms derived from active participles',
#  'Arabic terms derived from the Bible',
#  "Arabic terms derived from the Qur'an",
#  'Arabic terms interfixed with ان',
#  'Arabic terms suffixed with ية',
#  'Arabic terms with IPA pronunciation',
#  'Arabic terms with archaic senses',
#  'Arabic terms with audio links',
#  'Arabic terms with collocations',
#  'Arabic terms with historical senses',
#  'Arabic terms with homophones',
#  'Arabic terms with irregular pronunciations',
#  'Arabic terms with obsolete senses',
#  'Arabic terms with quotations',
#  'Arabic terms with rare senses',
#  'Arabic terms with redundant head parameter',
#  'Arabic terms with uncertain meaning',
#  'Arabic terms with uncommon senses',
#  'Arabic terms with usage examples',
#  'Arabic time adverbs',
#  'Arabic tool nouns',
#  'Arabic trademarks',
#  'Arabic transitive verbs',
#  'Arabic tritransitive verbs',
#  'Arabic uncommon forms',
#  'Arabic uncommon terms',
#  'Arabic uncountable nouns',
#  'Arabic unisex given names',
#  'Arabic verb forms',
#  'Arabic verbal nouns',
#  'Arabic verbs',
#  'Arabic verbs with ambiguous radicals',
#  'Arabic verbs with quadriliteral roots',
#  'Arabic vulgarities',
#  'Arabic words derived through metathesis',
#  'Arabic_active_participles',
#  'Arabic_terms_belonging_to_the_root_ر_ض_و',
#  'Chadian Arabic',
#  'Classical Arabic',
#  'Combining characters',
#  'Cypriot Arabic',
#  'Egyptian Arabic',
#  'Egyptian Arabic terms with IPA pronunciation',
#  'Entries missing English vernacular names of taxa',
#  'Entries using missing taxonomic name (genus)',
#  'Entries using missing taxonomic name (nothospecies)',
#  'Entries using missing taxonomic name (species)',
#  'Entries using missing taxonomic name (subgenus)',
#  'Entries using missing taxonomic name (subspecies)',
#  'Entries using missing taxonomic name (tribe)',
#  'Entries using missing taxonomic name (variety)',
#  'Entries with deprecated labels',
#  'Forms linking to themselves',
#  'French terms with quotations',
#  'Galilean Arabic',
#  'Gulf Arabic terms with IPA pronunciation',
#  'Hijazi Arabic terms with IPA pronunciation',
#  'Inflections with a red link for singular',
#  'Iraqi Arabic',
#  'Israeli Arabic',
#  'Jordanian Arabic',
#  'Judeo-Arabic',
#  'Lebanese Arabic',
#  'Levantine Arabic',
#  'Libyan Arabic',
#  'Libyan Arabic terms with IPA pronunciation',
#  'Malian Arabic',
#  'Mauritanian Arabic',
#  'Moroccan Arabic',
#  'Moroccan Arabic 1-syllable words',
#  'Moroccan Arabic 2-syllable words',
#  'Moroccan Arabic 3-syllable words',
#  'Moroccan Arabic terms with IPA pronunciation',
#  'Moroccan Arabic terms with audio links',
#  'Nigerian Arabic',
#  'North Levantine Arabic terms with IPA pronunciation',
#  'Omani Arabic',
#  'Palestinian Arabic',
#  'Plurals with a red link for singular',
#  'Post-classical Arabic',
#  'Pre-classical Arabic',
#  'Quotation templates to be cleaned',
#  'Regional Arabic',
#  'Requests for audio pronunciation in Egyptian Arabic entries',
#  'Requests for date',
#  'Requests for gender in Arabic entries',
#  'Requests for gender in Hebrew entries',
#  'Requests for gender in Urdu entries',
#  'Requests for gender in Ushojo entries',
#  'Requests for native script for Chagatai terms',
#  'Requests for native script for Middle Persian terms',
#  'Requests for native script for Munji terms',
#  'Requests for native script for Yidgha terms',
#  'Requests for native script in Arabic quotations',
#  'Requests for pronunciation in Arabic entries',
#  'Requests for pronunciation in Egyptian Arabic entries',
#  'Requests for translations of Arabic quotations',
#  'Requests for translations of Arabic usage examples',
#  'Requests for transliteration of Arabic quotations',
#  'Requests for transliteration of Arabic terms',
#  'Requests for transliteration of Arabic usage examples',
#  'Requests for transliteration of Persian terms',
#  'Requests for transliteration of South Levantine Arabic terms',
#  'Requests for transliteration of Urdu terms',
#  'Rhymes:Arabic/awl',
#  'Rhymes:Arabic/aː',
#  'Rhymes:Arabic/aːb',
#  'Rhymes:Arabic/aːb/1 syllable',
#  'Rhymes:Arabic/aːdˤ',
#  'Rhymes:Arabic/aːd͡ʒ',
#  'Rhymes:Arabic/aːd͡ʒ/3 syllables',
#  'Rhymes:Arabic/aːl',
#  'Rhymes:Arabic/aːl/3 syllables',
#  'Rhymes:Arabic/aːm',
#  'Rhymes:Arabic/aːn',
#  'Rhymes:Arabic/aːn/1 syllable',
#  'Rhymes:Arabic/aːn/2 syllables',
#  'Rhymes:Arabic/aːn/3 syllables',
#  'Rhymes:Arabic/aːr',
#  'Rhymes:Arabic/aːr/2 syllables',
#  'Rhymes:Arabic/aːsˤ',
#  'Rhymes:Arabic/aːsˤ/1 syllable',
#  'Rhymes:Arabic/aːt',
#  'Rhymes:Arabic/aːt/1 syllable',
#  'Rhymes:Arabic/aːz',
#  'Rhymes:Arabic/aːz/1 syllable',
#  'Rhymes:Arabic/aːz/3 syllables',
#  'Rhymes:Arabic/aːʔ',
#  'Rhymes:Arabic/aːʔ/2 syllables',
#  'Rhymes:Arabic/ijj',
#  'Rhymes:Arabic/ijj/2 syllables',
#  'Rhymes:Arabic/il',
#  'Rhymes:Arabic/iːd',
#  'Rhymes:Arabic/iːd/2 syllables',
#  'Rhymes:Arabic/iːdˤ',
#  'Rhymes:Arabic/iːdˤ/2 syllables',
#  'Rhymes:Arabic/iːl',
#  'Rhymes:Arabic/iːm',
#  'Rhymes:Arabic/iːm/3 syllables',
#  'Rhymes:Arabic/iːn',
#  'Rhymes:Arabic/iːn/2 syllables',
#  'Rhymes:Arabic/iːr',
#  'Rhymes:Arabic/iːr/2 syllables',
#  'Rhymes:Arabic/laː',
#  'Rhymes:Arabic/ul',
#  'Rhymes:Arabic/un',
#  'Rhymes:Arabic/uːd',
#  'Rhymes:Arabic/uːd/1 syllable',
#  'Rhymes:Arabic/uːd/2 syllables',
#  'Rhymes:Arabic/uːf',
#  'Rhymes:Arabic/uːf/2 syllables',
#  'Rhymes:Arabic/uːn',
#  'Rhymes:Arabic/uːr',
#  'Rhymes:Arabic/uːr/1 syllable',
#  'Rhymes:Arabic/uːr/2 syllables',
#  'Rhymes:Arabic/uːʔ',
#  'Rhymes:Hijazi Arabic/ar',
#  'Sisters of ʾinna',
#  'Sudanese Arabic',
#  'Syrian Arabic',
#  'Terms with manual transliterations different from the automated ones',
#  'Terms with manual transliterations different from the automated ones/aii',
#  'Terms with manual transliterations different from the automated ones/am',
#  'Terms with manual transliterations different from the automated ones/ar',
#  'Terms with manual transliterations different from the automated ones/bn',
#  'Terms with manual transliterations different from the automated ones/ckb',
#  'Terms with manual transliterations different from the automated ones/cmn',
#  'Terms with manual transliterations different from the automated ones/hi',
#  'Terms with manual transliterations different from the automated ones/inc-opa',
#  'Terms with manual transliterations different from the automated ones/ko',
#  'Terms with manual transliterations different from the automated ones/pa',
#  'Terms with manual transliterations different from the automated ones/tig',
#  'Terms with manual transliterations different from the automated ones/ur',
#  'Terms with manual transliterations different from the automated ones/yi',
#  'Terms with redundant transliterations',
#  'Terms with redundant transliterations/ar',
#  'Terms with redundant transliterations/bn',
#  'Terms with redundant transliterations/ckb',
#  'Terms with redundant transliterations/cmn',
#  'Terms with redundant transliterations/ka',
#  'Terms with redundant transliterations/mxi',
#  'Terms with redundant transliterations/pa',
#  'Terms with redundant transliterations/peo',
#  'Terms with redundant transliterations/sd',
#  'Terms with redundant transliterations/ug',
#  'Terms with redundant transliterations/ur',
#  'Terms with redundant transliterations/yue',
#  'Terms with redundant transliterations/zh',
#  'Tunisian Arabic',
#  'Tunisian Arabic terms with IPA pronunciation',
#  'Yemeni Arabic',
#  'acw:Containers',
#  'afb:Currencies',
#  'ar:Acanthus family plants',
#  'ar:Accounting',
#  'ar:Acting',
#  'ar:Adjectives',
#  'ar:Administrative divisions',
#  'ar:Afghanistan',
#  'ar:Africa',
#  'ar:Agriculture',
#  'ar:Albania',
#  'ar:Alchemy',
#  'ar:Algae',
#  'ar:Alliums',
#  'ar:Alloys',
#  'ar:Alternative medicine',
#  'ar:Amaranths and goosefoots',
#  'ar:Ambiguity',
#  'ar:Anatomy',
#  'ar:Ancient settlements',
#  'ar:Andorra',
#  'ar:Anger',
#  'ar:Animal body parts',
#  'ar:Animal sounds',
#  'ar:Animals',
#  'ar:Arabian deities',
#  'ar:Arabic letter names',
#  'ar:Arachnids',
#  'ar:Archaeology',
#  'ar:Archery',
#  'ar:Architectural elements',
#  'ar:Architecture',
#  'ar:Areas in Kuwait',
#  'ar:Argentina',
#  'ar:Arithmetic',
#  'ar:Armenia',
#  'ar:Art',
#  'ar:Arum family plants',
#  'ar:Asia',
#  'ar:Asparagales order plants',
#  'ar:Astrology',
#  'ar:Astronomy',
#  'ar:Astrophysics',
#  'ar:Athletes',
#  'ar:Atmospheric phenomena',
#  'ar:Australia',
#  'ar:Auto parts',
#  'ar:Automobiles',
#  'ar:Automotive',
#  'ar:Autonomous communities of Spain',
#  'ar:Autonomous community capitals of Spain',
#  'ar:Autumn',
#  'ar:Aviation',
#  'ar:Azerbaijan',
#  'ar:Babies',
#  'ar:Baby animals',
#  'ar:Backgammon',
#  'ar:Bacteriology',
#  'ar:Bags',
#  'ar:Bahamas',
#  'ar:Bahrain',
#  'ar:Baháʼí Faith',
#  'ar:Bangladesh',
#  'ar:Banking',
#  'ar:Basketball',
#  'ar:Beards',
#  'ar:Beekeeping',
#  'ar:Beer',
#  'ar:Beetles',
#  'ar:Belgium',
#  'ar:Beverages',
#  'ar:Bible',
#  'ar:Biblical characters',
#  'ar:Biochemistry',
#  'ar:Biology',
#  'ar:Birch family plants',
#  'ar:Birds',
#  'ar:Birds of prey',
#  'ar:Blacks',
#  'ar:Board games',
#  'ar:Bodily fluids',
#  'ar:Body',
#  'ar:Body parts',
#  'ar:Bodybuilding',
#  'ar:Bones',
#  'ar:Books',
#  'ar:Books of the Bible',
#  'ar:Borage family plants',
#  'ar:Bosnia and Herzegovina',
#  'ar:Botany',
#  'ar:Boxing',
#  'ar:Brassicales order plants',
#  'ar:Brazil',
#  'ar:Breads',
#  'ar:Breastfeeding',
#  'ar:Bridges',
#  'ar:Broomrape family plants',
#  'ar:Buddhism',
#  'ar:Building materials',
#  'ar:Buildings',
#  'ar:Burial',
#  'ar:Business',
#  'ar:Buttercup family plants',
#  'ar:Cacti',
#  'ar:Caesalpinia subfamily plants',
#  'ar:Cakes and pastries',
#  'ar:Calligraphy',
#  'ar:Caltrop family plants',
#  'ar:Camelids',
#  'ar:Canids',
#  'ar:Cantons of Switzerland',
#  'ar:Capital cities',
#  'ar:Card games',
#  'ar:Cardiology',
#  'ar:Caryophyllales order plants',
#  'ar:Catholicism',
#  'ar:Cats',
#  'ar:Cattle',
#  'ar:Celestial inhabitants',
#  'ar:Cheeses',
#  'ar:Chemical elements',
#  'ar:Chemistry',
#  'ar:Chess',
#  'ar:Chickens',
#  "ar:Children's games",
#  'ar:China',
#  'ar:Christianity',
#  'ar:Cichlids',
#  'ar:Cichorieae tribe plants',
#  'ar:Cities',
#  'ar:Cities in Afghanistan',
#  'ar:Cities in Albania',
#  'ar:Cities in Algeria',
#  'ar:Cities in Andalusia',
#  'ar:Cities in Andorra',
#  'ar:Cities in Angola',
#  'ar:Cities in Aragon',
#  'ar:Cities in Argentina',
#  'ar:Cities in Armenia',
#  'ar:Cities in Australia',
#  'ar:Cities in Austria',
#  'ar:Cities in Azerbaijan',
#  'ar:Cities in Bahia, Brazil',
#  'ar:Cities in Bahrain',
#  'ar:Cities in Bangladesh',
#  'ar:Cities in Barbados',
#  'ar:Cities in Belarus',
#  'ar:Cities in Belgium',
#  'ar:Cities in Belize',
#  'ar:Cities in Beni Mellal-Khenifra',
#  'ar:Cities in Benin',
#  'ar:Cities in Bhutan',
#  'ar:Cities in Bolivia',
#  'ar:Cities in Bosnia and Herzegovina',
#  'ar:Cities in Botswana',
#  'ar:Cities in Brazil',
#  'ar:Cities in Brunei',
#  'ar:Cities in Bulgaria',
#  'ar:Cities in Burkina Faso',
#  'ar:Cities in Burundi',
#  'ar:Cities in California, USA',
#  'ar:Cities in Cambodia',
#  'ar:Cities in Cameroon',
#  'ar:Cities in Canada',
#  'ar:Cities in Cape Verde',
#  'ar:Cities in Casablanca-Settat',
#  'ar:Cities in Castile and León',
#  'ar:Cities in Catalonia',
#  'ar:Cities in Chad',
#  'ar:Cities in Chile',
#  'ar:Cities in China',
#  'ar:Cities in Colombia',
#  'ar:Cities in Costa Rica',
#  'ar:Cities in Croatia',
#  'ar:Cities in Cuba',
#  'ar:Cities in Cyprus',
#  'ar:Cities in Denmark',
#  'ar:Cities in Distrito Federal, Brazil',
#  'ar:Cities in Djibouti',
#  'ar:Cities in Dominica',
#  'ar:Cities in Egypt',
#  'ar:Cities in El Salvador',
#  'ar:Cities in England',
#  'ar:Cities in Eritrea',
#  'ar:Cities in Estonia',
#  'ar:Cities in Ethiopia',
#  'ar:Cities in Fez-Meknes',
#  'ar:Cities in Finland',
#  'ar:Cities in France',
#  'ar:Cities in Georgia',
#  'ar:Cities in Georgia, USA',
#  'ar:Cities in Germany',
#  'ar:Cities in Greece',
#  'ar:Cities in Guelmim-Oued Noun',
#  'ar:Cities in Hungary',
#  'ar:Cities in Illinois, USA',
#  'ar:Cities in India',
#  'ar:Cities in Indonesia',
#  'ar:Cities in Iran',
#  'ar:Cities in Iraq',
#  'ar:Cities in Ireland',
#  'ar:Cities in Israel',
#  'ar:Cities in Italy',
#  'ar:Cities in Ivory Coast',
#  'ar:Cities in Jalisco',
#  'ar:Cities in Japan',
#  'ar:Cities in Jordan',
#  'ar:Cities in Kaliningrad Oblast',
#  'ar:Cities in Kazakhstan',
#  'ar:Cities in Kuwait',
#  'ar:Cities in Kyoto Prefecture',
#  'ar:Cities in Laos',
#  'ar:Cities in Lebanon',
#  'ar:Cities in León',
#  'ar:Cities in Libya',
#  'ar:Cities in Lombardy',
#  'ar:Cities in Louisiana, USA',
#  'ar:Cities in Maharashtra',
#  'ar:Cities in Malaysia',
#  'ar:Cities in Mali',
#  'ar:Cities in Marrakesh-Safi',
#  'ar:Cities in Massachusetts, USA',
#  'ar:Cities in Mauritania',
#  'ar:Cities in Mexico',
#  'ar:Cities in Moldova',
#  'ar:Cities in Morocco',
#  'ar:Cities in New South Wales',
#  'ar:Cities in New York, USA',
#  'ar:Cities in Newfoundland and Labrador',
#  'ar:Cities in North Holland, Netherlands',
#  'ar:Cities in North Rhine-Westphalia',
#  'ar:Cities in Oman',
#  'ar:Cities in Oriental',
#  'ar:Cities in Osaka Prefecture',
#  'ar:Cities in Pakistan',
#  'ar:Cities in Palestine',
#  'ar:Cities in Poland',
#  'ar:Cities in Portugal',
#  "ar:Cities in Provence-Alpes-Côte d'Azur",
#  'ar:Cities in Qatar',
#  'ar:Cities in Quebec',
#  'ar:Cities in Rabat-Sale-Kenitra',
#  'ar:Cities in Rio de Janeiro, Brazil',
#  'ar:Cities in Romania',
#  'ar:Cities in Russia',
#  'ar:Cities in Saudi Arabia',
#  'ar:Cities in Somalia',
#  'ar:Cities in Souss-Massa',
#  'ar:Cities in South Korea',
#  'ar:Cities in South Sudan',
#  'ar:Cities in Spain',
#  'ar:Cities in Sri Lanka',
#  'ar:Cities in Sudan',
#  'ar:Cities in Sweden',
#  'ar:Cities in Switzerland',
#  'ar:Cities in Syria',
#  'ar:Cities in São Paulo, Brazil',
#  'ar:Cities in Tamil Nadu',
#  'ar:Cities in Tanger-Tetouan-Al Hoceima',
#  'ar:Cities in Tanzania',
#  'ar:Cities in Thailand',
#  'ar:Cities in Tunisia',
#  'ar:Cities in Turkey',
#  'ar:Cities in Turkmenistan',
#  'ar:Cities in Ukraine',
#  'ar:Cities in Uzbekistan',
#  'ar:Cities in Valencia',
#  'ar:Cities in Veneto',
#  'ar:Cities in Venezuela',
#  'ar:Cities in Virginia, USA',
#  'ar:Cities in Vladimir Oblast',
#  'ar:Cities in Western Sahara',
#  'ar:Cities in Yemen',
#  'ar:Cities in the Bahamas',
#  'ar:Cities in the Central African Republic',
#  'ar:Cities in the Comoros',
#  'ar:Cities in the Czech Republic',
#  'ar:Cities in the Democratic Republic of the Congo',
#  'ar:Cities in the Dominican Republic',
#  'ar:Cities in the Netherlands',
#  'ar:Cities in the Philippines',
#  'ar:Cities in the Republic of Bashkortostan',
#  'ar:Cities in the Republic of the Congo',
#  'ar:Cities in the United Arab Emirates',
#  'ar:Cities in the United Kingdom',
#  'ar:Cities in the United States',
#  'ar:Citrus subfamily plants',
#  'ar:City nicknames',
#  'ar:City-states',
#  'ar:Cleaning',
#  'ar:Clocks',
#  'ar:Clothing',
#  'ar:Clouds',
#  'ar:Coffee',
#  'ar:Coins',
#  'ar:Collective numbers',
#  'ar:Collectives',
#  'ar:Colors',
#  'ar:Columbids',
#  'ar:Communication',
#  'ar:Communism',
#  'ar:Compass points',
#  'ar:Composites',
#  'ar:Computing',
#  'ar:Condiments',
#  'ar:Constellations',
#  'ar:Construction vehicles',
#  'ar:Containers',
#  'ar:Continents',
#  'ar:Cooking',
#  'ar:Cookware and bakeware',
#  'ar:Coraciiforms',
#  'ar:Counties of England',
#  'ar:Counties of Iran',
#  'ar:Counties of Romania',
#  'ar:Countries',
#  'ar:Countries in Africa',
#  'ar:Countries in Asia',
#  'ar:Countries in Central America',
#  'ar:Countries in Europe',
#  'ar:Countries in North America',
#  'ar:Countries in Oceania',
#  'ar:Countries in South America',
#  'ar:Countries of the United Kingdom',
#  'ar:County seats of Georgia, USA',
#  'ar:Crickets and grasshoppers',
#  'ar:Crime',
#  'ar:Criminal law',
#  'ar:Crucifers',
#  'ar:Cryptocurrency',
#  'ar:Currencies',
#  'ar:Currency',
#  'ar:Custard apple family plants',
#  'ar:Cycling',
#  'ar:Cypress family plants',
#  'ar:Cyprinids',
#  'ar:Dairy products',
#  'ar:Dance',
#  'ar:Day',
#  'ar:Days of the week',
#  'ar:Death',
#  'ar:Democratic Republic of the Congo',
#  'ar:Demonyms',
#  'ar:Denmark',
#  'ar:Dental hygiene',
#  'ar:Departmental capitals',
#  'ar:Departments of El Salvador',
#  'ar:Dependent territories of the United Kingdom',
#  'ar:Dependent territories of the United States',
#  'ar:Dermatology',
#  'ar:Deserts',
#  'ar:Desserts',
#  'ar:Dice games',
#  'ar:Dictionaries',
#  'ar:Disease',
#  'ar:Diseases',
#  'ar:District capitals',
#  'ar:Districts of Bangladesh',
#  'ar:Districts of India',
#  'ar:Districts of Lebanon',
#  'ar:Districts of Turkey',
#  'ar:Districts of Yemen',
#  'ar:Divination',
#  'ar:Divisions of Bangladesh',
#  'ar:Dogbane family plants',
#  'ar:Drinking',
#  'ar:Eagles',
#  'ar:Earth',
#  'ar:Economics',
#  'ar:Ecuador',
#  'ar:Education',
#  'ar:Eels',
#  'ar:Eggs',
#  'ar:Egypt',
#  'ar:Egyptian deities',
#  'ar:Eight',
#  'ar:Eighteen',
#  'ar:Electrical engineering',
#  'ar:Electricity',
#  'ar:Electromagnetism',
#  'ar:Electronics',
#  'ar:Elephants',
#  'ar:Emirate capitals',
#  'ar:Emirates of the United Arab Emirates',
#  'ar:Emotions',
#  'ar:England',
#  'ar:English',
#  'ar:English male given names',
#  'ar:English surnames',
#  'ar:Epidemiology',
#  'ar:Epistemology',
#  'ar:Equids',
#  'ar:Ethics',
#  'ar:Ethnonyms',
#  'ar:Even-toed ungulates',
#  'ar:Evolutionary theory',
#  'ar:Exercise equipment',
#  'ar:Explosives',
#  'ar:Eye',
#  'ar:Eyewear',
#  'ar:Fabeae tribe plants',
#  'ar:Fabrics',
#  'ar:Face',
#  'ar:Facial expressions',
#  'ar:Falconids',
#  'ar:Family',
#  'ar:Farriery',
#  'ar:Fascism',
#  'ar:Fasteners',
#  'ar:Fats and oils',
#  'ar:Fear',
#  'ar:Feces',
#  'ar:Federal territories of Malaysia',
#  'ar:Female',
#  'ar:Female animals',
#  'ar:Female people',
#  'ar:Fermions',
#  'ar:Fibers',
#  'ar:Fiction',
#  'ar:Fifteen',
#  'ar:Film',
#  'ar:Finance',
#  'ar:Fingers',
#  'ar:Fire',
#  'ar:Firearms',
#  'ar:Fish',
#  'ar:Fishing',
#  'ar:Five',
#  'ar:Flowers',
#  'ar:Food and drink',
#  'ar:Foods',
#  'ar:Football (soccer)',
#  'ar:Footwear',
#  'ar:Forests',
#  'ar:Forms of government',
#  'ar:Four',
#  'ar:Fourteen',
#  'ar:Fowls',
#  'ar:Freshwater birds',
#  'ar:Fruits',
#  'ar:Furniture',
#  'ar:Gambling',
#  'ar:Games',
#  'ar:Gems',
#  'ar:Gender',
#  'ar:Genealogy',
#  'ar:Genetic disorders',
#  'ar:Geography',
#  'ar:Geology',
#  'ar:Geometry',
#  'ar:Germany',
#  'ar:Ginger family plants',
#  'ar:Gnosticism',
#  'ar:Goats',
#  'ar:God',
#  'ar:Gourd family plants',
#  'ar:Government',
#  'ar:Governorates of Iraq',
#  'ar:Governorates of Saudi Arabia',
#  'ar:Governorates of Syria',
#  'ar:Governorates of Tunisia',
#  'ar:Grains',
#  'ar:Grammar',
#  'ar:Graphical user interface',
#  'ar:Grasses',
#  'ar:Greece',
#  'ar:Greek mythology',
#  'ar:Gregorian calendar months',
#  'ar:Gums and resins',
#  'ar:Hair',
#  'ar:Handball',
#  'ar:Healthcare occupations',
#  'ar:Hebrew calendar months',
#  'ar:Hebrew letter names',
#  'ar:Hemipterans',
#  'ar:Herrings',
#  'ar:Hills',
#  'ar:Hinduism',
#  'ar:Historical and traditional regions',
#  'ar:Historical capitals',
#  'ar:Historical events',
#  'ar:Historical periods',
#  'ar:Historical political subdivisions',
#  'ar:Historical polities',
#  'ar:Historical settlements',
#  'ar:History',
#  'ar:Horse tack',
#  'ar:Horticulture',
#  'ar:Human',
#  'ar:Hunting',
#  'ar:Hygiene',
#  'ar:Hyraxes',
#  'ar:Ice',
#  'ar:Immunology',
#  'ar:India',
#  'ar:Individuals',
#  'ar:Inorganic compounds',
#  'ar:Insects',
#  'ar:International law',
#  'ar:Internet',
#  'ar:Iran',
#  'ar:Iranian mythology',
#  'ar:Ireland',
#  'ar:Islam',
#  'ar:Islamic finance',
#  'ar:Islamic jurisprudence',
#  'ar:Islamic law',
#  'ar:Islamic months',
#  'ar:Islands',
#  'ar:Israel',
#  'ar:Jamaica',
#  'ar:Japan',
#  'ar:Japanese fiction',
#  'ar:Jawless fish',
#  'ar:Jewelry',
#  'ar:Judaism',
#  'ar:Kazakhstan',
#  'ar:Kitchenware',
#  'ar:Korea',
#  'ar:Kuwait',
#  'ar:LGBT',
#  'ar:Lakes',
#  'ar:Lamiales order plants',
#  'ar:Lamniform sharks',
#  'ar:Landforms',
#  'ar:Language',
#  'ar:Languages',
#  'ar:Larks',
#  'ar:Latin letter names',
#  'ar:Laughter',
#  'ar:Laundry',
#  'ar:Law',
#  'ar:Law enforcement',
#  'ar:Legumes',
#  'ar:Lexicography',
#  'ar:Lichens',
#  'ar:Light sources',
#  'ar:Liliales order plants',
#  'ar:Linguistic morphology',
#  'ar:Linguistics',
#  'ar:Liquids',
#  'ar:Literature',
#  'ar:Lizards',
#  'ar:Locks',
#  'ar:Logic',
#  'ar:Love',
#  'ar:Male',
#  'ar:Male animals',
#  'ar:Mallow family plants',
#  'ar:Mallow subfamily plants',
#  'ar:Malpighiales order plants',
#  'ar:Malvales order plants',
#  'ar:Mammals',
#  'ar:Manichaeism',
#  'ar:Marriage',
#  'ar:Marsupials',
#  'ar:Mathematical analysis',
#  'ar:Mathematics',
#  'ar:Meals',
#  'ar:Meats',
#  'ar:Media',
#  'ar:Medical equipment',
#  'ar:Medical signs and symptoms',
#  'ar:Medicine',
#  'ar:Memetics',
#  'ar:Menstruation',
#  'ar:Metaphysics',
#  'ar:Meteorology',
#  'ar:Mexico',
#  'ar:Micronesia',
#  'ar:Military',
#  'ar:Military ranks',
#  'ar:Military vehicles',
#  'ar:Milk',
#  'ar:Mimosa subfamily plants',
#  'ar:Mining',
#  'ar:Mint family plants',
#  'ar:Monarchy',
#  'ar:Monasticism',
#  'ar:Money',
#  'ar:Morning glory family plants',
#  'ar:Moschatel family plants',
#  'ar:Mountains',
#  'ar:Mulberry family plants',
#  'ar:Municipalities of Bahia, Brazil',
#  'ar:Municipalities of Brazil',
#  'ar:Municipalities of Moldova',
#  'ar:Municipalities of North Holland, Netherlands',
#  'ar:Municipalities of Rio de Janeiro, Brazil',
#  'ar:Municipalities of São Paulo, Brazil',
#  'ar:Municipalities of the Netherlands',
#  'ar:Murder',
#  'ar:Muscles',
#  'ar:Mushrooms',
#  'ar:Music',
#  'ar:Musical instruments',
#  'ar:Myrtales order plants',
#  'ar:Myrtle family plants',
#  'ar:Mythological creatures',
#  'ar:Mythological plants',
#  'ar:Narratology',
#  'ar:National capitals',
#  'ar:Nationalities',
#  'ar:Natural materials',
#  'ar:Nautical',
#  'ar:Navigation',
#  'ar:Nazism',
#  'ar:Neckwear',
#  'ar:Neighbourhoods in North Rhine-Westphalia',
#  'ar:Nettle family plants',
#  'ar:Night',
#  'ar:Nightshades',
#  'ar:Nineteen',
#  'ar:Nobility',
#  'ar:North Korea',
#  'ar:Nouns',
#  'ar:Nuts',
#  'ar:Oaks',
#  'ar:Oblasts of Russia',
#  'ar:Oblasts of Ukraine',
#  'ar:Obstetrics',
#  'ar:Occult',
#  'ar:Occupations',
#  'ar:Oil industry',
#  'ar:Olive family plants',
#  'ar:Oman',
#  'ar:One',
#  'ar:Opera',
#  'ar:Organic compounds',
#  'ar:Organizations',
#  'ar:Organs',
#  'ar:Paganism',
#  'ar:Painting',
#  'ar:Palm trees',
#  'ar:Panthers',
#  'ar:Parasites',
#  'ar:Parts of speech',
#  'ar:Pasta',
#  'ar:Pathology',
#  'ar:Peninsulas',
#  'ar:People',
#  'ar:Perching birds',
#  'ar:Personifications',
#  'ar:Petrochemistry',
#  'ar:Pharmaceutical drugs',
#  'ar:Pharmacology',
#  'ar:Pharmacy',
#  'ar:Philippines',
#  'ar:Philosophy',
#  'ar:Phonetics',
#  'ar:Phonology',
#  'ar:Photography',
#  'ar:Physics',
#  'ar:Physiology',
#  'ar:Pinnipeds',
#  'ar:Places in Afghanistan',
#  'ar:Places in Albania',
#  'ar:Places in Algeria',
#  'ar:Places in Andalusia',
#  'ar:Places in Andorra',
#  'ar:Places in Angola',
#  'ar:Places in Aragon',
#  'ar:Places in Argentina',
#  'ar:Places in Armenia',
#  'ar:Places in Australia',
#  'ar:Places in Austria',
#  'ar:Places in Azerbaijan',
#  'ar:Places in Bahia, Brazil',
#  'ar:Places in Bahrain',
#  'ar:Places in Bangladesh',
#  'ar:Places in Barbados',
#  'ar:Places in Belarus',
#  'ar:Places in Belgium',
#  'ar:Places in Belize',
#  'ar:Places in Beni Mellal-Khenifra',
#  'ar:Places in Benin',
#  'ar:Places in Bhutan',
#  'ar:Places in Bolivia',
#  'ar:Places in Bosnia and Herzegovina',
#  'ar:Places in Botswana',
#  'ar:Places in Brazil',
#  'ar:Places in Brunei',
#  'ar:Places in Bulgaria',
#  'ar:Places in Burkina Faso',
#  'ar:Places in Burundi',
#  'ar:Places in California, USA',
#  'ar:Places in Cambodia',
#  'ar:Places in Cameroon',
#  'ar:Places in Canada',
#  'ar:Places in Cape Verde',
#  'ar:Places in Casablanca-Settat',
#  'ar:Places in Castile and León',
#  'ar:Places in Catalonia',
#  'ar:Places in Chad',
#  'ar:Places in Chile',
#  'ar:Places in China',
#  'ar:Places in Colombia',
#  'ar:Places in Costa Rica',
#  'ar:Places in Croatia',
#  'ar:Places in Cuba',
#  'ar:Places in Cyprus',
#  'ar:Places in Denmark',
#  'ar:Places in Distrito Federal, Brazil',
#  'ar:Places in Djibouti',
#  'ar:Places in Dominica',
#  'ar:Places in Egypt',
#  'ar:Places in El Salvador',
#  'ar:Places in England',
#  'ar:Places in Eritrea',
#  'ar:Places in Estonia',
#  'ar:Places in Ethiopia',
#  'ar:Places in Extremadura',
#  'ar:Places in Fez-Meknes',
#  'ar:Places in Finland',
#  'ar:Places in France',
#  'ar:Places in Georgia',
#  'ar:Places in Georgia, USA',
#  'ar:Places in Germany',
#  'ar:Places in Greece',
#  'ar:Places in Guelmim-Oued Noun',
#  'ar:Places in Hungary',
#  'ar:Places in Illinois, USA',
#  'ar:Places in India',
#  'ar:Places in Indonesia',
#  'ar:Places in Iran',
#  'ar:Places in Iraq',
#  'ar:Places in Ireland',
#  'ar:Places in Israel',
#  'ar:Places in Italy',
#  'ar:Places in Ivory Coast',
#  'ar:Places in Jalisco',
#  'ar:Places in Japan',
#  'ar:Places in Jordan',
#  'ar:Places in Kaliningrad Oblast',
#  'ar:Places in Kazakhstan',
#  'ar:Places in Kuwait',
#  'ar:Places in Kyoto Prefecture',
#  'ar:Places in La Rioja',
#  'ar:Places in Laos',
#  'ar:Places in Lazio',
#  'ar:Places in Lebanon',
#  'ar:Places in Libya',
#  'ar:Places in Lombardy',
#  'ar:Places in Louisiana, USA',
#  'ar:Places in Maharashtra',
#  'ar:Places in Malaysia',
#  'ar:Places in Mali',
#  'ar:Places in Marrakesh-Safi',
#  'ar:Places in Massachusetts, USA',
#  'ar:Places in Mauritania',
#  'ar:Places in Mexico',
#  'ar:Places in Moldova',
#  'ar:Places in Morocco',
#  'ar:Places in New South Wales',
#  'ar:Places in New York, USA',
#  'ar:Places in Newfoundland and Labrador',
#  'ar:Places in North Holland, Netherlands',
#  'ar:Places in North Rhine-Westphalia',
#  'ar:Places in Oman',
#  'ar:Places in Oriental',
#  'ar:Places in Osaka Prefecture',
#  'ar:Places in Pakistan',
#  'ar:Places in Palestine',
#  'ar:Places in Poland',
#  'ar:Places in Portugal',
#  "ar:Places in Provence-Alpes-Côte d'Azur",
#  'ar:Places in Punjab',
#  'ar:Places in Qatar',
#  'ar:Places in Quebec',
#  'ar:Places in Rabat-Sale-Kenitra',
#  'ar:Places in Rio de Janeiro, Brazil',
#  'ar:Places in Romania',
#  'ar:Places in Rome',
#  'ar:Places in Russia',
#  'ar:Places in Saudi Arabia',
#  'ar:Places in Scotland',
#  'ar:Places in Sicily',
#  'ar:Places in Somalia',
#  'ar:Places in Souss-Massa',
#  'ar:Places in South Korea',
#  'ar:Places in South Sudan',
#  'ar:Places in Spain',
#  'ar:Places in Sri Lanka',
#  'ar:Places in Sudan',
#  'ar:Places in Sweden',
#  'ar:Places in Switzerland',
#  'ar:Places in Syria',
#  'ar:Places in São Paulo, Brazil',
#  'ar:Places in Tamil Nadu',
#  'ar:Places in Tanger-Tetouan-Al Hoceima',
#  'ar:Places in Tanzania',
#  'ar:Places in Thailand',
#  'ar:Places in Tunisia',
#  'ar:Places in Turkey',
#  'ar:Places in Turkmenistan',
#  'ar:Places in Ukraine',
#  'ar:Places in Uzbekistan',
#  'ar:Places in Valencia',
#  'ar:Places in Veneto',
#  'ar:Places in Venezuela',
#  'ar:Places in Virginia, USA',
#  'ar:Places in Vladimir Oblast',
#  'ar:Places in Western Sahara',
#  'ar:Places in Yemen',
#  'ar:Places in the Bahamas',
#  'ar:Places in the Balearic Islands',
#  'ar:Places in the Central African Republic',
#  'ar:Places in the Comoros',
#  'ar:Places in the Czech Republic',
#  'ar:Places in the Democratic Republic of the Congo',
#  'ar:Places in the Dominican Republic',
#  'ar:Places in the Netherlands',
#  'ar:Places in the Philippines',
#  'ar:Places in the Republic of Bashkortostan',
#  'ar:Places in the Republic of the Congo',
#  'ar:Places in the United Arab Emirates',
#  'ar:Places in the United Kingdom',
#  'ar:Places in the United States',
#  'ar:Places of worship',
#  'ar:Planets of the Solar System',
#  'ar:Plant diseases',
#  'ar:Poetry',
#  'ar:Pokémon',
#  'ar:Politics',
#  'ar:Polities',
#  'ar:Pome fruits',
#  'ar:Poppies',
#  'ar:Portugal',
#  'ar:Prayer',
#  'ar:Prefectural capitals of Japan',
#  'ar:Prefectures of Japan',
#  'ar:Pregnancy',
#  'ar:Primates',
#  'ar:Printing',
#  'ar:Prison',
#  'ar:Probability theory',
#  'ar:Programming',
#  'ar:Prosody',
#  'ar:Prostitution',
#  'ar:Provinces of Afghanistan',
#  'ar:Provinces of Algeria',
#  'ar:Provinces of Canada',
#  'ar:Provinces of Chile',
#  'ar:Provinces of Iran',
#  'ar:Provinces of Italy',
#  'ar:Provinces of Pakistan',
#  'ar:Provinces of Spain',
#  'ar:Provinces of Turkey',
#  'ar:Provincial capitals',
#  'ar:Provincial capitals of Canada',
#  'ar:Psychology',
#  'ar:Punctuation marks',
#  "ar:Qur'an",
#  'ar:Radio',
#  'ar:Rain',
#  'ar:Ratites',
#  'ar:Rays and skates',
#  'ar:Recreational drugs',
#  'ar:Reds',
#  'ar:Reference works',
#  'ar:Regional capitals of France',
#  'ar:Regional capitals of Italy',
#  'ar:Regional capitals of Morocco',
#  'ar:Regions in Asia',
#  'ar:Regions of Djibouti',
#  'ar:Regions of France',
#  'ar:Religion',
#  'ar:Reptiles',
#  'ar:Republic capitals of Russia',
#  'ar:Republic of the Congo',
#  'ar:Restaurants',
#  'ar:Rhetoric',
#  'ar:Rivers',
#  'ar:Rivers in Africa',
#  'ar:Rivers in China',
#  'ar:Rivers in India',
#  'ar:Rivers in Pakistan',
#  'ar:Rivers in Romania',
#  'ar:Rivers in Spain',
#  'ar:Roads',
#  'ar:Roman Catholicism',
#  'ar:Roman deities',
#  'ar:Roman mythology',
#  'ar:Rooms',
#  'ar:Rosales order plants',
#  'ar:Rue family plants',
#  'ar:Russia',
#  'ar:Russian surnames',
#  'ar:Salads',
#  'ar:Sandwiches',
#  'ar:Santalales order plants',
#  'ar:Sapindales order plants',
#  'ar:Sapote family plants',
#  'ar:Sauces',
#  'ar:Saudi Arabia',
#  'ar:Sausages',
#  'ar:Scents',
#  'ar:Schools',
#  'ar:Sciences',
#  'ar:Scientists',
#  'ar:Seas',
#  'ar:Sedges',
#  'ar:Seismology',
#  'ar:Semantics',
#  'ar:Semiconductors',
#  'ar:Set theory',
#  'ar:Seven',
#  'ar:Seventeen',
#  'ar:Sex',
#  'ar:Sexuality',
#  'ar:Shahnameh characters',
#  'ar:Shapes',
#  'ar:Sheep',
#  "ar:Shi'ism",
#  'ar:Ship parts',
#  'ar:Shoemaking',
#  'ar:Shops',
#  'ar:Simple machines',
#  'ar:Singapore',
#  'ar:Six',
#  'ar:Sixteen',
#  'ar:Size',
#  'ar:Slavery',
#  'ar:Sleep',
#  'ar:Smell',
#  'ar:Smoking',
#  'ar:Snakes',
#  'ar:Snow',
#  'ar:Social media',
#  'ar:Social sciences',
#  'ar:Socialism',
#  'ar:Software',
#  'ar:South Korea',
#  'ar:Spears',
#  'ar:Special administrative regions of China',
#  'ar:Spices',
#  'ar:Spices and herbs',
#  'ar:Sports',
#  'ar:Spurges',
#  'ar:Stars',
#  'ar:State capitals of Australia',
#  'ar:State capitals of Brazil',
#  'ar:State capitals of India',
#  'ar:State capitals of Mexico',
#  'ar:State capitals of the United States',
#  'ar:States of Brazil',
#  'ar:States of India',
#  'ar:States of Sudan',
#  'ar:States of the United States',
#  'ar:Statistics',
#  'ar:Straits',
#  'ar:String instruments',
#  'ar:Subatomic particles',
#  'ar:Subdistricts',
#  'ar:Succulents',
#  'ar:Sufism',
#  'ar:Sugars',
#  'ar:Suicide',
#  'ar:Sumac family plants',
#  'ar:Surgery',
#  'ar:Sweden',
#  'ar:Sweets',
#  'ar:Swords',
#  'ar:Syrian Christian months',
#  'ar:Systems',
#  'ar:Talking',
#  'ar:Taxation',
#  'ar:Taxonomy',
#  'ar:Telephony',
#  'ar:Television',
#  'ar:Tennis',
#  'ar:Textiles',
#  'ar:Textual division',
#  'ar:Thailand',
#  'ar:Theater',
#  'ar:Theology',
#  'ar:Thinking',
#  'ar:Thirteen',
#  'ar:Thistles',
#  'ar:Three',
#  'ar:Time',
#  'ar:Titles',
#  'ar:Tobacco',
#  'ar:Toiletries',
#  'ar:Tools',
#  'ar:Towns',
#  'ar:Towns in Algeria',
#  'ar:Towns in Andalusia',
#  'ar:Towns in Aragon',
#  'ar:Towns in Azerbaijan',
#  'ar:Towns in Djibouti',
#  'ar:Towns in Egypt',
#  'ar:Towns in India',
#  'ar:Towns in La Rioja',
#  'ar:Towns in Lebanon',
#  'ar:Towns in Libya',
#  'ar:Towns in Palestine',
#  'ar:Towns in Punjab',
#  'ar:Towns in Spain',
#  'ar:Towns in Sudan',
#  'ar:Towns in Tunisia',
#  'ar:Towns in Turkey',
#  'ar:Towns in Yemen',
#  'ar:Toys',
#  'ar:Translation studies',
#  'ar:Trapping',
#  'ar:Travel',
#  'ar:Trees',
#  'ar:Trifolieae tribe plants',
#  'ar:Trigonometry',
#  'ar:Turkmenistan',
#  'ar:Turtles',
#  'ar:Twelve',
#  'ar:Twenty',
#  'ar:Twitter',
#  'ar:Two',
#  'ar:Typography',
#  'ar:United Arab Emirates',
#  'ar:United Kingdom',
#  'ar:United States',
#  'ar:Units of measure',
#  'ar:Ursids',
#  'ar:Uruguay',
#  'ar:Uzbekistan',
#  'ar:Valleys',
#  'ar:Vegetables',
#  'ar:Vehicles',
#  'ar:Verbs',
#  'ar:Vessels',
#  'ar:Veterinary medicine',
#  'ar:Video games',
#  'ar:Villages in Bahrain',
#  'ar:Villages in Egypt',
#  'ar:Villages in Iran',
#  'ar:Villages in Jordan',
#  'ar:Villages in Lebanon',
#  'ar:Villages in Saudi Arabia',
#  'ar:Villages in Syria',
#  'ar:Villages in Yemen',
#  'ar:Villages in the United Arab Emirates',
#  'ar:Violence',
#  'ar:Viral diseases',
#  'ar:Virology',
#  'ar:Vision',
#  'ar:Vladimir Putin',
#  'ar:Volcanoes',
#  'ar:Volleyball',
#  'ar:War',
#  'ar:Washington, D.C.',
#  'ar:Water',
#  'ar:Water plants',
#  'ar:Watercraft',
#  'ar:Weapons',
#  'ar:Weather',
#  'ar:Weaving',
#  'ar:Western Sahara',
#  'ar:Wicca',
#  'ar:Wiki',
#  'ar:Wind',
#  'ar:Wind instruments',
#  'ar:Wine',
#  'ar:Winter',
#  'ar:Woods',
#  'ar:Writing',
#  'ar:Writing instruments',
#  'ar:Yemen',
#  'ar:Zingiberales order plants',
#  'ar:Zoology',
#  'fa:Animals',
#  'fa:Astronomy',
#  'fa:Bodily fluids',
#  'fa:Computing',
#  'fa:Dairy products',
#  'fa:Family',
#  'fa:Football',
#  'fa:Footwear',
#  'fa:Grammar',
#  'fa:Horses',
#  'fa:Islam',
#  'fa:Love',
#  'fa:Marriage',
#  'fa:Musical notes',
#  'fa:Pathology',
#  'fa:Places of worship',
#  'fa:Religion',
#  'fa:Reptiles',
#  'fa:Sex',
#  'fa:Shahnameh characters',
#  'fa:War',
#  'fa:Watercraft',
#  'he:Geology',
#  'he:God',
#  'he:Time',
#  'ms:Biblical characters',
#  'ms:Blues',
#  'ms:Colors',
#  'ms:Individuals',
#  'ms:Time',
#  'ms:Whites',
#  "mul:Qur'an",
#  'ota:Military',
#  'ota:Occupations',
#  'ps:Body',
#  'ps:Family',
#  'ug:Trading',
#  'ur:Anatomy',
#  'ur:Backgammon',
#  'ur:Biblical characters',
#  'ur:Bodily fluids',
#  'ur:Death',
#  'ur:Distributive numbers',
#  'ur:Fruits',
#  'ur:Islam',
#  'ur:Marriage',
#  'ur:Occupations',
#  'ur:Parts of speech',
#  'ur:Religion',
#  'ur:Sex',
#  'ur:Time',
#  'yi:Monarchy']
