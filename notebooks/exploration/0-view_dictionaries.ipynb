# %% [markdown]
# ## 1.0 Imports

# %%
import gzip
import json
from pathlib import Path
from pprint import pprint
from random import choice

# %% [markdown]
# ## 2.0 Define Paths

# %%
# Path for preproceed Wikitionary
wiktionary_dir = Path("../../data/processed/wikidata")
wiki_jsonl_path = wiktionary_dir / "ar-wiktextract-data.json.gz"
wiki_indices_path = wiktionary_dir / "ar_reindex.json.gz"

# %%
# Path to save words status
output_dir = Path("../../data/interim/")

# %% [markdown]
# # 3.0 Load Wikitionary Files

# %%
# 2. load the wikitionary
with gzip.open(wiki_jsonl_path, "rt", encoding="utf-8") as gzip_obj:
    wikitionary = []
    for i, json_line in enumerate(gzip_obj):
        wikitionary.append(dict(json.loads(json_line)))
        print(f"Reading line-{i}", end="\r")
# Out:
# Reading line-872
# Reading line-128636

# %%
# 3. load Indices
with gzip.open(wiki_indices_path, "rt", encoding="utf-8") as gzip_obj:
    wiki_idxs = json.load(gzip_obj)

# %% [markdown]
# # 4.0 View Dictionaries

# %% [markdown]
# ## 4.1 Search for Arabic Word in Wiktionary

# %%
ar_word = "عصا"

# %%
if idxs := wiki_idxs.get(ar_word):
    for idx in idxs:
        print(idx)
        pprint(wikitionary[idx])
        print()
# Out:
# 12009
# {'عصا': {'categories': ['Arabic 2-syllable words',
#                         'Arabic feminine nouns',
#                         'Arabic final-weak form-I verbs',
#                         'Arabic final-weak verbs',
#                         'Arabic final-weak verbs by conjugation',
#                         'Arabic form-I verbs',
#                         'Arabic form-I verbs with و as third radical',
#                         'Arabic lemmas',
#                         'Arabic nouns',
#                         'Arabic terms with IPA pronunciation',
#                         'Arabic terms with homophones',
#                         'Arabic verbs',
#                         'Terms with redundant transliterations',
#                         'Terms with redundant transliterations/ar'],
#          'descendants': [{'depth': 1,
#                           'templates': [{'args': {'1': 'mt', '2': 'għasa'},
#                                          'expansion': 'Maltese: għasa',
#                                          'name': 'desc'}],
#                           'text': 'Maltese: għasa'},
#                          {'depth': 1,
#                           'templates': [{'args': {'1': 'ary',
#                                                   '2': 'عصا',
#                                                   'tr': 'ʕṣā'},
#                                          'expansion': 'Moroccan Arabic: عصا '
#                                                       '(ʕṣā)',
#                                          'name': 'desc'}],
#                           'text': 'Moroccan Arabic: عصا (ʕṣā)'},
#                          {'depth': 1,
#                           'templates': [{'args': {'1': 'afb',
#                                                   '2': 'عصاية',
#                                                   'der': '1',
#                                                   'tr': 'ʕaṣāya'},
#                                          'expansion': '⇒ Gulf Arabic: عصاية '
#                                                       '(ʕaṣāya)',
#                                          'name': 'desc'}],
#                           'text': '⇒ Gulf Arabic: عصاية (ʕaṣāya)'},
#                          {'depth': 1,
#                           'templates': [{'args': {'1': 'acw',
#                                                   '2': 'عصاية',
#                                                   'der': '1',
#                                                   'tr': 'ʕaṣāya'},
#                                          'expansion': '⇒ Hijazi Arabic: عصاية '
#                                                       '(ʕaṣāya)',
#                                          'name': 'desc'}],
#                           'text': '⇒ Hijazi Arabic: عصاية (ʕaṣāya)'},
#                          {'depth': 1,
#                           'templates': [{'args': {'1': 'hy',
#                                                   '2': 'ասա',
#                                                   'bor': '1'},
#                                          'expansion': '→ Armenian: ասա (asa)',
#                                          'name': 'desc'}],
#                           'text': '→ Armenian: ասա (asa)'}],
#          'etymology_number': 1,
#          'etymology_templates': [{'args': {'1': 'ar',
#                                            '2': 'sem-pro',
#                                            '3': '*ʕiṣ́-'},
#                                   'expansion': 'Proto-Semitic *ʕiṣ́-',
#                                   'name': 'inh'},
#                                  {'args': {'1': 'he', '2': 'עֵץ', 'tr': 'ʿēṣ'},
#                                   'expansion': 'Hebrew עֵץ (ʿēṣ)',
#                                   'name': 'cog'}],
#          'etymology_text': 'From Proto-Semitic *ʕiṣ́-. Cognate with Hebrew עֵץ '
#                            '(ʿēṣ).',
#          'forms': [{'form': 'عَصًا', 'tags': ['canonical']},
#                    {'form': 'ʕaṣan', 'tags': ['romanization']},
#                    {'form': 'عَصَا', 'roman': 'ʕaṣā', 'tags': ['construct']},
#                    {'form': 'عَصَوَانِ', 'roman': 'ʕaṣawāni', 'tags': ['dual']},
#                    {'form': 'عُصِيّ', 'roman': 'ʕuṣiyy', 'tags': ['plural']},
#                    {'form': 'عِصِيّ', 'roman': 'ʕiṣiyy', 'tags': ['plural']},
#                    {'form': 'أَعْصٍ', 'roman': 'ʔaʕṣin', 'tags': ['plural']},
#                    {'form': 'أَعْصَاء', 'roman': 'ʔaʕṣāʔ', 'tags': ['plural']},
#                    {'form': '', 'source': 'declension', 'tags': ['table-tags']},
#                    {'form': 'ar-decl-noun',
#                     'source': 'declension',
#                     'tags': ['inflection-template']},
#                    {'form': 'عَصَا',
#                     'roman': 'ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'indefinite',
#                              'informal',
#                              'singular']},
#                    {'form': 'الْعَصَا',
#                     'roman': 'al-ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'definite',
#                              'informal',
#                              'singular']},
#                    {'form': 'عَصَا',
#                     'roman': 'ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'construct',
#                              'informal',
#                              'singular']},
#                    {'form': 'عَصًا',
#                     'roman': 'ʕaṣan',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'indefinite',
#                              'nominative',
#                              'singular']},
#                    {'form': 'الْعَصَا',
#                     'roman': 'al-ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'definite',
#                              'nominative',
#                              'singular']},
#                    {'form': 'عَصَا',
#                     'roman': 'ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'construct',
#                              'nominative',
#                              'singular']},
#                    {'form': 'عَصًا',
#                     'roman': 'ʕaṣan',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-an-alef',
#                              'indefinite',
#                              'singular']},
#                    {'form': 'الْعَصَا',
#                     'roman': 'al-ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-an-alef',
#                              'definite',
#                              'singular']},
#                    {'form': 'عَصَا',
#                     'roman': 'ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-an-alef',
#                              'construct',
#                              'singular']},
#                    {'form': 'عَصًا',
#                     'roman': 'ʕaṣan',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'genitive',
#                              'indefinite',
#                              'singular']},
#                    {'form': 'الْعَصَا',
#                     'roman': 'al-ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'definite',
#                              'genitive',
#                              'singular']},
#                    {'form': 'عَصَا',
#                     'roman': 'ʕaṣā',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'construct',
#                              'genitive',
#                              'singular']},
#                    {'form': 'عَصَوَيْن',
#                     'roman': 'ʕaṣawayn',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'dual',
#                              'indefinite',
#                              'informal',
#                              'singular']},
#                    {'form': 'الْعَصَوَيْن',
#                     'roman': 'al-ʕaṣawayn',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'definite',
#                              'dual',
#                              'informal',
#                              'singular']},
#                    {'form': 'عَصَوَيْ',
#                     'roman': 'ʕaṣaway',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'construct',
#                              'dual',
#                              'informal',
#                              'singular']},
#                    {'form': 'عَصَوَانِ',
#                     'roman': 'ʕaṣawāni',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'dual',
#                              'indefinite',
#                              'nominative',
#                              'singular']},
#                    {'form': 'الْعَصَوَانِ',
#                     'roman': 'al-ʕaṣawāni',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'definite',
#                              'dual',
#                              'nominative',
#                              'singular']},
#                    {'form': 'عَصَوَا',
#                     'roman': 'ʕaṣawā',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'construct',
#                              'dual',
#                              'nominative',
#                              'singular']},
#                    {'form': 'عَصَوَيْنِ',
#                     'roman': 'ʕaṣawayni',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-an-alef',
#                              'dual',
#                              'indefinite',
#                              'singular']},
#                    {'form': 'الْعَصَوَيْنِ',
#                     'roman': 'al-ʕaṣawayni',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-an-alef',
#                              'definite',
#                              'dual',
#                              'singular']},
#                    {'form': 'عَصَوَيْ',
#                     'roman': 'ʕaṣaway',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-an-alef',
#                              'construct',
#                              'dual',
#                              'singular']},
#                    {'form': 'عَصَوَيْنِ',
#                     'roman': 'ʕaṣawayni',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'dual',
#                              'genitive',
#                              'indefinite',
#                              'singular']},
#                    {'form': 'الْعَصَوَيْنِ',
#                     'roman': 'al-ʕaṣawayni',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'definite',
#                              'dual',
#                              'genitive',
#                              'singular']},
#                    {'form': 'عَصَوَيْ',
#                     'roman': 'ʕaṣaway',
#                     'source': 'declension',
#                     'tags': ['ar-infl-an-alef',
#                              'construct',
#                              'dual',
#                              'genitive',
#                              'singular']},
#                    {'form': 'عُصِي',
#                     'roman': 'ʕuṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عِصِي',
#                     'roman': 'ʕiṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصِي',
#                     'roman': 'ʔaʕṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصَاء',
#                     'roman': 'ʔaʕṣāʔ',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْعُصِي',
#                     'roman': 'al-ʕuṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْعِصِي',
#                     'roman': 'al-ʕiṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْأَعْصِي',
#                     'roman': 'al-ʔaʕṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْأَعْصَاء',
#                     'roman': 'al-ʔaʕṣāʔ',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عُصِي',
#                     'roman': 'ʕuṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عِصِي',
#                     'roman': 'ʕiṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصِي',
#                     'roman': 'ʔaʕṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصَاء',
#                     'roman': 'ʔaʕṣāʔ',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'informal',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عُصِيٌّ',
#                     'roman': 'ʕuṣiyyun',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عِصِيٌّ',
#                     'roman': 'ʕiṣiyyun',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصٍ',
#                     'roman': 'ʔaʕṣin',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصَاءٌ',
#                     'roman': 'ʔaʕṣāʔun',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْعُصِيُّ',
#                     'roman': 'al-ʕuṣiyyu',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْعِصِيُّ',
#                     'roman': 'al-ʕiṣiyyu',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْأَعْصِي',
#                     'roman': 'al-ʔaʕṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْأَعْصَاءُ',
#                     'roman': 'al-ʔaʕṣāʔu',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عُصِيُّ',
#                     'roman': 'ʕuṣiyyu',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عِصِيُّ',
#                     'roman': 'ʕiṣiyyu',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصِي',
#                     'roman': 'ʔaʕṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصَاءُ',
#                     'roman': 'ʔaʕṣāʔu',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'nominative',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عُصِيًّا',
#                     'roman': 'ʕuṣiyyan',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عِصِيًّا',
#                     'roman': 'ʕiṣiyyan',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصِيًا',
#                     'roman': 'ʔaʕṣiyan',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصَاءً',
#                     'roman': 'ʔaʕṣāʔan',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'indefinite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْعُصِيَّ',
#                     'roman': 'al-ʕuṣiyya',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْعِصِيَّ',
#                     'roman': 'al-ʕiṣiyya',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْأَعْصِيَ',
#                     'roman': 'al-ʔaʕṣiya',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْأَعْصَاءَ',
#                     'roman': 'al-ʔaʕṣāʔa',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عُصِيَّ',
#                     'roman': 'ʕuṣiyya',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عِصِيَّ',
#                     'roman': 'ʕiṣiyya',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصِيَ',
#                     'roman': 'ʔaʕṣiya',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصَاءَ',
#                     'roman': 'ʔaʕṣāʔa',
#                     'source': 'declension',
#                     'tags': ['accusative',
#                              'ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عُصِيٍّ',
#                     'roman': 'ʕuṣiyyin',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'genitive',
#                              'indefinite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عِصِيٍّ',
#                     'roman': 'ʕiṣiyyin',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'genitive',
#                              'indefinite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصٍ',
#                     'roman': 'ʔaʕṣin',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'genitive',
#                              'indefinite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصَاءٍ',
#                     'roman': 'ʔaʕṣāʔin',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'genitive',
#                              'indefinite',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْعُصِيِّ',
#                     'roman': 'al-ʕuṣiyyi',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'genitive',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْعِصِيِّ',
#                     'roman': 'al-ʕiṣiyyi',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'genitive',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْأَعْصِي',
#                     'roman': 'al-ʔaʕṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'genitive',
#                              'plural',
#                              'triptote']},
#                    {'form': 'الْأَعْصَاءِ',
#                     'roman': 'al-ʔaʕṣāʔi',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'definite',
#                              'genitive',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عُصِيِّ',
#                     'roman': 'ʕuṣiyyi',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'genitive',
#                              'plural',
#                              'triptote']},
#                    {'form': 'عِصِيِّ',
#                     'roman': 'ʕiṣiyyi',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'genitive',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصِي',
#                     'roman': 'ʔaʕṣī',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'genitive',
#                              'plural',
#                              'triptote']},
#                    {'form': 'أَعْصَاءِ',
#                     'roman': 'ʔaʕṣāʔi',
#                     'source': 'declension',
#                     'tags': ['ar-infl-in',
#                              'broken-form',
#                              'construct',
#                              'genitive',
#                              'plural',
#                              'triptote']}],
#          'head_templates': [{'args': {'1': 'عَصًا',
#                                       '2': 'f',
#                                       'cons': 'عَصَا',
#                                       'd': 'عَصَوَانِ',
#                                       'pl': 'عُصِيّ',
#                                       'pl2': 'عِصِيّ',
#                                       'pl3': 'أَعْصٍ',
#                                       'pl4': 'أَعْصَاء'},
#                              'expansion': 'عَصًا • (ʕaṣan) f (construct state '
#                                           'عَصَا (ʕaṣā), dual عَصَوَانِ '
#                                           '(ʕaṣawāni), plural عُصِيّ (ʕuṣiyy) '
#                                           'or عِصِيّ (ʕiṣiyy) or أَعْصٍ '
#                                           '(ʔaʕṣin) or أَعْصَاء (ʔaʕṣāʔ))',
#                              'name': 'ar-noun'}],
#          'inflection_templates': [{'args': {'1': 'عَصًا',
#                                             'd': 'عَصَوَانِ',
#                                             'pl': 'عُصِيّ',
#                                             'pl2': 'عِصِيّ',
#                                             'pl3': 'أَعْصٍ',
#                                             'pl4': 'أَعْصَاء'},
#                                    'name': 'ar-decl-noun'}],
#          'lang': 'Arabic',
#          'lang_code': 'ar',
#          'pos': 'noun',
#          'senses': [{'glosses': ['staff, stick'],
#                      'links': [['staff', 'staff'], ['stick', 'stick']]},
#                     {'glosses': ['punishment, chastisement'],
#                      'links': [['punishment', 'punishment'],
#                                ['chastisement', 'chastisement']]},
#                     {'glosses': ['wooden handle'],
#                      'links': [['wooden', 'wooden'], ['handle', 'handle']]},
#                     {'glosses': ['scepter'], 'links': [['scepter', 'scepter']]},
#                     {'glosses': ['crosier'], 'links': [['crosier', 'crosier']]},
#                     {'glosses': ['dominion'],
#                      'links': [['dominion', 'dominion']]},
#                     {'glosses': ['penis'], 'links': [['penis', 'penis']]},
#                     {'glosses': ['lingual bone, tongue'],
#                      'links': [['lingual', 'lingual'],
#                                ['bone', 'bone'],
#                                ['tongue', 'tongue']]},
#                     {'glosses': ['Muslim fraternity or a community in general'],
#                      'links': [['Muslim', 'Muslim'],
#                                ['fraternity', 'fraternity'],
#                                ['community', 'community']]}],
#          'sounds': [{'ipa': '/ʕa.sˤan/'},
#                     {'ipa': '/ʕa.sˤaː/'},
#                     {'homophone': 'عَصَى (ʕaṣā)'}]}}
#
# 12010
# {'عصا': {'categories': ['Arabic 2-syllable words',
#                         'Arabic final-weak form-I verbs',
#                         'Arabic final-weak verbs',
#                         'Arabic final-weak verbs by conjugation',
#                         'Arabic form-I verbs',
#                         'Arabic form-I verbs with و as third radical',
#                         'Arabic lemmas',
#                         'Arabic terms with IPA pronunciation',
#                         'Arabic terms with homophones',
#                         'Arabic verbs',
#                         'Terms with redundant transliterations',
#                         'Terms with redundant transliterations/ar'],
#          'etymology_number': 2,
#          'etymology_templates': [{'args': {'1': 'ع ص و'},
#                                   'expansion': 'ع ص و (ʕ-ṣ-w)',
#                                   'name': 'ar-root'}],
#          'etymology_text': 'From the root ع ص و (ʕ-ṣ-w).',
#          'forms': [{'form': 'يَعْصُو', 'roman': 'yaʕṣū', 'tags': ['non-past']},
#                    {'form': 'عَصَا', 'tags': ['canonical']},
#                    {'form': 'ʕaṣā', 'tags': ['romanization']},
#                    {'form': 'weak',
#                     'source': 'conjugation',
#                     'tags': ['table-tags']},
#                    {'form': 'ar-conj',
#                     'source': 'conjugation',
#                     'tags': ['inflection-template']},
#                    {'form': 'عَصْو',
#                     'roman': 'ʕaṣw',
#                     'source': 'conjugation',
#                     'tags': ['noun-from-verb']},
#                    {'form': 'عَاصٍ',
#                     'roman': 'ʕāṣin',
#                     'source': 'conjugation',
#                     'tags': ['active', 'participle']},
#                    {'form': 'مَعْصُوّ',
#                     'roman': 'maʕṣuww',
#                     'source': 'conjugation',
#                     'tags': ['participle', 'passive']},
#                    {'form': 'عَصَوْتُ',
#                     'roman': 'ʕaṣawtu',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'first-person',
#                              'indicative',
#                              'masculine',
#                              'past',
#                              'perfective',
#                              'singular']},
#                    {'form': 'عَصَوْتَ',
#                     'roman': 'ʕaṣawta',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'indicative',
#                              'masculine',
#                              'past',
#                              'perfective',
#                              'second-person',
#                              'singular']},
#                    {'form': 'عَصَا',
#                     'roman': 'ʕaṣā',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'indicative',
#                              'masculine',
#                              'past',
#                              'perfective',
#                              'singular',
#                              'third-person']},
#                    {'form': 'عَصَوْتُمَا',
#                     'roman': 'ʕaṣawtumā',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'dual',
#                              'indicative',
#                              'masculine',
#                              'past',
#                              'perfective',
#                              'second-person']},
#                    {'form': 'عَصَوَا',
#                     'roman': 'ʕaṣawā',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'dual',
#                              'indicative',
#                              'masculine',
#                              'past',
#                              'perfective',
#                              'third-person']},
#                    {'form': 'عَصَوْنَا',
#                     'roman': 'ʕaṣawnā',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'first-person',
#                              'indicative',
#                              'masculine',
#                              'past',
#                              'perfective',
#                              'plural']},
#                    {'form': 'عَصَوْتُمْ',
#                     'roman': 'ʕaṣawtum',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'indicative',
#                              'masculine',
#                              'past',
#                              'perfective',
#                              'plural',
#                              'second-person']},
#                    {'form': 'عَصَوْا',
#                     'roman': 'ʕaṣaw',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'indicative',
#                              'masculine',
#                              'past',
#                              'perfective',
#                              'plural',
#                              'third-person']},
#                    {'form': 'عَصَوْتُ',
#                     'roman': 'ʕaṣawtu',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'first-person',
#                              'indicative',
#                              'past',
#                              'perfective',
#                              'singular']},
#                    {'form': 'عَصَوْتِ',
#                     'roman': 'ʕaṣawti',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'indicative',
#                              'past',
#                              'perfective',
#                              'second-person',
#                              'singular']},
#                    {'form': 'عَصَتْ',
#                     'roman': 'ʕaṣat',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'indicative',
#                              'past',
#                              'perfective',
#                              'singular',
#                              'third-person']},
#                    {'form': 'عَصَوْتُمَا',
#                     'roman': 'ʕaṣawtumā',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'dual',
#                              'feminine',
#                              'indicative',
#                              'past',
#                              'perfective',
#                              'second-person']},
#                    {'form': 'عَصَتَا',
#                     'roman': 'ʕaṣatā',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'dual',
#                              'feminine',
#                              'indicative',
#                              'past',
#                              'perfective',
#                              'third-person']},
#                    {'form': 'عَصَوْنَا',
#                     'roman': 'ʕaṣawnā',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'first-person',
#                              'indicative',
#                              'past',
#                              'perfective',
#                              'plural']},
#                    {'form': 'عَصَوْتُنَّ',
#                     'roman': 'ʕaṣawtunna',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'indicative',
#                              'past',
#                              'perfective',
#                              'plural',
#                              'second-person']},
#                    {'form': 'عَصَوْنَ',
#                     'roman': 'ʕaṣawna',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'indicative',
#                              'past',
#                              'perfective',
#                              'plural',
#                              'third-person']},
#                    {'form': 'أَعْصُو',
#                     'roman': 'ʔaʕṣū',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'first-person',
#                              'imperfective',
#                              'indicative',
#                              'masculine',
#                              'non-past',
#                              'singular']},
#                    {'form': 'تَعْصُو',
#                     'roman': 'taʕṣū',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'imperfective',
#                              'indicative',
#                              'masculine',
#                              'non-past',
#                              'second-person',
#                              'singular']},
#                    {'form': 'يَعْصُو',
#                     'roman': 'yaʕṣū',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'imperfective',
#                              'indicative',
#                              'masculine',
#                              'non-past',
#                              'singular',
#                              'third-person']},
#                    {'form': 'تَعْصُوَانِ',
#                     'roman': 'taʕṣuwāni',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'dual',
#                              'imperfective',
#                              'indicative',
#                              'masculine',
#                              'non-past',
#                              'second-person']},
#                    {'form': 'يَعْصُوَانِ',
#                     'roman': 'yaʕṣuwāni',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'dual',
#                              'imperfective',
#                              'indicative',
#                              'masculine',
#                              'non-past',
#                              'third-person']},
#                    {'form': 'نَعْصُو',
#                     'roman': 'naʕṣū',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'first-person',
#                              'imperfective',
#                              'indicative',
#                              'masculine',
#                              'non-past',
#                              'plural']},
#                    {'form': 'تَعْصُونَ',
#                     'roman': 'taʕṣūna',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'imperfective',
#                              'indicative',
#                              'masculine',
#                              'non-past',
#                              'plural',
#                              'second-person']},
#                    {'form': 'يَعْصُونَ',
#                     'roman': 'yaʕṣūna',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'imperfective',
#                              'indicative',
#                              'masculine',
#                              'non-past',
#                              'plural',
#                              'third-person']},
#                    {'form': 'أَعْصُو',
#                     'roman': 'ʔaʕṣū',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'first-person',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'singular']},
#                    {'form': 'تَعْصِينَ',
#                     'roman': 'taʕṣīna',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'second-person',
#                              'singular']},
#                    {'form': 'تَعْصُو',
#                     'roman': 'taʕṣū',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'singular',
#                              'third-person']},
#                    {'form': 'تَعْصُوَانِ',
#                     'roman': 'taʕṣuwāni',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'dual',
#                              'feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'second-person']},
#                    {'form': 'تَعْصُوَانِ',
#                     'roman': 'taʕṣuwāni',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'dual',
#                              'feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'third-person']},
#                    {'form': 'نَعْصُو',
#                     'roman': 'naʕṣū',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'first-person',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'plural']},
#                    {'form': 'تَعْصُونَ',
#                     'roman': 'taʕṣūna',
#                     'source': 'conjugation',
#                     'tags': ['active',
#                              'feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'plural',
# ...
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'passive',
#                              'singular']},
#                    {'form': 'تُعْصَيْنَ',
#                     'roman': 'tuʕṣayna',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'passive',
#                              'second-person',
#                              'singular']},
#                    {'form': 'تُعْصَى',
#                     'roman': 'tuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'passive',
#                              'singular',
#                              'third-person']},
#                    {'form': 'تُعْصَيَانِ',
#                     'roman': 'tuʕṣayāni',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'passive',
#                              'second-person']},
#                    {'form': 'تُعْصَيَانِ',
#                     'roman': 'tuʕṣayāni',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'passive',
#                              'third-person']},
#                    {'form': 'نُعْصَى',
#                     'roman': 'nuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'first-person',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'passive',
#                              'plural']},
#                    {'form': 'تُعْصَيْنَ',
#                     'roman': 'tuʕṣayna',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'passive',
#                              'plural',
#                              'second-person']},
#                    {'form': 'يُعْصَيْنَ',
#                     'roman': 'yuʕṣayna',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'imperfective',
#                              'indicative',
#                              'non-past',
#                              'passive',
#                              'plural',
#                              'third-person']},
#                    {'form': 'أُعْصَى',
#                     'roman': 'ʔuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['first-person',
#                              'masculine',
#                              'passive',
#                              'singular',
#                              'subjunctive']},
#                    {'form': 'تُعْصَى',
#                     'roman': 'tuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['masculine',
#                              'passive',
#                              'second-person',
#                              'singular',
#                              'subjunctive']},
#                    {'form': 'يُعْصَى',
#                     'roman': 'yuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['masculine',
#                              'passive',
#                              'singular',
#                              'subjunctive',
#                              'third-person']},
#                    {'form': 'تُعْصَيَا',
#                     'roman': 'tuʕṣayā',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'masculine',
#                              'passive',
#                              'second-person',
#                              'subjunctive']},
#                    {'form': 'يُعْصَيَا',
#                     'roman': 'yuʕṣayā',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'masculine',
#                              'passive',
#                              'subjunctive',
#                              'third-person']},
#                    {'form': 'نُعْصَى',
#                     'roman': 'nuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['first-person',
#                              'masculine',
#                              'passive',
#                              'plural',
#                              'subjunctive']},
#                    {'form': 'تُعْصَوْا',
#                     'roman': 'tuʕṣaw',
#                     'source': 'conjugation',
#                     'tags': ['masculine',
#                              'passive',
#                              'plural',
#                              'second-person',
#                              'subjunctive']},
#                    {'form': 'يُعْصَوْا',
#                     'roman': 'yuʕṣaw',
#                     'source': 'conjugation',
#                     'tags': ['masculine',
#                              'passive',
#                              'plural',
#                              'subjunctive',
#                              'third-person']},
#                    {'form': 'أُعْصَى',
#                     'roman': 'ʔuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'first-person',
#                              'passive',
#                              'singular',
#                              'subjunctive']},
#                    {'form': 'تُعْصَيْ',
#                     'roman': 'tuʕṣay',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'passive',
#                              'second-person',
#                              'singular',
#                              'subjunctive']},
#                    {'form': 'تُعْصَى',
#                     'roman': 'tuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'passive',
#                              'singular',
#                              'subjunctive',
#                              'third-person']},
#                    {'form': 'تُعْصَيَا',
#                     'roman': 'tuʕṣayā',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'feminine',
#                              'passive',
#                              'second-person',
#                              'subjunctive']},
#                    {'form': 'تُعْصَيَا',
#                     'roman': 'tuʕṣayā',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'feminine',
#                              'passive',
#                              'subjunctive',
#                              'third-person']},
#                    {'form': 'نُعْصَى',
#                     'roman': 'nuʕṣā',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'first-person',
#                              'passive',
#                              'plural',
#                              'subjunctive']},
#                    {'form': 'تُعْصَيْنَ',
#                     'roman': 'tuʕṣayna',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'passive',
#                              'plural',
#                              'second-person',
#                              'subjunctive']},
#                    {'form': 'يُعْصَيْنَ',
#                     'roman': 'yuʕṣayna',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'passive',
#                              'plural',
#                              'subjunctive',
#                              'third-person']},
#                    {'form': 'أُعْصَ',
#                     'roman': 'ʔuʕṣa',
#                     'source': 'conjugation',
#                     'tags': ['first-person',
#                              'jussive',
#                              'masculine',
#                              'passive',
#                              'singular']},
#                    {'form': 'تُعْصَ',
#                     'roman': 'tuʕṣa',
#                     'source': 'conjugation',
#                     'tags': ['jussive',
#                              'masculine',
#                              'passive',
#                              'second-person',
#                              'singular']},
#                    {'form': 'يُعْصَ',
#                     'roman': 'yuʕṣa',
#                     'source': 'conjugation',
#                     'tags': ['jussive',
#                              'masculine',
#                              'passive',
#                              'singular',
#                              'third-person']},
#                    {'form': 'تُعْصَيَا',
#                     'roman': 'tuʕṣayā',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'jussive',
#                              'masculine',
#                              'passive',
#                              'second-person']},
#                    {'form': 'يُعْصَيَا',
#                     'roman': 'yuʕṣayā',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'jussive',
#                              'masculine',
#                              'passive',
#                              'third-person']},
#                    {'form': 'نُعْصَ',
#                     'roman': 'nuʕṣa',
#                     'source': 'conjugation',
#                     'tags': ['first-person',
#                              'jussive',
#                              'masculine',
#                              'passive',
#                              'plural']},
#                    {'form': 'تُعْصَوْا',
#                     'roman': 'tuʕṣaw',
#                     'source': 'conjugation',
#                     'tags': ['jussive',
#                              'masculine',
#                              'passive',
#                              'plural',
#                              'second-person']},
#                    {'form': 'يُعْصَوْا',
#                     'roman': 'yuʕṣaw',
#                     'source': 'conjugation',
#                     'tags': ['jussive',
#                              'masculine',
#                              'passive',
#                              'plural',
#                              'third-person']},
#                    {'form': 'أُعْصَ',
#                     'roman': 'ʔuʕṣa',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'first-person',
#                              'jussive',
#                              'passive',
#                              'singular']},
#                    {'form': 'تُعْصَيْ',
#                     'roman': 'tuʕṣay',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'jussive',
#                              'passive',
#                              'second-person',
#                              'singular']},
#                    {'form': 'تُعْصَ',
#                     'roman': 'tuʕṣa',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'jussive',
#                              'passive',
#                              'singular',
#                              'third-person']},
#                    {'form': 'تُعْصَيَا',
#                     'roman': 'tuʕṣayā',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'feminine',
#                              'jussive',
#                              'passive',
#                              'second-person']},
#                    {'form': 'تُعْصَيَا',
#                     'roman': 'tuʕṣayā',
#                     'source': 'conjugation',
#                     'tags': ['dual',
#                              'feminine',
#                              'jussive',
#                              'passive',
#                              'third-person']},
#                    {'form': 'نُعْصَ',
#                     'roman': 'nuʕṣa',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'first-person',
#                              'jussive',
#                              'passive',
#                              'plural']},
#                    {'form': 'تُعْصَيْنَ',
#                     'roman': 'tuʕṣayna',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'jussive',
#                              'passive',
#                              'plural',
#                              'second-person']},
#                    {'form': 'يُعْصَيْنَ',
#                     'roman': 'yuʕṣayna',
#                     'source': 'conjugation',
#                     'tags': ['feminine',
#                              'jussive',
#                              'passive',
#                              'plural',
#                              'third-person']}],
#          'head_templates': [{'args': {'1': 'I', '2': 'a', '3': 'u', 'III': 'و'},
#                              'expansion': 'عَصَا • (ʕaṣā) I, non-past يَعْصُو '
#                                           '(yaʕṣū)',
#                              'name': 'ar-verb'}],
#          'inflection_templates': [{'args': {'1': 'I',
#                                             '2': 'a',
#                                             '3': 'u',
#                                             'III': 'و',
#                                             'vn': 'عَصْو'},
#                                    'name': 'ar-conj'}],
#          'lang': 'Arabic',
#          'lang_code': 'ar',
#          'pos': 'verb',
#          'senses': [{'glosses': ['to beat or strike with a stick, sword, or '
#                                  'staff; to use, handle, wield, equip any of '
#                                  'the above.'],
#                      'links': [['beat', 'beat'],
#                                ['strike', 'strike'],
#                                ['stick', 'stick'],
#                                ['sword', 'sword'],
#                                ['staff', 'staff'],
#                                ['use', 'use'],
#                                ['handle', 'handle'],
#                                ['wield', 'wield'],
#                                ['equip', 'equip']]},
#                     {'glosses': ['to dress wound, to use a splint on a wound'],
#                      'links': [['dress', 'dress'],
#                                ['wound', 'wound'],
#                                ['use', 'use'],
#                                ['splint', 'splint']]},
#                     {'glosses': ['to unite people for a purpose, to shepherd '
#                                  'people together'],
#                      'links': [['unite', 'unite'],
#                                ['people', 'people'],
#                                ['purpose', 'purpose'],
#                                ['shepherd', 'shepherd'],
#                                ['together', 'together']]}],
#          'sounds': [{'ipa': '/ʕa.sˤaː/'}, {'homophone': 'عَصَى (ʕaṣā)'}]}}

# %% [markdown]
# ## 4.2 View Random Dictionary

# %% [markdown]
# View dictionaries to check where to find the information

# %%
# show sample example
random_word = choice(list(wiki_idxs.keys()))
random_word_idxs = wiki_idxs[random_word]
print("word, idx:", random_word, random_word_idxs)
# Out:
# word, idx: تجهدون [81531, 81532, 81533, 81534]

# %%
pprint(wikitionary[choice(random_word_idxs)])
# Out:
# {'تجهدون': {'categories': ['Arabic non-lemma forms', 'Arabic verb forms'],
#             'etymology_number': 1,
#             'etymology_templates': [],
#             'etymology_text': '',
#             'forms': [{'form': 'تُجْهَدُونَ', 'tags': ['canonical']},
#                       {'form': 'tujhadūna', 'tags': ['romanization']}],
#             'head_templates': [{'args': {'1': 'تُجْهَدُونَ', '2': 'I'},
#                                 'expansion': 'تُجْهَدُونَ • (tujhadūna) (form '
#                                              'I)',
#                                 'name': 'ar-verb-form'}],
#             'lang': 'Arabic',
#             'lang_code': 'ar',
#             'pos': 'verb',
#             'senses': [{'form_of': [{'extra': 'jahada', 'word': 'جَهَدَ'}],
#                         'glosses': ['second-person masculine plural non-past '
#                                     'passive indicative of جَهَدَ (jahada)'],
#                         'links': [['جَهَدَ', 'جهد#Arabic']],
#                         'tags': ['form-i',
#                                  'form-of',
#                                  'indicative',
#                                  'masculine',
#                                  'non-past',
#                                  'passive',
#                                  'plural',
#                                  'second-person']}]}}

# %% [markdown]
# # 4.3 View Wikitionary By Index

# %%
wiki_idx = 10506
pprint(wikitionary[wiki_idx])
# Out:
# {'اسلنطح': {'categories': ['Arabic form-IIIq verbs',
#                            'Arabic lemmas',
#                            'Arabic sound form-IIIq verbs',
#                            'Arabic sound verbs',
#                            'Arabic sound verbs by conjugation',
#                            'Arabic verbs',
#                            'Arabic verbs with quadriliteral roots',
#                            'Terms with redundant transliterations',
#                            'Terms with redundant transliterations/ar'],
#             'etymology_templates': [{'args': {'1': 'س ل ط ح'},
#                                      'expansion': 'س ل ط ح (s-l-ṭ-ḥ)',
#                                      'name': 'ar-root'},
#                                     {'args': {'1': 'ar',
#                                               '2': 'سُلْطُح',
#                                               '3': '',
#                                               '4': 'slanting, rising '
#                                                    'gradually'},
#                                      'expansion': 'سُلْطُح (sulṭuḥ, “slanting, '
#                                                   'rising gradually”)',
#                                      'name': 'm'}],
#             'etymology_text': 'From the root س ل ط ح (s-l-ṭ-ḥ); possibly '
#                               'related to سُلْطُح (sulṭuḥ, “slanting, rising '
#                               'gradually”).',
#             'forms': [{'form': 'يَسْلَنْطِحُ',
#                        'roman': 'yaslanṭiḥu',
#                        'tags': ['non-past']},
#                       {'form': 'اِسْلَنْطَحَ', 'tags': ['canonical']},
#                       {'form': 'islanṭaḥa', 'tags': ['romanization']},
#                       {'form': '',
#                        'source': 'conjugation',
#                        'tags': ['table-tags']},
#                       {'form': 'ar-conj',
#                        'source': 'conjugation',
#                        'tags': ['inflection-template']},
#                       {'form': 'اِسْلِنْطَاح',
#                        'roman': 'islinṭāḥ',
#                        'source': 'conjugation',
#                        'tags': ['noun-from-verb']},
#                       {'form': 'مُسْلَنْطِح',
#                        'roman': 'muslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active', 'participle']},
#                       {'form': 'مُسْلَنْطَح',
#                        'roman': 'muslanṭaḥ',
#                        'source': 'conjugation',
#                        'tags': ['participle', 'passive']},
#                       {'form': 'اِسْلَنْطَحْتُ',
#                        'roman': 'islanṭaḥtu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطَحْتَ',
#                        'roman': 'islanṭaḥta',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطَحَ',
#                        'roman': 'islanṭaḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْتُمَا',
#                        'roman': 'islanṭaḥtumā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطَحَا',
#                        'roman': 'islanṭaḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْنَا',
#                        'roman': 'islanṭaḥnā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'plural']},
#                       {'form': 'اِسْلَنْطَحْتُمْ',
#                        'roman': 'islanṭaḥtum',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطَحُوا',
#                        'roman': 'islanṭaḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'indicative',
#                                 'masculine',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْتُ',
#                        'roman': 'islanṭaḥtu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطَحْتِ',
#                        'roman': 'islanṭaḥti',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطَحَتْ',
#                        'roman': 'islanṭaḥat',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْتُمَا',
#                        'roman': 'islanṭaḥtumā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطَحَتَا',
#                        'roman': 'islanṭaḥatā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطَحْنَا',
#                        'roman': 'islanṭaḥnā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'plural']},
#                       {'form': 'اِسْلَنْطَحْتُنَّ',
#                        'roman': 'islanṭaḥtunna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطَحْنَ',
#                        'roman': 'islanṭaḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'indicative',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحُ',
#                        'roman': 'ʔaslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحُ',
#                        'roman': 'taslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'يَسْلَنْطِحُ',
#                        'roman': 'yaslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَانِ',
#                        'roman': 'taslanṭiḥāni',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحَانِ',
#                        'roman': 'yaslanṭiḥāni',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحُ',
#                        'roman': 'naslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'plural']},
#                       {'form': 'تَسْلَنْطِحُونَ',
#                        'roman': 'taslanṭiḥūna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحُونَ',
#                        'roman': 'yaslanṭiḥūna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحُ',
#                        'roman': 'ʔaslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحِينَ',
#                        'roman': 'taslanṭiḥīna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحُ',
#                        'roman': 'taslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَانِ',
#                        'roman': 'taslanṭiḥāni',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'second-person']},
#                       {'form': 'تَسْلَنْطِحَانِ',
#                        'roman': 'taslanṭiḥāni',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحُ',
#                        'roman': 'naslanṭiḥu',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'plural']},
#                       {'form': 'تَسْلَنْطِحْنَ',
#                        'roman': 'taslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحْنَ',
#                        'roman': 'yaslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحَ',
#                        'roman': 'ʔaslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'masculine',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحَ',
#                        'roman': 'taslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'masculine',
#                                 'second-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'يَسْلَنْطِحَ',
#                        'roman': 'yaslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'masculine',
#                                 'singular',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'masculine',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': 'يَسْلَنْطِحَا',
#                        'roman': 'yaslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'masculine',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحَ',
#                        'roman': 'naslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'masculine',
#                                 'plural',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحُوا',
#                        'roman': 'taslanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'masculine',
#                                 'plural',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': 'يَسْلَنْطِحُوا',
#                        'roman': 'yaslanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'masculine',
#                                 'plural',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحَ',
#                        'roman': 'ʔaslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحِي',
#                        'roman': 'taslanṭiḥī',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'second-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحَ',
#                        'roman': 'taslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'singular',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحَ',
#                        'roman': 'naslanṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'plural',
#                                 'subjunctive']},
#                       {'form': 'تَسْلَنْطِحْنَ',
#                        'roman': 'taslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'plural',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': 'يَسْلَنْطِحْنَ',
#                        'roman': 'yaslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'plural',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحْ',
#                        'roman': 'ʔaslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'jussive',
#                                 'masculine',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحْ',
#                        'roman': 'taslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'jussive',
#                                 'masculine',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'يَسْلَنْطِحْ',
#                        'roman': 'yaslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'jussive',
#                                 'masculine',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'jussive',
#                                 'masculine',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحَا',
#                        'roman': 'yaslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'jussive',
#                                 'masculine',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحْ',
#                        'roman': 'naslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'first-person',
#                                 'jussive',
#                                 'masculine',
#                                 'plural']},
#                       {'form': 'تَسْلَنْطِحُوا',
#                        'roman': 'taslanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'jussive',
#                                 'masculine',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحُوا',
#                        'roman': 'yaslanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'jussive',
#                                 'masculine',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'أَسْلَنْطِحْ',
#                        'roman': 'ʔaslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'jussive',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحِي',
#                        'roman': 'taslanṭiḥī',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'jussive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'تَسْلَنْطِحْ',
#                        'roman': 'taslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'jussive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'jussive',
#                                 'second-person']},
#                       {'form': 'تَسْلَنْطِحَا',
#                        'roman': 'taslanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'jussive',
#                                 'third-person']},
#                       {'form': 'نَسْلَنْطِحْ',
#                        'roman': 'naslanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'first-person',
#                                 'jussive',
#                                 'plural']},
#                       {'form': 'تَسْلَنْطِحْنَ',
#                        'roman': 'taslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'jussive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'يَسْلَنْطِحْنَ',
#                        'roman': 'yaslanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'jussive',
#                                 'plural',
#                                 'third-person']},
#                       {'form': 'اِسْلَنْطِحْ',
#                        'roman': 'islanṭiḥ',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperative',
#                                 'masculine',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطِحَا',
#                        'roman': 'islanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'imperative',
#                                 'masculine',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطِحُوا',
#                        'roman': 'islanṭiḥū',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'imperative',
#                                 'masculine',
#                                 'plural',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطِحِي',
#                        'roman': 'islanṭiḥī',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperative',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اِسْلَنْطِحَا',
#                        'roman': 'islanṭiḥā',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'dual',
#                                 'feminine',
#                                 'imperative',
#                                 'second-person']},
#                       {'form': 'اِسْلَنْطِحْنَ',
#                        'roman': 'islanṭiḥna',
#                        'source': 'conjugation',
#                        'tags': ['active',
#                                 'feminine',
#                                 'imperative',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'اُسْلُنْطِحَ',
#                        'roman': 'uslunṭiḥa',
#                        'source': 'conjugation',
#                        'tags': ['indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['indicative',
#                                 'masculine',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'second-person',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'indicative',
#                                 'passive',
#                                 'past',
#                                 'perfective',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'يُسْلَنْطَحُ',
#                        'roman': 'yuslanṭaḥu',
#                        'source': 'conjugation',
#                        'tags': ['imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['imperfective',
#                                 'indicative',
#                                 'masculine',
#                                 'non-past',
#                                 'passive',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'imperfective',
#                                 'indicative',
#                                 'non-past',
#                                 'passive',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'masculine',
#                                 'passive',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['masculine',
#                                 'passive',
#                                 'second-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': 'يُسْلَنْطَحَ',
#                        'roman': 'yuslanṭaḥa',
#                        'source': 'conjugation',
#                        'tags': ['masculine',
#                                 'passive',
#                                 'singular',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'masculine',
#                                 'passive',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'masculine',
#                                 'passive',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'masculine',
#                                 'passive',
#                                 'plural',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['masculine',
#                                 'passive',
#                                 'plural',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['masculine',
#                                 'passive',
#                                 'plural',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'passive',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'passive',
#                                 'second-person',
#                                 'singular',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'passive',
#                                 'singular',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'passive',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'passive',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'passive',
#                                 'plural',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'passive',
#                                 'plural',
#                                 'second-person',
#                                 'subjunctive']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'passive',
#                                 'plural',
#                                 'subjunctive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'jussive',
#                                 'masculine',
#                                 'passive',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['jussive',
#                                 'masculine',
#                                 'passive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': 'يُسْلَنْطَحْ',
#                        'roman': 'yuslanṭaḥ',
#                        'source': 'conjugation',
#                        'tags': ['jussive',
#                                 'masculine',
#                                 'passive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'jussive',
#                                 'masculine',
#                                 'passive',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'jussive',
#                                 'masculine',
#                                 'passive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['first-person',
#                                 'jussive',
#                                 'masculine',
#                                 'passive',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['jussive',
#                                 'masculine',
#                                 'passive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['jussive',
#                                 'masculine',
#                                 'passive',
#                                 'plural',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'jussive',
#                                 'passive',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'jussive',
#                                 'passive',
#                                 'second-person',
#                                 'singular']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'jussive',
#                                 'passive',
#                                 'singular',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'jussive',
#                                 'passive',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['dual',
#                                 'feminine',
#                                 'jussive',
#                                 'passive',
#                                 'third-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'first-person',
#                                 'jussive',
#                                 'passive',
#                                 'plural']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'jussive',
#                                 'passive',
#                                 'plural',
#                                 'second-person']},
#                       {'form': '-',
#                        'source': 'conjugation',
#                        'tags': ['feminine',
#                                 'jussive',
#                                 'passive',
#                                 'plural',
#                                 'third-person']}],
#             'head_templates': [{'args': {'1': 'IIIq'},
#                                 'expansion': 'اِسْلَنْطَحَ • (islanṭaḥa) IIIq, '
#                                              'non-past يَسْلَنْطِحُ '
#                                              '(yaslanṭiḥu)',
#                                 'name': 'ar-verb'}],
#             'inflection_templates': [{'args': {'1': 'IIIq',
#                                                'passive': 'impers?'},
#                                       'name': 'ar-conj'}],
#             'lang': 'Arabic',
#             'lang_code': 'ar',
#             'pos': 'verb',
#             'senses': [{'glosses': ['to fall on the face'],
#                         'links': [['fall', 'fall'], ['face', 'face']]},
#                        {'glosses': ['to be long and wide'],
#                         'links': [['long', 'long'], ['wide', 'wide']]}]}}

# %% [markdown]
# # 5.0 Check Values in Wikitionaries

# %% [markdown]
# ## 5.1 Check Values in Categories

# %% [markdown]
# - List `categories` values in:
#   - `WIKITIONARY_DICT["categories"]: List[str]`
#   - `Senses[i]["categories"]` where `senses` is `WIKITIONARY_DICT["senses"]: List[Dict[str: List[str]]]`

# %%
import re

pattern = r'^(I|II|III|IV|V|VI|VII|VIII|IX|X|XI)$'


categories_values = set()
verb_forms = set()
for i, entry in enumerate(wikitionary):
    verb_form = []
    for _, word_data in entry.items():
        values = word_data.get("categories", [])
        if word_data["pos"] != "verb":
            continue
        for value in values:
            if match := re.search(r"(?<=form-)\w+(?= verbs)", value):
                if match.group() == "IIIq":
                    print(i)
                verb_form.append(match.group())
            categories_values.update(values)
    verb_forms.update([" ".join(verb_form)])
        # for sense in word_data.get("senses", []):
        #     if categories_senses := sense.get("categories", []):
        #         categories_values.update(categories_senses)

# pprint(sorted(list(categories_values)))
pprint(verb_forms)
# Out:
# 10506
# 10506
# 22473
# 22473
# 23260
# 23260
# 24582
# 24582
# 24596
# 24596
# {'',
#  'I I',
#  'I I I',
#  'I I I I',
#  'I I I I I',
#  'I I I I I I',
#  'I I I I I I I',
#  'I I II II I II',
#  'I I III III I',
#  'I I IV IV I',
#  'I II I I I II II II I II',
#  'I II I I II',
#  'I II I I II II',
#  'I II I II',
#  'I II I II I I I II II',
#  'I II I II I I I II II II',
#  'I II I II II',
#  'II II',
#  'II II II',
#  'II II II II',
#  'II II II II II',
#  'II II II II II II',
#  'II II IV IV II',
#  'III III',
#  'III III III',
#  'III III III III',
#  'III III III III III',
#  'III III IV IV III IV',
#  'III IV III III III IV IV IV III IV',
#  'IIIq IIIq',
#  'IIq IIq',
#  'IIq IIq IIq',
#  'IV IV',
#  'IV IV IV',
#  'IV IV IV IV',
#  'IV IV IV IV IV',
#  'IV Iq Iq Iq IV',
#  'IVq IVq',
#  'IVq IVq IVq',
#  'IX IX',
#  'Iq Iq',
#  'Iq Iq Iq',
#  'Iq Iq Iq Iq',
#  'Iq V Iq V',
#  'V V',
#  'V V V',
#  'V V V V',
#  'V V V V V',
#  'VI VI',
#  'VI VI VI',
#  'VI VI VI VI VI',
#  'VII VII',
#  'VII VII VII',
#  'VII VII VII VII VII',
#  'VIII VIII',
#  'VIII VIII VIII',
#  'VIII VIII VIII VIII',
#  'VIII VIII VIII VIII VIII',
#  'VIII X X VIII',
#  'X X',
#  'X X X',
#  'X X X X X',
#  'XI XI',
#  'XII XII',
#  'XII XII XII',
#  'XIII XIII'}
