# %% [markdown]
# # 1.0 Imports

# %%
import gzip
import json
import re
import time
from datetime import datetime
from pathlib import Path
from typing import Dict, List
from unicodedata import normalize

import pandas as pd
from pyarabic.araby import DIACRITICS, SHADDA, is_arabicword, name, vocalizedlike

# %% [markdown]
# # 2.0 Define Paths

# %%
# Path for preproceed Wikitionary
wiktionary_dir = Path("../data/processed/wikidata")
wiki_jsonl_path = wiktionary_dir / "ar-wiktextract-data.json.gz"
wiki_indices_path = wiktionary_dir / "ar_reindex.json.gz"

# %%
# Arabic GF-Wordnet
data_dir = Path("../data/interim/unambiguous")
ar_words_gf_path = data_dir / "20231201.1559_Q79_Q34_word_unambiguous.csv"

# %%
# Path to save words status
output_dir = Path("../data/interim/lexicon")
output_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # 3.0 Define Variables

# %%
DIACRITICS = set(DIACRITICS)  # Aabic diacritics/short vowels

# %%
TIMESTAMP = "_".join(ar_words_gf_path.stem.split("_")[:-2])

# %% [markdown]
# ## 4.0 Define Functions

# %% [markdown]
# ### 4.1 Utilities Functions

# %%
def reorder_shadda(ar_string: str) -> str:
    """unicodedata.normalize put shadda before diacritics; not correct"""
    list_ar_str = list(ar_string)

    for i in range(len(list_ar_str) - 1):
        char = list_ar_str[i]
        next_char = list_ar_str[i + 1]

        if char in DIACRITICS and next_char == SHADDA:
            list_ar_str[i], list_ar_str[i + 1] = (
                next_char,
                char,
            )  # Swap shadda and diacritic

    return "".join(list_ar_str)

# %%
def normalize_ar(ar_vocalized: str, verbose: bool = False) -> str:
    """get the normal form for the Unicode string unistr using NFC then fix the shadda order issue"""
    ar_norm = normalize("NFC", ar_vocalized)
    ar_norm = reorder_shadda(ar_norm)
    if verbose:
        print([name(char) for char in ar_norm])
    return ar_norm

# %% [markdown]
# ## 4.2 Morphology Features

# %% [markdown]
# ### 4.2.1 Gender

# %%
def get_noun_gender(entry, form):
    for _, word_data in entry.items():
        categories: List[str] = word_data.get("categories", [])
        for category in categories:
            masculine = category.find("masculine") != -1
            feminine = category.find("feminine") != -1
            if masculine and feminine:
                return "N"
            elif masculine:
                return "masc"
            elif feminine:
                return "fem"
        return pd.NA

# %%
def get_adj_gender(entry, form):
    for _, word_data in entry.items():
        word_forms: List[dict] = word_data.get("forms", [])
        masculine, feminine = None, None
        for form_dict in word_forms:
            if {'indefinite', 'masculine', 'singular', 'nominative'}.issubset(form_dict.get("tags", [])):
                masculine = normalize_ar(form_dict["form"])
            elif {'indefinite', 'feminine', 'singular', 'nominative'}.issubset(form_dict.get("tags", [])):
                feminine = normalize_ar(form_dict["form"])
            if masculine and feminine:
                break

        # TODO: Confusing = redesign
        if not masculine and not feminine:
            return pd.NA, pd.NA
        elif not masculine or not feminine:
            return "masc", pd.NA if masculine else "fem", pd.NA

        if vocalizedlike(form, masculine):
            return "masc", feminine
        return "fem", masculine

# %%
def get_gender(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    pos = row["wiki_pos"]
    form: str = normalize_ar(row["vocal_forms"])
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        if pos == "noun":
            return get_noun_gender(entry, None)
        elif pos == "adj":
            return get_adj_gender(entry, form)
    return [pd.NA] * 2

# %% [markdown]
# ### 4.2.2 Plural

# %%
def get_noun_plural(entry):
    for _, word_data in entry.items():
        word_forms = word_data.get("forms", [])
        for form_dict in word_forms:
            if "plural" == form_dict.get("tags", [None])[0]:
                return form_dict["form"]
        inflections = word_data.get("head_templates", [])
        for dict_inflection in inflections:
            plural = dict_inflection.get("args", {}).get("pl", None)
            if plural is not None:
                if is_arabicword(plural):
                    return normalize_ar(plural)
                elif plural == "-":
                    return normalize_ar("غير معدود")
                return normalize_ar("جمع سالم")
    return pd.NA

# %%
def get_adj_plural(entry):
    for _, word_data in entry.items():
        word_forms = word_data.get("forms", [])
        masc_pl, fem_pl = None, None
        for form_dict in word_forms:
            if ['masculine', 'plural'] == form_dict.get("tags", [None]):
                masc_pl = form_dict["form"]
            elif ['feminine', 'plural'] == form_dict.get("tags", [None]):
                fem_pl = form_dict["form"]
            if masc_pl and fem_pl:
                break
    masc_pl = normalize_ar(masc_pl) if masc_pl else pd.NA
    fem_pl = normalize_ar(fem_pl) if fem_pl else pd.NA

    return masc_pl, fem_pl

# %%
def get_plural(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    pos = row["wiki_pos"]
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        if pos == "noun":
            return get_noun_plural(entry)
        elif pos == "adj":
            return get_adj_plural(entry)
    if pos == "noun":
        return pd.NA
    elif pos == "adj":
        return [pd.NA]*2

# %% [markdown]
# ### 4.2.3 Root

# %%
def get_root(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        for _, word_data in entry.items():
            for etymology in word_data.get('etymology_templates', []):
                if etymology.get("name", "").startswith("ar-root"):
                    if len(etymology["args"]) == 3:
                        return normalize_ar("".join(list(etymology["args"].values())))
                    if len(etymology["args"]) == 1:
                        return normalize_ar("".join(etymology["args"]["1"].split()))
        return pd.NA

# %% [markdown]
# ### 4.2.4 Verb Forms

# %%
def get_verb_form(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        form_number = None
        for _, word_data in entry.items():
            form_numbers = []
            categories: List[str] = word_data.get("categories", [])
            for category in categories:
                if match := re.search(r"(?<=form-)\w+(?= verbs)", category):
                    form_numbers.append(match.group())
            if form_numbers:
                form_number = max(form_numbers)

        return f"Form{form_number}" if form_number is not None else pd.NA

# %%
def get_imperfect_form(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        for _, word_data in entry.items():
            word_forms: List[dict] = word_data.get("forms", [])
            for form_dict in word_forms:
                if {
                    "active",
                    "indicative",
                    "masculine",
                    "non-past",
                    "imperfective",
                    "singular",
                    "third-person",
                }.issubset(form_dict.get("tags", [])):
                    return normalize_ar(form_dict["form"])

        return pd.NA

# %% [markdown]
# # 5.0 Load Files

# %%
# 1. load the wikitionary
with gzip.open(wiki_jsonl_path, "rt", encoding="utf-8") as gzip_obj:
    wikitionary = []
    for i, json_line in enumerate(gzip_obj):
        wikitionary.append(dict(json.loads(json_line)))
        print(f"Reading line-{i}", end="\r")
# Out:
# Reading line-128636

# %%
# 2. load the csv arabic-english_gf words
df_ar_gf = pd.read_csv(ar_words_gf_path, delimiter="\t", index_col=0)

# %%
df_ar_gf = df_ar_gf[df_ar_gf["select"] == 1]

# %%
# Get nouns, adjectives and verbs
df_ar_gf_nouns = df_ar_gf.copy()[(df_ar_gf["wiki_pos"] == "noun") & (df_ar_gf["select"] == 1)]
df_ar_gf_adjs = df_ar_gf.copy()[(df_ar_gf["wiki_pos"] == "adj") & (df_ar_gf["select"] == 1)]
df_ar_gf_verbs = df_ar_gf.copy()[(df_ar_gf["wiki_pos"] == "verb") & (df_ar_gf["select"] == 1)]

# %% [markdown]
# # 6.0 Get Morphological Features

# %% [markdown]
# ## 6.1 Nouns

# %%
df_ar_gf_nouns["gender"] = df_ar_gf_nouns.apply(get_gender, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["gender"].value_counts()
# Out:
# gender
# masc            43
# fem             29
# [<NA>, <NA>]    10
# Name: count, dtype: int64

# %%
df_ar_gf_nouns["plural"] = df_ar_gf_nouns.apply(get_plural, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["plural"].isna().value_counts()
# Out:
# plural
# False    61
# True     35
# Name: count, dtype: int64

# %%
df_ar_gf_nouns["root"] = df_ar_gf_nouns.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["root"].isna().value_counts()
# Out:
# root
# True     53
# False    43
# Name: count, dtype: int64

# %% [markdown]
# ## 6.2 Adjectives

# %%
df_ar_gf_adjs["gender"], df_ar_gf_adjs["other_gender_form"] = zip(
    *df_ar_gf_adjs.apply(get_gender, args=(wikitionary,), axis="columns")
)
df_ar_gf_adjs["gender"].value_counts()
# Out:
# gender
# masc    25
# Name: count, dtype: int64

# %%
df_ar_gf_adjs["masc_pl"], df_ar_gf_adjs["fem_pl"]  = zip(*df_ar_gf_adjs.apply(get_plural, args=(wikitionary,), axis="columns"))
print(df_ar_gf_adjs["masc_pl"].isna().value_counts())
print(df_ar_gf_adjs["fem_pl"].isna().value_counts())
# Out:
# masc_pl
# False    25
# True      7
# Name: count, dtype: int64
# fem_pl
# False    25
# True      7
# Name: count, dtype: int64

# %%
df_ar_gf_adjs["root"] = df_ar_gf_adjs.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_adjs["root"].isna().value_counts()
# Out:
# root
# True     17
# False    15
# Name: count, dtype: int64

# %% [markdown]
# ## 6.3 Verbs

# %%
df_ar_gf_verbs["verb_form"] = df_ar_gf_verbs.apply(get_verb_form, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["verb_form"].isna().value_counts()
# Out:
# verb_form
# False    8
# True     1
# Name: count, dtype: int64

# %%
df_ar_gf_verbs["root"] = df_ar_gf_verbs.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["root"].isna().value_counts()
# Out:
# root
# False    8
# True     1
# Name: count, dtype: int64

# %%
df_ar_gf_verbs["imperfect"] = df_ar_gf_verbs.apply(get_imperfect_form, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["imperfect"].isna().value_counts()
# Out:
# imperfect
# False    8
# True     1
# Name: count, dtype: int64

# %% [markdown]
# # 7.0 Export Data

# %%
df_ar_gf_verbs.drop(columns=["select", "entry_num", "pos"], inplace=True)
df_ar_gf_nouns.drop(columns=["select", "entry_num", "pos"], inplace=True)
df_ar_gf_adjs.drop(columns=["select", "entry_num", "pos"], inplace=True)

# %%
df_ar_gf_verbs.to_csv(output_dir / f"{TIMESTAMP}_verbs_lexicon.csv", decimal=",")
df_ar_gf_nouns.to_csv(output_dir / f"{TIMESTAMP}_nouns_lexicon.csv", decimal=",")
df_ar_gf_adjs.to_csv(output_dir / f"{TIMESTAMP}_adjectives_lexicon.csv", decimal=",")

# %% [markdown]
# # 8.0 Visualize Data

# %%
df_ar_gf_verbs
# Out:
#      wiki_idx        en_entry     ar vocal_forms wiki_pos
# 208      8500        birr_1_N    بير       بِيرَ     verb  \
# 194    116328   consider_6_V3  اعتبر   اِعْتَبَر     verb
# 317     20863      succeed_V2    نجح      نَجَحَ     verb
# 165      8070       rank_2_V2    صنف     صَنَّفَ     verb
# 236       148  designate_4_V2    عين     عَيَّنَ     verb
# 190      4743           reach    وصل       وَصَل     verb
# 181      6248      speak_3_V2   تكلم    تَكَلَّم     verb
# 158       698       have_1_V2    ملك       مَلَك     verb
# 169      8035       show_2_V2    عرض      عَرَضَ     verb
#
#                                           ar_letters
# 208                             باء-كسرة | ياء | راء  \
# 194  ألف-كسرة | عين-سكون | تاء-فتحة | باء-فتحة | راء
# 317                   نون-فتحة | جيم-فتحة | حاء-فتحة
# 165               صاد-فتحة | نون-شدة-فتحة | فاء-فتحة
# 236               عين-فتحة | ياء-شدة-فتحة | نون-فتحة
# 190                   واو-فتحة | صاد-فتحة | لام-فتحة
# 181    تاء-فتحة | كاف-فتحة | لام-شدة-فتحة | ميم-فتحة
# 158                   ميم-فتحة | لام-فتحة | كاف-فتحة
# 169                   عين-فتحة | راء-فتحة | ضاد-فتحة
#
#                                                 senses tim_translit
# 208                                                NaN         biyr  \
# 194  ['to take example, to take warning, to learn a...    AiEotabar
# 317                   ['to succeed, to be successful']       najaHa
# 165  ['to sort, classify, or categorize something /...      San~afa
# 236  ['to appoint, to assign, to name, to nominate ...      Eay~ana
# 190  ['(transitive, with إِلَى (ʔilā)) to arrive (“...       waSala
# 181  ['to talk, to have a discussion or conversation']    takal~ama
# 158  ['to take in possession, to take over, to acqu...       malaka
# 169  ['to appear / to happen, to occur / to show, t...       EaraDa
#
#                           file verb_form  root    imperfect
# 208    6_20231201.1559_Q79_Q34      <NA>  <NA>         <NA>
# 194   20_20231122.1302_Q79_Q34      VIII   عبر   يَعْتَبِرُ
# 317   50_20231201.1559_Q79_Q34         I   نجح     يَنْجَحُ
# 165  100_20231122.1302_Q79_Q34        II   صنف    يُصَنِّفُ
# 236   18_20231201.1559_Q79_Q34        II   عين    يُعَيِّنُ
# 190  158_20231122.1302_Q79_Q34         I   وصل       يَصِلُ
# 181  118_20231122.1302_Q79_Q34         V   كلم  يَتَكَلَّمُ
# 158   54_20231122.1302_Q79_Q34         I   ملك     يَمْلِكُ
# 169  113_20231122.1302_Q79_Q34         I   عرض     يَعْرِضُ

# %%
df_ar_gf_adjs
# Out:
#      wiki_idx            en_entry         ar        vocal_forms wiki_pos
# 31         -1             added_A       مضاف              مُضاف      adj  \
# 1          -1   authoritarian_1_A   استبدادي      اِسْتِبْدادِي      adj
# 14         -1          median_3_A     الوسيط           الوَسِيط      adj
# 16         -1          nordic_2_A     الشمال           الشَّمال      adj
# 2        4973        domestic_1_A       محلي          مَحَلِّيّ      adj
# 3      117599       following_2_A       تالي             تَالِي      adj
# 7       10802            full_3_A      ممتلئ          مُمْتَلِئ      adj
# 8      124714           gross_1_A     إجمالي        إِجْمَالِيّ      adj
# 11     124077      individual_4_A       فردي           فَرْدِيّ      adj
# 15     115192        moderate_1_A      معتدل          مُعْتَدِل      adj
# 196      5922        absolute_3_A       مطلق            مُطْلَق      adj
# 29       3016    administrative_A       حاكم             حَاكِم      adj
# 218     25071         communist_A      شيوعي          شُيُوعِيّ      adj
# 220      8330  constitutional_2_A     دستوري        دُسْتُورِيّ      adj
# 234     25151      democratic_1_A   ديمقراطي     دِيمُقْرَاطِيّ      adj
# 248     10031          former_3_A       سابق             سَابِق      adj
# 10       5211            high_1_A       عالي             عَالِي      adj
# 12       4262           large_1_A       كبير             كَبِير      adj
# 266     10173             low_1_A       قليل             قَلِيل      adj
# 268      4970        military_2_A      عسكري         عَسْكَرِيّ      adj
# 17        788      obligatory_1_A       واجب             وَاجِب      adj
# 293    127672   parliamentary_2_A    برلماني      بَرْلَمَانِيّ      adj
# 26      23237           total_1_A      مجموع           مَجْمُوع      adj
# 199        64            arabic_A       عربي           عَرَبِيّ      adj
# 4        4339            free_1_A         حر               حُرّ      adj
# 256    120131            hybrid_A       هجين             هَجِين      adj
# 19      22237        official_1_A       رسمي           رَسْمِيّ      adj
# 287     22237        official_3_A       رسمي           رَسْمِيّ      adj
# 292    128098        orthodox_3_A  أرثوذكسية  أُرْثُوذُكْسِيَّة      adj
# 24       2788          square_1_A       مربع           مُرَبَّع      adj
# 280        76            muslim_A       مسلم            مُسْلِم      adj
# 223     21952           current_A       حاضر             حَاضِر      adj
#
#                                             ar_letters
# 31                           ميم-ضمة | ضاد | ألف | فاء  \
# 1    ألف-كسرة | سين-سكون | تاء-كسرة | باء-سكون | دا...
# 14         ألف | لام | واو-فتحة | سين-كسرة | ياء | طاء
# 16                                                 NaN
# 2         ميم-فتحة | حاء-فتحة | لام-شدة-كسرة | ياء-شدة
# 3                      تاء-فتحة | ألف | لام-كسرة | ياء
# 7    ميم-ضمة | ميم-سكون | تاء-فتحة | لام-كسرة | همز...
# 8    همزة تحت الألف-كسرة | جيم-سكون | ميم-فتحة | أل...
# 11            فاء-فتحة | راء-سكون | دال-كسرة | ياء-شدة
# 15      ميم-ضمة | عين-سكون | تاء-فتحة | دال-كسرة | لام
# 196                ميم-ضمة | طاء-سكون | لام-فتحة | قاف
# 29                     حاء-فتحة | ألف | كاف-كسرة | ميم
# 218       شين-ضمة | ياء-ضمة | واو | عين-كسرة | ياء-شدة
# 220  دال-ضمة | سين-سكون | تاء-ضمة | واو | راء-كسرة ...
# 234  دال-كسرة | ياء | ميم-ضمة | قاف-سكون | راء-فتحة...
# 248                    سين-فتحة | ألف | باء-كسرة | قاف
# 10                     عين-فتحة | ألف | لام-كسرة | ياء
# 12                     كاف-فتحة | باء-كسرة | ياء | راء
# 266                    قاف-فتحة | لام-كسرة | ياء | لام
# 268  عين-فتحة | سين-سكون | كاف-فتحة | راء-كسرة | يا...
# 17                     واو-فتحة | ألف | جيم-كسرة | باء
# 293  باء-فتحة | راء-سكون | لام-فتحة | ميم-فتحة | أل...
# 26           ميم-فتحة | جيم-سكون | ميم-ضمة | واو | عين
# 199           عين-فتحة | راء-فتحة | باء-كسرة | ياء-شدة
# 4                                    حاء-ضمة | راء-شدة
# 256                    هاء-فتحة | جيم-كسرة | ياء | نون
# 19            راء-فتحة | سين-سكون | ميم-كسرة | ياء-شدة
# 287           راء-فتحة | سين-سكون | ميم-كسرة | ياء-شدة
# 292  همزة على الألف-ضمة | راء-سكون | ثاء-ضمة | واو ...
# 24             ميم-ضمة | راء-فتحة | باء-شدة-فتحة | عين
# 280                ميم-ضمة | سين-سكون | لام-كسرة | ميم
# 223                    حاء-فتحة | ألف | ضاد-كسرة | راء
#
#                                                 senses       tim_translit
# 31                                               added              muDAf  \
# 1                            arbitrary / authoritarian      AisotibodAdiy
# 14            the+mediator / go-between / intermediary           AlwasiyT
# 16                                                 NaN                NaN
# 2                                  ['local, national']          maHal~iy~
# 3                                                 ['']             taAliy
# 7                 ['full, filled, filled up, replete']          mumotali}
# 8                    ['comprehensive, general, total']        <ijomaAliy~
# 11     ['single / individual, personal / odd, uneven']           farodiy~
# 15   ['straight, even, proportionate / temperate, m...          muEotadil
# 196  ['absolute, utter, very, unlimited, unrestrict...            muTolaq
# 29                    ['ruling, governing / decisive']             HaAkim
# 218               ['communist / Communist / communal']          $uyuwEiy~
# 220                                 ['constitutional']        dusotuwriy~
# 234                                     ['democratic']     diymuqoraATiy~
# 248  ['preceding, previous / former / active partic...             saAbiq
# 10                                                ['']             EaAliy
# 12   ['big, large / great, great importance / old (...             kabiyr
# 266  ['few, little / scarce / short, thin, paltry, ...             qaliyl
# 268                                       ['military']         Easokariy~
# 17   ['necessary, indispensable, unavoidable, essen...             waAjib
# 293                                  ['parliamentary']      barolamaAniy~
# 26                             ['united / reconciled']           majomuwE
# 199                        ['Arab / Arabic / Arabian']           Earabiy~
# 4    ['free / unimpeded / set free, freedman / born...               Hur~
# 256                    ['hybrid, half-breed, mongrel']             hajiyn
# 19   ['official, legitimate / formal / normal / con...           rasomiy~
# 287  ['official, legitimate / formal / normal / con...           rasomiy~
# 292  ['feminine singular of أُرْثُوذُكْسِيّ (ʔurṯūḏ...  >urovuw*ukosiy~ap
# 24   ['square, quadratic / fourfold, quadruple / te...           murab~aE
# 280     ['Muslim / submitting, accepting, believing.']            musolim
# 223  ['present, before the eyes, ready (also applie...             HaADir
#
#                           file gender  other_gender_form             masc_pl
# 31   157_20231122.1302_Q79_Q34   <NA>               <NA>                <NA>  \
# 1      7_20231122.1302_Q79_Q34   <NA>               <NA>                <NA>
# 14    76_20231122.1302_Q79_Q34   <NA>               <NA>                <NA>
# 16    84_20231122.1302_Q79_Q34   <NA>               <NA>                <NA>
# 2     31_20231122.1302_Q79_Q34   masc       مَحَلِّيَّةٌ       مَحَلِّيُّونَ
# 3     41_20231122.1302_Q79_Q34   <NA>               <NA>                <NA>
# 7     45_20231122.1302_Q79_Q34   masc       مُمْتَلِئَةٌ       مُمْتَلِئُونَ
# 8     50_20231122.1302_Q79_Q34   masc     إِجْمَالِيَّةٌ     إِجْمَالِيُّونَ
# 11    59_20231122.1302_Q79_Q34   masc        فَرْدِيَّةٌ        فَرْدِيُّونَ
# 15    79_20231122.1302_Q79_Q34   masc       مُعْتَدِلَةٌ       مُعْتَدِلُونَ
# 196    0_20231201.1559_Q79_Q34   masc         مُطْلَقَةٌ         مُطْلَقُونَ
# 29   153_20231122.1302_Q79_Q34   masc          حَاكِمَةٌ           حَاكِمُون
# 218   12_20231201.1559_Q79_Q34   masc       شُيُوعِيَّةٌ       شُيُوعِيُّونَ
# 220   13_20231201.1559_Q79_Q34   masc     دُسْتُورِيَّةٌ     دُسْتُورِيُّونَ
# 234   17_20231201.1559_Q79_Q34   masc  دِيمُقْرَاطِيَّةٌ  دِيمُقْرَاطِيُّونَ
# 248   22_20231201.1559_Q79_Q34   masc          سَابِقَةٌ             سُبَّاق
# 10    57_20231122.1302_Q79_Q34   <NA>               <NA>                <NA>
# 12    72_20231122.1302_Q79_Q34   masc          كَبِيرَةٌ            كُبَرَاء
# 266   34_20231201.1559_Q79_Q34   masc          قَلِيلَةٌ           أَقِلَّاء
# 268   35_20231201.1559_Q79_Q34   masc      عَسْكَرِيَّةٌ            عَسَاكِر
# 17    87_20231122.1302_Q79_Q34   masc          وَاجِبَةٌ          وَاجِبُونَ
# 293   42_20231201.1559_Q79_Q34   masc   بَرْلَمَانِيَّةٌ   بَرْلَمَانِيُّونَ
# 26   126_20231122.1302_Q79_Q34   masc        مَجْمُوعَةٌ        مَجْمُوعُونَ
# 199    2_20231201.1559_Q79_Q34   masc        عَرَبِيَّةٌ               عَرَب
# 4     43_20231122.1302_Q79_Q34   masc            حُرَّةٌ            أَحْرَار
# 256   26_20231201.1559_Q79_Q34   masc            هَجِينٌ              هِجَان
# 19    89_20231122.1302_Q79_Q34   masc        رَسْمِيَّةٌ        رَسْمِيُّونَ
# 287   40_20231201.1559_Q79_Q34   masc        رَسْمِيَّةٌ        رَسْمِيُّونَ
# 292   41_20231201.1559_Q79_Q34   <NA>               <NA>                <NA>
# 24   120_20231122.1302_Q79_Q34   masc        مُرَبَّعَةٌ        مُرَبَّعُونَ
# 280   38_20231201.1559_Q79_Q34   masc         مُسْلِمَةٌ          مُسْلِمُون
# 223   14_20231201.1559_Q79_Q34   masc          حَاضِرَةٌ              حُضُور
#
#                 fem_pl  root
# 31                <NA>  None
# 1                 <NA>  None
# 14                <NA>  None
# 16                <NA>  None
# 2         مَحَلِّيَّات  <NA>
# 3                 <NA>  <NA>
# 7         مُمْتَلِئَات   ملء
# 8       إِجْمَالِيَّات   جمل
# 11         فَرْدِيَّات   فرد
# 15        مُعْتَدِلَات   عدل
# 196         مُطْلَقَات   طلق
# 29           حَاكِمَات   حكم
# 218       شُيُوعِيَّات  <NA>
# 220     دُسْتُورِيَّات  <NA>
# 234  دِيمُقْرَاطِيَّات  <NA>
# 248          سَابِقَات   سبق
# 10                <NA>  <NA>
# 12           كَبِيرَات   كبر
# 266          قَلِيلَات   قلل
# 268      عَسْكَرِيَّات  <NA>
# 17           وَاجِبَات   وجب
# 293   بَرْلَمَانِيَّات  <NA>
# 26         مَجْمُوعَات   جمع
# 199        عَرَبِيَّات  <NA>
# 4              حُرَّات   حرر
# 256           هَجَائِن   هجن
# 19         رَسْمِيَّات  <NA>
# 287        رَسْمِيَّات  <NA>
# 292               <NA>  <NA>
# 24         مُرَبَّعَات  <NA>
# 280         مُسْلِمَات   سلم
# 223          حَاضِرَات   حضر

# %%
df_ar_gf_nouns
# Out:
#      wiki_idx         en_entry       ar  vocal_forms wiki_pos
# 213        -1        chinese_N    صينىة    صِينِيَّة     noun  \
# 231        -1           dari_N    دارية     دارِيَّة     noun
# 69         -1  development_2_N    تطوير     تَطْوِير     noun
# 263        -1        italian_N  ايطالية  إِيطالِيَّة     noun
# 108        -1        krona_1_N     كرون        كَرون     noun
# ..        ...              ...      ...          ...      ...
# 273      3220       mother_1_N       أم         أُمّ     noun
# 311      3927       starch_1_N     نشاء       نَشَاء     noun
# 44       2554          age_1_N      عمر        عُمْر     noun
# 145      5764         west_2_N      غرب        غَرْب     noun
# 97        695         king_1_N     ملِك        مَلِك     noun
#
#                                             ar_letters
# 213  صاد-كسرة | ياء | نون-كسرة | ياء-شدة-فتحة | تاء...  \
# 231   دال | ألف | راء-كسرة | ياء-شدة-فتحة | تاء مربوطة
# 69          تاء-فتحة | طاء-سكون | واو-كسرة | ياء | راء
# 263  همزة تحت الألف-كسرة | ياء | طاء | ألف | لام-كس...
# 108                         كاف-فتحة | راء | واو | نون
# ..                                                 ...
# 273                       همزة على الألف-ضمة | ميم-شدة
# 311                   نون-فتحة | شين-فتحة | ألف | همزة
# 44                            عين-ضمة | ميم-سكون | راء
# 145                          غين-فتحة | راء-سكون | باء
# 97                           ميم-فتحة | لام-كسرة | كاف
#
#                                                 senses tim_translit
# 213                                  Chinese+[fem.sg.]    Siyniy~ap  \
# 231                                                NaN     dAriy~ap
# 69               development / advancement / promotion     taTowiyr
# 263                                                NaN  <iyTAliy~ap
# 108                                                NaN        karwn
# ..                                                 ...          ...
# 273                       ['mother / origin / source']         >um~
# 311                     ['starch, cornstarch, farina']       na$aA'
# 44   ['life as a period of time, length of life, li...        Eumor
# 145  ['verbal noun of غَرَبَ (ḡaraba) (form I) / we...        garob
# 97                        ['king, sovereign, monarch']        malik
#
#                           file        gender     plural  root
# 213   10_20231201.1559_Q79_Q34  [<NA>, <NA>]        NaN  None
# 231   15_20231201.1559_Q79_Q34  [<NA>, <NA>]        NaN  None
# 69    29_20231122.1302_Q79_Q34  [<NA>, <NA>]        NaN  None
# 263   31_20231201.1559_Q79_Q34  [<NA>, <NA>]        NaN  None
# 108   69_20231122.1302_Q79_Q34  [<NA>, <NA>]        NaN  None
# ..                         ...           ...        ...   ...
# 273   37_20231201.1559_Q79_Q34           fem  أُمَّهَات   ءمم
# 311   49_20231201.1559_Q79_Q34          masc       <NA>   نشو
# 44     0_20231122.1302_Q79_Q34          masc   أَعْمَار   عمر
# 145  136_20231122.1302_Q79_Q34          masc       <NA>  <NA>
# 97    67_20231122.1302_Q79_Q34          masc     مُلُوك  <NA>
#
# [96 rows x 12 columns]
