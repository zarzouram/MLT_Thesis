# %% [markdown]
# # 1.0 Imports

# %%
import gzip
import json
import re
import time
from datetime import datetime
from pathlib import Path
from typing import Dict, List
from unicodedata import normalize

import pandas as pd
from pyarabic.araby import DIACRITICS, SHADDA, is_arabicword, name, vocalizedlike

# %% [markdown]
# # 2.0 Define Variables

# %%
DIACRITICS = set(DIACRITICS)  # Aabic diacritics/short vowels

# %% [markdown]
# # 3.0 Define Paths

# %%
# Path for preproceed Wikitionary
wiktionary_dir = Path("../data/processed/wikidata")
wiki_jsonl_path = wiktionary_dir / "ar-wiktextract-data.json.gz"
wiki_indices_path = wiktionary_dir / "ar_reindex.json.gz"

# %%
# Arabic GF-Wordnet
data_dir = Path("../data/interim/")
ar_words_gf_path = data_dir / "word_unambiguous.csv"

# %%
# Path to save words status
output_dir = Path("../data/interim/lexicon")
output_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 4.0 Define Functions

# %% [markdown]
# ### 4.1 Utilities Functions

# %%
def reorder_shadda(ar_string: str) -> str:
    """unicodedata.normalize put shadda before diacritics; not correct"""
    list_ar_str = list(ar_string)

    for i in range(len(list_ar_str) - 1):
        char = list_ar_str[i]
        next_char = list_ar_str[i + 1]

        if char in DIACRITICS and next_char == SHADDA:
            list_ar_str[i], list_ar_str[i + 1] = (
                next_char,
                char,
            )  # Swap shadda and diacritic

    return "".join(list_ar_str)

# %%
def normalize_ar(ar_vocalized: str, verbose: bool = False) -> str:
    """get the normal form for the Unicode string unistr using NFC then fix the shadda order issue"""
    ar_norm = normalize("NFC", ar_vocalized)
    ar_norm = reorder_shadda(ar_norm)
    if verbose:
        print([name(char) for char in ar_norm])
    return ar_norm

# %% [markdown]
# ## 4.2 Morphology Features

# %% [markdown]
# ### 4.2.1 Gender

# %%
def get_noun_gender(entry, form):
    for _, word_data in entry.items():
        categories: List[str] = word_data.get("categories", [])
        for category in categories:
            masculine = category.find("masculine") != -1
            feminine = category.find("feminine") != -1
            if masculine and feminine:
                return "N"
            elif masculine:
                return "masc"
            elif feminine:
                return "fem"
        return pd.NA

# %%
def get_adj_gender(entry, form):
    for _, word_data in entry.items():
        word_forms: List[dict] = word_data.get("forms", [])
        masculine, feminine = None, None
        for form_dict in word_forms:
            if {'indefinite', 'masculine', 'singular', 'nominative'}.issubset(form_dict.get("tags", [])):
                masculine = normalize_ar(form_dict["form"])
            elif {'indefinite', 'feminine', 'singular', 'nominative'}.issubset(form_dict.get("tags", [])):
                feminine = normalize_ar(form_dict["form"])
            if masculine and feminine:
                break

        # TODO: Confusing = redesign
        if not masculine and not feminine:
            return pd.NA, pd.NA
        elif not masculine or not feminine:
            return "masc", pd.NA if masculine else "fem", pd.NA

        if vocalizedlike(form, masculine):
            return "masc", feminine
        return "fem", masculine

# %%
def get_gender(row, wikitionary):
    wiki_idx = row["wiki_idx"]
    pos = row["pos"]
    form: str = normalize_ar(row["vocal_forms"])
    entry = wikitionary[wiki_idx]
    if pos == "noun":
        return get_noun_gender(entry, None)
    elif pos == "adj":
        return get_adj_gender(entry, form)
    else:
        return pd.NA

# %% [markdown]
# ### 4.2.2 Plural

# %%
def get_noun_plural(entry):
    for _, word_data in entry.items():
        word_forms = word_data.get("forms", [])
        for form_dict in word_forms:
            if "plural" == form_dict.get("tags", [None])[0]:
                return form_dict["form"]
        inflections = word_data.get("head_templates", [])
        for dict_inflection in inflections:
            plural = dict_inflection.get("args", {}).get("pl", None)
            if plural is not None:
                if is_arabicword(plural):
                    return normalize_ar(plural)
                elif plural == "-":
                    return normalize_ar("غير معدود")
                return normalize_ar("جمع سالم")
    return pd.NA

# %%
def get_adj_plural(entry):
    for _, word_data in entry.items():
        word_forms = word_data.get("forms", [])
        masc_pl, fem_pl = None, None
        for form_dict in word_forms:
            if ['masculine', 'plural'] == form_dict.get("tags", [None]):
                masc_pl = form_dict["form"]
            elif ['feminine', 'plural'] == form_dict.get("tags", [None]):
                fem_pl = form_dict["form"]
            if masc_pl and fem_pl:
                break
    masc_pl = normalize_ar(masc_pl) if masc_pl else pd.NA
    fem_pl = normalize_ar(fem_pl) if fem_pl else pd.NA

    return masc_pl, fem_pl

# %%
def get_plural(row, wikitionary):
    wiki_idx = row["wiki_idx"]
    pos = row["pos"]
    entry = wikitionary[wiki_idx]
    if pos == "noun":
        return get_noun_plural(entry)
    elif pos == "adj":
        return get_adj_plural(entry)
    else:
        return pd.NA

# %% [markdown]
# ### 4.2.3 Root

# %%
def get_root(row, wikitionary):
    wiki_idx = row["wiki_idx"]
    entry = wikitionary[wiki_idx]
    for _, word_data in entry.items():
        for etymology in word_data.get('etymology_templates', []):
            if etymology.get("name", "").startswith("ar-root"):
                if len(etymology["args"]) == 3:
                    return normalize_ar("".join(list(etymology["args"].values())))
                if len(etymology["args"]) == 1:
                    return normalize_ar("".join(etymology["args"]["1"].split()))
    return pd.NA

# %% [markdown]
# ### 4.2.4 Verb Forms

# %%
def get_verb_form(row, wikitionary):
    wiki_idx = row["wiki_idx"]
    entry = wikitionary[wiki_idx]
    form_number = pd.NA
    for _, word_data in entry.items():
        form_numbers = []
        categories: List[str] = word_data.get("categories", [])
        for category in categories:
            if match := re.search(r"(?<=form-)\w+(?= verbs)", category):
                form_numbers.append(match.group())
        if form_numbers:
            form_number = max(form_numbers)

    return form_number

# %%
def get_imperfect_form(row, wikitionary):
    wiki_idx = row["wiki_idx"]
    entry = wikitionary[wiki_idx]
    for _, word_data in entry.items():
        word_forms: List[dict] = word_data.get("forms", [])
        for form_dict in word_forms:
            if {
                "active",
                "indicative",
                "masculine",
                "non-past",
                "imperfective",
                "singular",
                "third-person",
            }.issubset(form_dict.get("tags", [])):
                return normalize_ar(form_dict["form"])

    return pd.NA

# %% [markdown]
# # 5.0 Load Files

# %%
# 1. load the wikitionary
with gzip.open(wiki_jsonl_path, "rt", encoding="utf-8") as gzip_obj:
    wikitionary = []
    for i, json_line in enumerate(gzip_obj):
        wikitionary.append(dict(json.loads(json_line)))
        print(f"Reading line-{i}", end="\r")
# Out:
# Reading line-2262
# Reading line-128636

# %%
# 2. load the csv arabic-english_gf words
df_ar_gf = pd.read_csv(ar_words_gf_path, delimiter="\t", index_col=0, converters={"senses": pd.eval})

# %%
df_ar_gf = df_ar_gf[df_ar_gf["select"] == 1]

# %%
# Get nouns, adjectives and verbs
df_ar_gf_nouns = df_ar_gf.copy()[(df_ar_gf["pos"] == "noun") & (df_ar_gf["select"] == 1)]
df_ar_gf_adjs = df_ar_gf.copy()[(df_ar_gf["pos"] == "adj") & (df_ar_gf["select"] == 1)]
df_ar_gf_verbs = df_ar_gf.copy()[(df_ar_gf["pos"] == "verb") & (df_ar_gf["select"] == 1)]

# %% [markdown]
# # 6.0 Get Morphological Features

# %% [markdown]
# ## 6.1 Nouns

# %%
df_ar_gf_nouns["gender"] = df_ar_gf_nouns.apply(get_gender, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["gender"].value_counts()
# Out:
# gender
# masc    40
# fem     18
# Name: count, dtype: int64

# %%
df_ar_gf_nouns["plural"] = df_ar_gf_nouns.apply(get_plural, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["plural"].isna().value_counts()
# Out:
# plural
# False    36
# True     22
# Name: count, dtype: int64

# %%
df_ar_gf_nouns["root"] = df_ar_gf_nouns.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["root"].isna().value_counts()
# Out:
# root
# True     35
# False    23
# Name: count, dtype: int64

# %% [markdown]
# ## 6.2 Adjectives

# %%
df_ar_gf_adjs["gender"], df_ar_gf_adjs["other_gender_form"] = zip(
    *df_ar_gf_adjs.apply(get_gender, args=(wikitionary,), axis="columns")
)
df_ar_gf_adjs["gender"].value_counts()
# Out:
# gender
# masc    18
# Name: count, dtype: int64

# %%
df_ar_gf_adjs["masc_pl"], df_ar_gf_adjs["fem_pl"]  = zip(*df_ar_gf_adjs.apply(get_plural, args=(wikitionary,), axis="columns"))
print(df_ar_gf_adjs["masc_pl"].isna().value_counts())
print(df_ar_gf_adjs["fem_pl"].isna().value_counts())
# Out:
# masc_pl
# False    18
# Name: count, dtype: int64
# fem_pl
# False    18
# Name: count, dtype: int64

# %%
df_ar_gf_adjs["root"] = df_ar_gf_adjs.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_adjs["root"].isna().value_counts()
# Out:
# root
# True     10
# False     8
# Name: count, dtype: int64

# %% [markdown]
# ## 6.3 Verbs

# %%
df_ar_gf_verbs["verb_form"] = df_ar_gf_verbs.apply(get_verb_form, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["verb_form"].isna().value_counts()
# Out:
# verb_form
# False    5
# Name: count, dtype: int64

# %%
df_ar_gf_verbs["root"] = df_ar_gf_verbs.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["root"].isna().value_counts()
# Out:
# root
# False    5
# Name: count, dtype: int64

# %%
df_ar_gf_verbs["imperfect"] = df_ar_gf_verbs.apply(get_imperfect_form, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["imperfect"].isna().value_counts()
# Out:
# imperfect
# False    5
# Name: count, dtype: int64

# %% [markdown]
# # 7.0 Export Data

# %%
df_ar_gf_verbs.drop(columns=["select", "entry_num", "pos"], inplace=True)
df_ar_gf_nouns.drop(columns=["select", "entry_num", "pos"], inplace=True)
df_ar_gf_adjs.drop(columns=["select", "entry_num", "pos"], inplace=True)

# %%
RUN_TIME_STAMP = date_time = datetime.fromtimestamp(time.time()).strftime("%Y%m%d.%H%M%S")
df_ar_gf_verbs.to_csv(output_dir / f"{RUN_TIME_STAMP}_verbs_lexicon.csv", decimal=",")
df_ar_gf_nouns.to_csv(output_dir / f"{RUN_TIME_STAMP}_nouns_lexicon.csv", decimal=",")
df_ar_gf_adjs.to_csv(output_dir / f"{RUN_TIME_STAMP}_adjectives_lexicon.csv", decimal=",")

# %% [markdown]
# # 8.0 Visualize Data

# %%
df_ar_gf_verbs
# Out:
#         li  wiki_idx    ar              en vocal_forms  nesba
# 79   22868    117316   صمم  designate_4_V2     صَمَّمَ      0  \
# 110  38154       698   ملك       have_1_V2      مَلَكَ      0
# 232  75568      8035   عرض       show_2_V2      عَرَضَ      0
# 249  78616      6248  تكلم      speak_3_V2   تَكَلَّمَ      0
# 266  82083     20863   نجح      succeed_V2      نَجَحَ      0
#
#                                            ar_letters
# 79                 صاد-فتحة | ميم-شدة-فتحة | ميم-فتحة  \
# 110                    ميم-فتحة | لام-فتحة | كاف-فتحة
# 232   |  |  |  |  |  | عين-فتحة | راء-فتحة | ضاد-فتحة
# 249     تاء-فتحة | كاف-فتحة | لام-شدة-فتحة | ميم-فتحة
# 266                    نون-فتحة | جيم-فتحة | حاء-فتحة
#
#                                                 senses verb_form root
# 79   [to deafen [+accusative], to deafen / to resol...        II  صمم  \
# 110  [to take in possession, to take over, to acqui...         I  ملك
# 232  [to appear / to happen, to occur / to show, to...         I  عرض
# 249    [to talk, to have a discussion or conversation]         V  كلم
# 266                     [to succeed, to be successful]         I  نجح
#
#        imperfect
# 79     يُصَمِّمُ
# 110     يَمْلِكُ
# 232     يَعْرِضُ
# 249  يَتَكَلَّمُ
# 266     يَنْجَحُ

# %%
df_ar_gf_adjs
# Out:
#         li  wiki_idx               ar                  en      vocal_forms
# 1      292      5922           مُطلَق        absolute_3_A          مُطْلَق  \
# 7     3970        64             عربي            arabic_A         عَرَبِيّ
# 48   16805     25071        شُيُوعِيّ         communist_A        شُيُوعِيّ
# 50   17986      8330           دستوري  constitutional_2_A      دُسْتُورِيّ
# 62   20596      2656            جَارٍ           current_A            جَارٍ
# 100  33131     10031             سابق          former_3_A           سَابِق
# 102  33517      4339             حُرّ            free_1_A             حُرّ
# 121  39071     12466              عال            high_1_A            عَالٍ
# 141  42239      7474           شَخْصي      individual_4_A         شَخْصِيّ
# 167  46486      4262            كبِير           large_1_A           كَبِير
# 175  49027      1238        مُنْخَفِض             low_1_A        مُنْخَفِض
# 177  51991      4970          عسْكرِي        military_2_A       عَسْكَرِيّ
# 196  56486     22237          رسْمِيّ        official_1_A         رَسْمِيّ
# 199  56488     22237             رسمي        official_3_A         رَسْمِيّ
# 203  57340    114892  أُرْثُوذُكْسِيّ        orthodox_3_A  أُرْثُوذُكْسِيّ
# 204  58889    127672          برلماني   parliamentary_2_A    بَرْلَمَانِيّ
# 258  79531      2788             مربع          square_1_A         مُرَبَّع
# 276  86624     23237            مجموع           total_1_A         مَجْمُوع
#
#      nesba                                         ar_letters
# 1        0                ميم-ضمة | طاء-سكون | لام-فتحة | قاف  \
# 7        1           عين-فتحة | راء-فتحة | باء-كسرة | ياء-شدة
# 48       1       شين-ضمة | ياء-ضمة | واو | عين-كسرة | ياء-شدة
# 50       1  دال-ضمة | سين-سكون | تاء-ضمة | واو | راء-كسرة ...
# 62       0                        جيم-فتحة | ألف | راء-كسرتان
# 100      0                    سين-فتحة | ألف | باء-كسرة | قاف
# 102      0                                  حاء-ضمة | راء-شدة
# 121      0                        عين-فتحة | ألف | لام-كسرتان
# 141      1           شين-فتحة | خاء-سكون | صاد-كسرة | ياء-شدة
# 167      0                    كاف-فتحة | باء-كسرة | ياء | راء
# 175      0     ميم-ضمة | نون-سكون | خاء-فتحة | فاء-كسرة | ضاد
# 177      0  عين-فتحة | سين-سكون | كاف-فتحة | راء-كسرة | يا...
# 196      1           راء-فتحة | سين-سكون | ميم-كسرة | ياء-شدة
# 199      1           راء-فتحة | سين-سكون | ميم-كسرة | ياء-شدة
# 203      1  همزة على الألف-ضمة | راء-سكون | ثاء-ضمة | واو ...
# 204      1  باء-فتحة | راء-سكون | لام-فتحة | ميم-فتحة | أل...
# 258      0            ميم-ضمة | راء-فتحة | باء-شدة-فتحة | عين
# 276      0          ميم-فتحة | جيم-سكون | ميم-ضمة | واو | عين
#
#                                                 senses gender
# 1    [absolute, utter, very, unlimited, unrestricte...   masc  \
# 7                            [Arab / Arabic / Arabian]   masc
# 48                  [communist / Communist / communal]   masc
# 50                                    [constitutional]   masc
# 62                 [active participle of جَرَى (jarā)]   masc
# 100  [preceding, previous / former / active partici...   masc
# 102  [free / unimpeded / set free, freedman / born ...   masc
# 121  [active participle of عَلَا (ʕalā) or active p...   masc
# 141                        [own / personal / personal]   masc
# 167  [big, large / great, great importance / old (f...   masc
# 175  [low (altitude, frequency, price, etc.) / soft...   masc
# 177                                         [military]   masc
# 196  [official, legitimate / formal / normal / conv...   masc
# 199  [official, legitimate / formal / normal / conv...   masc
# 203                              [Orthodox / Orthodox]   masc
# 204                                    [parliamentary]   masc
# 258  [square, quadratic / fourfold, quadruple / tet...   masc
# 276                              [united / reconciled]   masc
#
#       other_gender_form             masc_pl              fem_pl  root
# 1            مُطْلَقَةٌ         مُطْلَقُونَ          مُطْلَقَات   طلق
# 7           عَرَبِيَّةٌ               عَرَب         عَرَبِيَّات  <NA>
# 48         شُيُوعِيَّةٌ       شُيُوعِيُّونَ        شُيُوعِيَّات  <NA>
# 50       دُسْتُورِيَّةٌ     دُسْتُورِيُّونَ      دُسْتُورِيَّات  <NA>
# 62            جَارِيَةٌ             جَارُون           جَارِيَات   جري
# 100           سَابِقَةٌ             سُبَّاق           سَابِقَات   سبق
# 102             حُرَّةٌ            أَحْرَار             حُرَّات   حرر
# 121           عَالِيَةٌ            عَالُونَ           عَالِيَات   علو
# 141         شَخْصِيَّةٌ        شَخْصِيُّونَ         شَخْصِيَّات  <NA>
# 167           كَبِيرَةٌ            كُبَرَاء           كَبِيرَات   كبر
# 175        مُنْخَفِضَةٌ       مُنْخَفِضُونَ        مُنْخَفِضَات   خفض
# 177       عَسْكَرِيَّةٌ            عَسَاكِر       عَسْكَرِيَّات  <NA>
# 196         رَسْمِيَّةٌ        رَسْمِيُّونَ         رَسْمِيَّات  <NA>
# 199         رَسْمِيَّةٌ        رَسْمِيُّونَ         رَسْمِيَّات  <NA>
# 203  أُرْثُوذُكْسِيَّةٌ  أُرْثُوذُكْسِيُّون  أُرْثُوذُكْسِيَّات  <NA>
# 204    بَرْلَمَانِيَّةٌ   بَرْلَمَانِيُّونَ    بَرْلَمَانِيَّات  <NA>
# 258         مُرَبَّعَةٌ        مُرَبَّعُونَ         مُرَبَّعَات  <NA>
# 276         مَجْمُوعَةٌ        مَجْمُوعُونَ         مَجْمُوعَات   جمع

# %%
df_ar_gf_nouns
# Out:
#         li  wiki_idx            ar                 en  entry_num
# 3     1558      8230     أفْغانِيّ        afghani_1_N          2  \
# 6     1643      1770          سِنّ            age_1_N          3
# 10    4109       503       مِنْطقة           area_6_N          3
# 11    4109       504       مِنْطقة           area_6_N          3
# 12    4109       505       مِنْطقة           area_6_N          3
# 14    4871    115331         آشوري       assyrian_2_N          2
# 15    6160      6264           منع            ban_2_N          2
# 18    7316    123391      بيلاروسي       belarusian_N          2
# 27    9270       274         كِتاب           book_1_N          3
# 35    9394      4496           حدّ         border_1_N          7
# 39   10872    116897        بلغاري        bulgarian_N          2
# 40   13580       827         رئِيس         chairman_N          2
# 44   14359       271         صينية          chinese_N          4
# 46   14638     26955   مَسِيحِيَّة   christianity_1_N          2
# 54   19228      2413           بلد        country_2_N          3
# 55   20590    115590        عُمْلة       currency_1_N          3
# 67   21757     20869          نقْص        decline_1_N          8
# 74   22351      5003  جُمْهُورِيّة      democracy_2_N          3
# 82   26444    115123        هولندي            dutch_N          2
# 83   26652      3888           شرق           east_4_N          3
# 86   28346     13023       مُساواة       equality_1_N          2
# 91   31802      1086           علم           flag_1_N          5
# 94   32046    120971         خَلَل           flaw_3_N          5
# 99   32346       794         دقِيق            flour_N          2
# 106  33608       290        فرنسية           french_N          2
# 123  40068       450       فُنْدُق            hotel_N          2
# 125  40241      3023           بشر            human_N          7
# 137  41860       875          دخْل           income_N          4
# 139  42126     23122        دَلِيل          index_2_N          2
# 144  42375      4863         تفاوت       inequality_N          2
# 146  42549      4618        تضخُّم      inflation_1_N          2
# 150  44251       330       إيطالية          italian_N          4
# 188                ميم-ضمة | سين-سكون | لام-كسرة | ميم
# 194                    شين-فتحة | ميم-فتحة | ألف | لام
# 206         راء-فتحة | همزة على الياء-كسرة | ياء | سين
# 208         راء-فتحة | همزة على الياء-كسرة | ياء | سين
# 210        ميم-فتحة | لام-كسرة | كاف-فتحة | تاء مربوطة
# 214                          سين-كسرة | عين-سكون | راء
# 218            ميم-ضمة | عين-فتحة | دال-شدة-فتحة | لام
# 222                               دال-كسرة | ياء | نون
# 227  جيم-ضمة | ميم-سكون | هاء-ضمة | واو | راء-كسرة ...
# 231                 راء-ضمة | واو | سين-كسرة | ياء-شدة
# 244                     جيم-فتحة | نون-ضمة | واو | باء
# 248  همزة تحت الألف-كسرة | سين-سكون | باء-فتحة | أل...
# 260                   نون-فتحة | شين-فتحة | ألف | همزة
# 271  همزة تحت الألف-كسرة | راء-سكون | هاء-فتحة | أل...
# 274  تاء-فتحة | ألف | ياء-سكون | لام-فتحة | ألف | ن...
# 280  تاء-ضمة | راء-سكون | كاف-كسرة | ياء-شدة-فتحة |...
# 281                              ميم-فتحة | ألف | همزة
# 287                          غين-فتحة | راء-سكون | باء
# 291                    عين-فتحة | ألف | لام-فتحة | ميم
# 293                    عين-فتحة | ألف | لام-فتحة | ميم
# 295                   سين-فتحة | نون-فتحة | تاء مربوطة
#
#                                                 senses gender
# 3                                             [Afghan]   masc  \
# 6    [tooth, tusk, fang / point or tip / a spearhea...    fem
# 10   [belt, girdle / zone / vicinity, range, distri...    fem
# 11   [zone / vicinity, range, district, area, terri...    fem
# 12       [verbal noun of مَنْطَقَ (manṭaqa) (form Iq)]    fem
# 14                                [Assyrian, Ashurite]   masc
# 15   [verbal noun of مَنَعَ (manaʕa) (form I) / pre...   masc
# 18                               [Belarusian (person)]   masc
# 27   [verbal noun of كَتَبَ (kataba) (form I) / ver...   masc
# 35   [verbal noun of حَدَّ (ḥadda) (form I) / limit...   masc
# 39      [Bulgarian (native or inhabitant of Bulgaria)]   masc
# 40   [boss, chief, leader / director / headmaster, ...   masc
# 44                                  [Chinese language]    fem
# 46   [Christianity / female equivalent of مَسِيحِيّ...    fem
# 54   [country, land, homeland / town, city / place,...   masc
# 55                      [currency, standardized money]    fem
# 67   [verbal noun of نَقَصَ (naqaṣa) (form I) / red...   masc
# 74                          [republicanism / republic]    fem
# 82                            [Netherlander, Dutchman]   masc
# 83                                      [east; Orient]   masc
# 86   [verbal noun of سَاوَى (sāwā) (form III) / equ...    fem
# 91   [sign, token, mark, badge / harelip / road sig...   masc
# 94   [gap, breach, interstice, interspace, chink / ...   masc
# 99                                       [flour, meal]   masc
# 106  [female equivalent of فَرَنْسِيّ (faransiyy, “...    fem
# 123                                      [inn / hotel]   masc
# 125                        [human / humans, humankind]   masc
# 137  [income / revenues, receipts, returns / interf...   masc
# 139  [sign, indication, proof, demonstration, evide...   masc
# 144    [verbal noun of تَفَاوَتَ (tafāwata) (form VI)]   masc
# 146  [verbal noun of تَضَخَّمَ (taḍaḵḵama) (form V)...   masc
# 150                                 [Italian language]    fem
# 157                         [king, sovereign, monarch]   masc
# 171                                      [Latvian man]   masc
# 173  [boss, chief, leader / director / headmaster, ...   masc
# 180                                         [monarchy]    fem
# 182                         [mother / origin / source]    fem
# 188                                           [Muslim]   masc
# 194                                            [north]    fem
# 206  [boss, chief, leader / director / headmaster, ...   masc
# 208  [boss, chief, leader / director / headmaster, ...   masc
# 210                                            [queen]    fem
# 214  [price / quote (a summary of work to be done w...   masc
# 218                                   [rate / average]   masc
# 222  [verbal noun of دَانَ (dāna, “to be religious”...   masc
# 227                         [republicanism / republic]    fem
# 231                                          [Russian]   masc
# 244                                            [south]   masc
# 248                                         [Spaniard]   masc
# 260                       [starch, cornstarch, farina]   masc
# 271                                        [terrorist]   masc
# 274                                    [Thai language]   masc
# 280                                 [Turkish language]    fem
# 281  [water / liquid, fluid, the liquefied or molte...   masc
# 287  [verbal noun of غَرَبَ (ḡaraba) (form I) / wes...   masc
# 291  [world / universe, cosmos, existence / world, ...   masc
# 293  [world / universe, cosmos, existence / world, ...   masc
# 295                                             [year]    fem
#
#               plural  root
# 3           أَفْغَان  <NA>
# 6           أَسْنَان  <NA>
# 10        مِنْطَقَات   نطق
# 11        مَنْطِقَات   نطق
# 12              <NA>   نطق
# 14       آشُورِيُّون  <NA>
# 15              <NA>   منع
# 18              <NA>  <NA>
# 27             كُتُب  <NA>
# 35            حُدُود  <NA>
# 39           بُلْغار  <NA>
# 40          رُؤَسَاء   رءس
# 44              <NA>  <NA>
# 46      مَسِيحِيَّات  <NA>
# 54            بِلَاد  <NA>
# 55          عُمْلَات   عمل
# 67              <NA>  <NA>
# 74    جُمْهُورِيَّات  <NA>
# 82   هُولَنْدِيُّونَ  <NA>
# 83              <NA>  <NA>
# 86              <NA>  <NA>
# 91          أَعْلَام  <NA>
# 94            خِلَال   خلل
# 99         غير معدود  <NA>
# 106    فَرَنْسِيَّات  <NA>
# 123         فَنَادِق  <NA>
# 125            بَشَر   بشر
# 137             <NA>  <NA>
# 139         أَدِلَّة   دلل
# 144             <NA>   فوت
# 146             <NA>   ضخم
# 150             <NA>  <NA>
# 157           مُلُوك  <NA>
# 171             <NA>  <NA>
# 173         رُؤَسَاء   رءس
# 180      مَلَكِيَّات   ملك
# 182        أُمَّهَات   ءمم
# 188       مُسْلِمُون   سلم
# 194             <NA>   شمل
# 206         رُؤَسَاء   رءس
# 208         رُؤَسَاء   رءس
# 210         مَلِكَات  <NA>
# 214         أَسْعَار   سعر
# 218             <NA>   عدل
# 222         أَدْيَان  <NA>
# 227   جُمْهُورِيَّات  <NA>
# 231             <NA>  <NA>
# 244             <NA>   جنب
# 248             <NA>  <NA>
# 260             <NA>   نشو
# 271             <NA>  <NA>
# 274             <NA>  <NA>
# 280             <NA>  <NA>
# 281           مِيَاه   موه
# 287             <NA>  <NA>
# 291        عَالَمُون  <NA>
# 293        عَالَمُون  <NA>
# 295         سَنَوَات  <NA>
