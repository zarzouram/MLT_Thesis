# %% [markdown]
# # 1.0 Imports

# %%
import gzip
import json
import re
import time
from datetime import datetime
from pathlib import Path
from typing import Dict, List
from unicodedata import normalize

import pandas as pd
from pyarabic.araby import DIACRITICS, SHADDA, is_arabicword, name, vocalizedlike

# %% [markdown]
# # 2.0 Define Paths

# %%
# Path for preproceed Wikitionary
wiktionary_dir = Path("../data/processed/wikidata")
wiki_jsonl_path = wiktionary_dir / "ar-wiktextract-data.json.gz"
wiki_indices_path = wiktionary_dir / "ar_reindex.json.gz"

# %%
# Arabic GF-Wordnet
data_dir = Path("../data/interim/unambiguous")
ar_words_gf_path = data_dir / "20240202.1101_Q79_Q34_Q16_word_unambiguous.csv"

# %%
# Path to save words status
output_dir = Path("../data/interim/lexicon")
output_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # 3.0 Define Variables

# %%
DIACRITICS = set(DIACRITICS)  # Aabic diacritics/short vowels

# %%
TIMESTAMP = "_".join(ar_words_gf_path.stem.split("_")[:-2])

# %% [markdown]
# ## 4.0 Define Functions

# %% [markdown]
# ### 4.1 Utilities Functions

# %%
def reorder_shadda(ar_string: str) -> str:
    """unicodedata.normalize put shadda before diacritics; not correct"""
    list_ar_str = list(ar_string)

    for i in range(len(list_ar_str) - 1):
        char = list_ar_str[i]
        next_char = list_ar_str[i + 1]

        if char in DIACRITICS and next_char == SHADDA:
            list_ar_str[i], list_ar_str[i + 1] = (
                next_char,
                char,
            )  # Swap shadda and diacritic

    return "".join(list_ar_str)

# %%
def normalize_ar(ar_vocalized: str, verbose: bool = False) -> str:
    """get the normal form for the Unicode string unistr using NFC then fix the shadda order issue"""
    ar_norm = normalize("NFC", ar_vocalized)
    ar_norm = reorder_shadda(ar_norm)
    if verbose:
        print([name(char) for char in ar_norm])
    return ar_norm

# %% [markdown]
# ## 4.2 Morphology Features

# %% [markdown]
# ### 4.2.1 Gender

# %%
def get_noun_gender(entry, form):
    for _, word_data in entry.items():
        categories: List[str] = word_data.get("categories", [])
        for category in categories:
            masculine = category.find("masculine") != -1
            feminine = category.find("feminine") != -1
            if masculine and feminine:
                return "N"
            elif masculine:
                return "masc"
            elif feminine:
                return "fem"
        return pd.NA

# %%
def get_adj_gender(entry, form):
    for _, word_data in entry.items():
        word_forms: List[dict] = word_data.get("forms", [])
        masculine, feminine = None, None
        for form_dict in word_forms:
            if {'indefinite', 'masculine', 'singular', 'nominative'}.issubset(form_dict.get("tags", [])):
                masculine = normalize_ar(form_dict["form"])
            elif {'indefinite', 'feminine', 'singular', 'nominative'}.issubset(form_dict.get("tags", [])):
                feminine = normalize_ar(form_dict["form"])
            if masculine and feminine:
                break

        # TODO: Confusing = redesign
        if not masculine and not feminine:
            return pd.NA, pd.NA
        elif not masculine or not feminine:
            return "masc", pd.NA if masculine else "fem", pd.NA

        if vocalizedlike(form, masculine):
            return "masc", feminine
        return "fem", masculine

# %%
def get_gender(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    pos = row["wiki_pos"]
    form: str = normalize_ar(row["vocal_forms"])
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        if pos == "noun":
            return get_noun_gender(entry, None)
        elif pos == "adj":
            return get_adj_gender(entry, form)
    return [pd.NA] * 2

# %% [markdown]
# ### 4.2.2 Plural

# %%
def get_noun_plural(entry):
    for _, word_data in entry.items():
        word_forms = word_data.get("forms", [])
        for form_dict in word_forms:
            if "plural" == form_dict.get("tags", [None])[0]:
                return form_dict["form"]
        inflections = word_data.get("head_templates", [])
        for dict_inflection in inflections:
            plural = dict_inflection.get("args", {}).get("pl", None)
            if plural is not None:
                if is_arabicword(plural):
                    return normalize_ar(plural)
                elif plural == "-":
                    return normalize_ar("غير معدود")
                return normalize_ar("جمع سالم")
    return pd.NA

# %%
def get_adj_plural(entry):
    for _, word_data in entry.items():
        word_forms = word_data.get("forms", [])
        masc_pl, fem_pl = None, None
        for form_dict in word_forms:
            if ['masculine', 'plural'] == form_dict.get("tags", [None]):
                masc_pl = form_dict["form"]
            elif ['feminine', 'plural'] == form_dict.get("tags", [None]):
                fem_pl = form_dict["form"]
            if masc_pl and fem_pl:
                break
    masc_pl = normalize_ar(masc_pl) if masc_pl else pd.NA
    fem_pl = normalize_ar(fem_pl) if fem_pl else pd.NA

    return masc_pl, fem_pl

# %%
def get_plural(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    pos = row["wiki_pos"]
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        if pos == "noun":
            return get_noun_plural(entry)
        elif pos == "adj":
            return get_adj_plural(entry)
    if pos == "noun":
        return pd.NA
    elif pos == "adj":
        return [pd.NA]*2

# %% [markdown]
# ### 4.2.3 Root

# %%
def get_root(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        for _, word_data in entry.items():
            for etymology in word_data.get('etymology_templates', []):
                if etymology.get("name", "").startswith("ar-root"):
                    if len(etymology["args"]) == 3:
                        return normalize_ar("".join(list(etymology["args"].values())))
                    if len(etymology["args"]) == 1:
                        return normalize_ar("".join(etymology["args"]["1"].split()))
        return pd.NA

# %% [markdown]
# ### 4.2.4 Verb Forms

# %%
def get_verb_form(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        form_number = None
        for _, word_data in entry.items():
            form_numbers = []
            categories: List[str] = word_data.get("categories", [])
            for category in categories:
                if match := re.search(r"(?<=form-)\w+(?= verbs)", category):
                    form_numbers.append(match.group())
            if form_numbers:
                form_number = max(form_numbers)

        return f"Form{form_number}" if form_number is not None else pd.NA

# %%
def get_imperfect_form(row, wikitionary):
    wiki_idx = int(row["wiki_idx"])
    if wiki_idx > -1:
        entry = wikitionary[wiki_idx]
        for _, word_data in entry.items():
            word_forms: List[dict] = word_data.get("forms", [])
            for form_dict in word_forms:
                if {
                    "active",
                    "indicative",
                    "masculine",
                    "non-past",
                    "imperfective",
                    "singular",
                    "third-person",
                }.issubset(form_dict.get("tags", [])):
                    return normalize_ar(form_dict["form"])

        return pd.NA

# %% [markdown]
# # 5.0 Load Files

# %%
# 1. load the wikitionary
with gzip.open(wiki_jsonl_path, "rt", encoding="utf-8") as gzip_obj:
    wikitionary = []
    for i, json_line in enumerate(gzip_obj):
        wikitionary.append(dict(json.loads(json_line)))
        print(f"Reading line-{i}", end="\r")
# Out:
# Reading line-1912
# Reading line-128636

# %%
# 2. load the csv arabic-english_gf words
df_ar_gf = pd.read_csv(ar_words_gf_path, delimiter="\t", index_col=0)

# %%
df_ar_gf = df_ar_gf[df_ar_gf["select"] == 1]

# %%
# Get nouns, adjectives and verbs
df_ar_gf_nouns = df_ar_gf.copy()[(df_ar_gf["wiki_pos"] == "noun") & (df_ar_gf["select"] == 1)]
df_ar_gf_adjs = df_ar_gf.copy()[(df_ar_gf["wiki_pos"] == "adj") & (df_ar_gf["select"] == 1)]
df_ar_gf_verbs = df_ar_gf.copy()[(df_ar_gf["wiki_pos"] == "verb") & (df_ar_gf["select"] == 1)]

# %% [markdown]
# # 6.0 Get Morphological Features

# %% [markdown]
# ## 6.1 Nouns

# %%
df_ar_gf_nouns["gender"] = df_ar_gf_nouns.apply(get_gender, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["gender"].value_counts()
# Out:
# gender
# [<NA>, <NA>]    18
# masc             9
# fem              9
# Name: count, dtype: int64

# %%
df_ar_gf_nouns["plural"] = df_ar_gf_nouns.apply(get_plural, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["plural"].isna().value_counts()
# Out:
# plural
# True     23
# False    17
# Name: count, dtype: int64

# %%
df_ar_gf_nouns["root"] = df_ar_gf_nouns.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_nouns["root"].isna().value_counts()
# Out:
# root
# True     27
# False    13
# Name: count, dtype: int64

# %% [markdown]
# ## 6.2 Adjectives

# %%
df_ar_gf_adjs["gender"], df_ar_gf_adjs["other_gender_form"] = zip(
    *df_ar_gf_adjs.apply(get_gender, args=(wikitionary,), axis="columns")
)
df_ar_gf_adjs["gender"].value_counts()
# Out:
# gender
# masc    3
# Name: count, dtype: int64

# %%
df_ar_gf_adjs["masc_pl"], df_ar_gf_adjs["fem_pl"]  = zip(*df_ar_gf_adjs.apply(get_plural, args=(wikitionary,), axis="columns"))
print(df_ar_gf_adjs["masc_pl"].isna().value_counts())
print(df_ar_gf_adjs["fem_pl"].isna().value_counts())
# Out:
# masc_pl
# True     5
# False    3
# Name: count, dtype: int64
# fem_pl
# True     5
# False    3
# Name: count, dtype: int64

# %%
df_ar_gf_adjs["root"] = df_ar_gf_adjs.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_adjs["root"].isna().value_counts()
# Out:
# root
# True     5
# False    3
# Name: count, dtype: int64

# %% [markdown]
# ## 6.3 Verbs

# %%
df_ar_gf_verbs["verb_form"] = df_ar_gf_verbs.apply(get_verb_form, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["verb_form"].isna().value_counts()

# %%
df_ar_gf_verbs["root"] = df_ar_gf_verbs.apply(get_root, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["root"].isna().value_counts()
# Out:
# root
# True    1
# Name: count, dtype: int64

# %%
df_ar_gf_verbs["imperfect"] = df_ar_gf_verbs.apply(get_imperfect_form, args=(wikitionary,), axis="columns")
df_ar_gf_verbs["imperfect"].isna().value_counts()
# Out:
# imperfect
# True    1
# Name: count, dtype: int64

# %% [markdown]
# # 7.0 Export Data

# %%
# df_ar_gf_verbs.drop(columns=["select", "entry_num", "pos"], inplace=True)
df_ar_gf_nouns.drop(columns=["select", "entry_num", "pos"], inplace=True)
df_ar_gf_adjs.drop(columns=["select", "entry_num", "pos"], inplace=True)

# %%
# df_ar_gf_verbs.to_csv(output_dir / f"{TIMESTAMP}_verbs_lexicon.csv", decimal=",")
df_ar_gf_nouns.to_csv(output_dir / f"{TIMESTAMP}_nouns_lexicon.csv", decimal=",")
df_ar_gf_adjs.to_csv(output_dir / f"{TIMESTAMP}_adjectives_lexicon.csv", decimal=",")

# %% [markdown]
# # 8.0 Visualize Data

# %%
df_ar_gf_verbs
# Out:
# Empty DataFrame
# Columns: [wiki_idx, no_en_entry, en_entry, ar, vocal_forms, pos, wiki_pos, select, entry_num, ar_letters, senses, tim_translit, file]
# Index: []

# %%
df_ar_gf_adjs
# Out:
#     wiki_idx  no_en_entry           en_entry      ar  vocal_forms wiki_pos
# 32        -1            1      demographic_N  سكانية  سُكّانِيَّة      adj  \
# 80        -1            1  life_expectancy_N   متوقع   مُتَوَقَّع      adj
# 68        -1            1         percent_MU   مئوية   مِئَوِيَّة      adj
# 8         -1            1            vat_1_N   مضافة      مُضافَة      adj
# 21      7862            0        average_1_N   متوسط   مُتَوَسِّط      adj
# 4      26328            0     healthcare_2_N    صحية    صِحِّيَّة      adj
# 49      7862            1  life_expectancy_N   متوسط   مُتَوَسِّط      adj
# 1       3016            0         regime_1_N    حاكم       حَاكِم      adj
#
#                                            ar_letters
# 32  سين-ضمة | كاف-شدة | ألف | نون-كسرة | ياء-شدة-ف...  \
# 80  ميم-ضمة | تاء-فتحة | واو-فتحة | قاف-شدة-فتحة |...
# 68  ميم-كسرة | همزة على الياء-فتحة | واو-كسرة | يا...
# 8         ميم-ضمة | ضاد | ألف | فاء-فتحة | تاء مربوطة
# 21  ميم-ضمة | تاء-فتحة | واو-فتحة | سين-شدة-كسرة |...
# 4   صاد-كسرة | حاء-شدة-كسرة | ياء-شدة-فتحة | تاء م...
# 49  ميم-ضمة | تاء-فتحة | واو-فتحة | سين-شدة-كسرة |...
# 1                     حاء-فتحة | ألف | كاف-كسرة | ميم
#
#                                                senses tim_translit  file
# 32                 residential / population+[fem.sg.]  suk~Aniy~ap   NaN  \
# 80                                                NaN          NaN   NaN
# 68      one-hundred / hundreth / percentage+[fem.sg.]   mi}awiy~ap   NaN
# 8                                     added+[fem.sg.]      muDAfap   NaN
# 21  ['being in the middle, mediating / middle, cen...   mutawas~iT   NaN
# 4          ['feminine singular of صِحِّيّ (ṣiḥḥiyy)']    SiH~iy~ap   NaN
# 49  ['being in the middle, mediating / middle, cen...   mutawas~iT   NaN
# 1                    ['ruling, governing / decisive']       HaAkim   NaN
#
#    gender other_gender_form         masc_pl         fem_pl  root
# 32   <NA>              <NA>            <NA>           <NA>  None
# 80   <NA>              <NA>            <NA>           <NA>  None
# 68   <NA>              <NA>            <NA>           <NA>  None
# 8    <NA>              <NA>            <NA>           <NA>  None
# 21   masc     مُتَوَسِّطَةٌ  مُتَوَسِّطُونَ  مُتَوَسِّطَات   وسط
# 4    <NA>              <NA>            <NA>           <NA>  <NA>
# 49   masc     مُتَوَسِّطَةٌ  مُتَوَسِّطُونَ  مُتَوَسِّطَات   وسط
# 1    masc         حَاكِمَةٌ       حَاكِمُون      حَاكِمَات   حكم

# %%
df_ar_gf_nouns
# Out:
#     wiki_idx  no_en_entry            en_entry          ar       vocal_forms
# 17        -1            0         algonquin_N   ألجونكوين         ألجونكوين  \
# 22        -1            0         blackfoot_N     بلاكفوت           بلاكفوت
# 23        -1            0            cayuga_N      كايوجا            كايوجا
# 10        -1            0           chinese_N       صينىة         صِينِيَّة
# 24        -1            0         chipewyan_N    تشيبويان          تشيبويان
# 33        -1            1       demographic_N      تركيبة        تَرْكِيبُه
# 35        -1            0           english_N  الإنجليزية  الإِنْجلِيزِيَّة
# 41        -1            0        filipino_2_N   الفلبينية  الفِلِبِّينِيَّة
# 44        -1            0           finnish_N   الفنلندية  الفِنْلَنْدِيَّة
# 45        -1            0             haida_N        هيدا              هيدا
# 64        -1            0          mohawk_2_N       موهوك         مَوَّهُوك
# 65        -1            0            oneida_N      أونيدا            أونيدا
# 66        -1            0          onondaga_N   أونونداجا         أونونداجا
# 71        -1            0           swedish_N    السويدية     السُوِيدِيَّة
# 73        -1            0           tlingit_N     تلينغيت           تلينغيت
# 74        -1            0         tsimshian_N    تسيمشيان          تسيمشيان
# 77        -1            0           yiddish_N    اليديشية          اليديشية
# 30     24287            0              cree_N         كري               كري
# 34        41            0           dollar_MU       دولار           دُولَار
# 38     12084            1   european_union_NP       اتحاد         اِتِّحَاد
# 48      4589            1     head_of_state_N        دولة           دَوْلَة
# 3     124114            0      healthcare_2_N       رعاية           رِعايَة
# 63      5386            0          literacy_N       كتابة          كِتَابَة
# 61      6133            0          literacy_N       معرفة         مَعْرِفَة
# 62      8344            0          literacy_N       قراءة          قِرَاءَة
# 67      5710            1          percent_MU        نسبة           نِسْبَة
# 69      5390            0          point_10_N        نقطة           نُقْطَة
# 9        818            0  prime_minister_2_N        وزير            وَزِير
# 0        661            0          regime_1_N        نظام            نِظَام
# 72       661            0          system_4_N        نظام            نِظَام
# 75    117666            0      unemployment_N       بطالة          بِطَالَة
# 6      20995            1             vat_1_N        قيمة            قِيمَة
# 5     117242            1             vat_1_N       ضريبة          ضَرِيبَة
# 28      2406            0            coptic_N        قبطي          قِبْطِيّ
# 40      3625            1   european_union_NP      أوروبي       أُورُوبِّيّ
# 46       827            1     head_of_state_N        رئيس            رَئِيس
# 13     13023            1        inequality_N      مساواة         مُسَاوَاة
# 81        -1            0             yen_2_N          ين               يِن
# 19        65            0            arabic_N        عربي          عَرَبِيّ
# 56      2554            1   life_expectancy_N         عمر             عُمْر
#
#    wiki_pos                                         ar_letters
# 17     noun  همزة على الألف | لام | جيم | واو | نون | كاف |...  \
# 22     noun            باء | لام | ألف | كاف | فاء | واو | تاء
# 23     noun                  كاف | ألف | ياء | واو | جيم | ألف
# 10     noun  صاد-كسرة | ياء | نون-كسرة | ياء-شدة-فتحة | تاء...
# 24     noun      تاء | شين | ياء | باء | واو | ياء | ألف | نون
# 33     noun  تاء-فتحة | راء-سكون | كاف-كسرة | ياء | باء-ضمة...
# 35     noun  ألف | لام | همزة تحت الألف-كسرة | نون-سكون | ج...
# 41     noun  ألف | لام | فاء-كسرة | لام-كسرة | باء-شدة-كسرة...
# 44     noun  ألف | لام | فاء-كسرة | نون-سكون | لام-فتحة | ن...
# 45     noun                              هاء | ياء | دال | ألف
# 64     noun                                                NaN
# 65     noun       همزة على الألف | واو | نون | ياء | دال | ألف
# 66     noun  همزة على الألف | واو | نون | واو | نون | دال |...
# 71     noun  ألف | لام | سين-ضمة | واو-كسرة | ياء | دال-كسر...
# 73     noun            تاء | لام | ياء | نون | غين | ياء | تاء
# 74     noun      تاء | سين | ياء | ميم | شين | ياء | ألف | نون
# 77     noun  ألف | لام | ياء | دال | ياء | شين | ياء | تاء ...
# 30     noun                                                NaN
# 34     noun               دال-ضمة | واو | لام-فتحة | ألف | راء
# 38     noun     ألف-كسرة | تاء-شدة-كسرة | حاء-فتحة | ألف | دال
# 48     noun        دال-فتحة | واو-سكون | لام-فتحة | تاء مربوطة
# 3      noun       راء-كسرة | عين | ألف | ياء-فتحة | تاء مربوطة
# 63     noun  كاف-كسرة | تاء-فتحة | ألف | باء-فتحة | تاء مربوطة
# 61     noun  ميم-فتحة | عين-سكون | راء-كسرة | فاء-فتحة | تا...
# 62     noun  قاف-كسرة | راء-فتحة | ألف | همزة-فتحة | تاء مر...
# 67     noun        نون-كسرة | سين-سكون | باء-فتحة | تاء مربوطة
# 69     noun         نون-ضمة | قاف-سكون | طاء-فتحة | تاء مربوطة
# 9      noun                    واو-فتحة | زاي-كسرة | ياء | راء
# 0      noun                    نون-كسرة | ظاء-فتحة | ألف | ميم
# 72     noun                    نون-كسرة | ظاء-فتحة | ألف | ميم
# 75     noun  باء-كسرة | طاء-فتحة | ألف | لام-فتحة | تاء مربوطة
# 6      noun             قاف-كسرة | ياء | ميم-فتحة | تاء مربوطة
# 5      noun  ضاد-فتحة | راء-كسرة | ياء | باء-فتحة | تاء مربوطة
# 28     noun           قاف-كسرة | باء-سكون | طاء-كسرة | ياء-شدة
# 40     noun  همزة على الألف-ضمة | واو | راء-ضمة | واو | باء...
# 46     noun         راء-فتحة | همزة على الياء-كسرة | ياء | سين
# 13     noun  ميم-ضمة | سين-فتحة | ألف | واو-فتحة | ألف | تا...
# 81     noun                                ياء-كسرة | نون-كسرة
# 19     noun           عين-فتحة | راء-فتحة | باء-كسرة | ياء-شدة
# 56     noun                           عين-ضمة | ميم-سكون | راء
#
#                                                senses      tim_translit  file
# 17                                                NaN         >ljwnkwyn   NaN  \
# 22                                                NaN           blAkfwt   NaN
# 23                                                NaN            kAywjA   NaN
# 10                                  Chinese+[fem.sg.]         Siyniy~ap   NaN
# 24                                                NaN          t$ybwyAn   NaN
# 33                installation / assembling+its / his        tarokiybuh   NaN
# 35                   the+English_(language)+[fem.sg.]  Al<inojliyziy~ap   NaN
# 41                the+Philippine / Filipino+[fem.sg.]  Alfilib~iyniy~ap   NaN
# 44                              the+Finnish+[fem.sg.]  Alfinolanodiy~ap   NaN
# 45                                                NaN              hydA   NaN
# 64  have_abundant_water / add_water / dilute+they_...               NaN   NaN
# 65                                                NaN            >wnydA   NaN
# 66                                                NaN         >wnwndAjA   NaN
# 71                              the+Swedish+[fem.sg.]     Alsuwiydiy~ap   NaN
# 73                                                NaN           tlyngyt   NaN
# 74                                                NaN          tsym$yAn   NaN
# 77                                                NaN          Alydy$yp   NaN
# 30                                      ['spherical']               NaN   NaN
# 34                                         ['dollar']           duwlaAr   NaN
# 38  ['verbal noun of اِتَّحَدَ (ittaḥada) (form VI...         Ait~iHaAd   NaN
# 48  ['state (sovereign polity) / alternation, chan...           dawolap   NaN
# 3                          ['care, support, custody']           riEAyap   NaN
# 63  ['verbal noun of كَتَبَ (kataba) (form I) / wr...          kitaAbap   NaN
# 61  ['verbal noun of عَرَفَ (ʕarafa) (form I) / kn...         maEorifap   NaN
# 62  ['verbal noun of قَرَأَ (qaraʔa) (form I) / re...          qiraA'ap   NaN
# 67  ['verbal noun of نَسَبَ (nasaba) (form I) / re...           nisobap   NaN
# 69  ['dot, point / period (punctuation mark) / spo...           nuqoTap   NaN
# 9   ['minister, cabinet minister / vizier / helper...            waziyr   NaN
# 0   ['system / regularity / order / method / rule ...            niZaAm   NaN
# 72  ['system / regularity / order / method / rule ...            niZaAm   NaN
# 75                        ['idleness / unemployment']          biTaAlap   NaN
# 6         ['value, worth / amount, quantity / price']            qiymap   NaN
# 5                       ['tribute, tax, public levy']          Dariybap   NaN
# 28                                           ['Copt']          qiboTiy~   NaN
# 40                                       ['European']       >uwruwb~iy~   NaN
# 46  ['boss, chief, leader / director / headmaster,...            ra}iys   NaN
# 13  ['verbal noun of سَاوَى (sāwā) (form III) / eq...         musaAwaAp   NaN
# 81                                                NaN               NaN   NaN
# 19                       ['Arab / Arabic (language)']          Earabiy~   NaN
# 56  ['life as a period of time, length of life, li...             Eumor   NaN
#
#           gender           plural  root
# 17  [<NA>, <NA>]             <NA>  None
# 22  [<NA>, <NA>]             <NA>  None
# 23  [<NA>, <NA>]             <NA>  None
# 10  [<NA>, <NA>]             <NA>  None
# 24  [<NA>, <NA>]             <NA>  None
# 33  [<NA>, <NA>]             <NA>  None
# 35  [<NA>, <NA>]             <NA>  None
# 41  [<NA>, <NA>]             <NA>  None
# 44  [<NA>, <NA>]             <NA>  None
# 45  [<NA>, <NA>]             <NA>  None
# 64  [<NA>, <NA>]             <NA>  None
# 65  [<NA>, <NA>]             <NA>  None
# 66  [<NA>, <NA>]             <NA>  None
# 71  [<NA>, <NA>]             <NA>  None
# 73  [<NA>, <NA>]             <NA>  None
# 74  [<NA>, <NA>]             <NA>  None
# 77  [<NA>, <NA>]             <NA>  None
# 30          <NA>             <NA>  <NA>
# 34          <NA>       دُولَارَات  <NA>
# 38          masc     اِتِّحَادَات   وحد
# 48           fem            دُوَل  <NA>
# 3           <NA>             <NA>   رعي
# 63           fem        كِتَابَات  <NA>
# 61           fem         مَعَارِف  <NA>
# 62           fem        قِرَاءَات   قرء
# 67           fem            نِسَب   نسب
# 69           fem         نُقْطَات   نقط
# 9           masc         وُزَرَاء   وزر
# 0           masc            نُظُم   نظم
# 72          masc            نُظُم   نظم
# 75           fem             <NA>   بطل
# 6            fem            قِيَم   قوم
# 5           <NA>         ضَرَائِب   ضرب
# 28          masc             <NA>  <NA>
# 40          masc  أُورُوبِّيُّونَ  <NA>
# 46          masc         رُؤَسَاء   رءس
# 13           fem             <NA>  <NA>
# 81  [<NA>, <NA>]             <NA>  None
# 19          masc            عَرَب  <NA>
# 56          masc         أَعْمَار   عمر
